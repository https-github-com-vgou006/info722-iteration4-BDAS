# %%
# Must be included at the beginning of each notebook. Remember to change the app name. 
import findspark
findspark.init('/home/ubuntu/spark-3.2.1-bin-hadoop2.7')
import pyspark

# Create SparkSession and giving it an appname
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('data_preparation').getOrCreate()

import warnings
warnings.simplefilter(action='ignore')
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/home/ubuntu/spark-3.2.1-bin-hadoop2.7/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/10/13 09:11:42 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Import the relevant Python libraries.
import numpy as np
import matplotlib.pyplot as plt
from pyspark.sql.functions import regexp_replace, udf
from pyspark.sql.types import IntegerType
from pyspark.sql.types import *
from pyspark.sql.functions import *
import pyspark.sql.functions as F
from pyspark.ml.feature import StringIndexer, VectorAssembler, StandardScaler, Bucketizer 
import seaborn as sns
import pandas as pd
from pyspark.sql import Window

from pyspark.mllib.evaluation import MulticlassMetrics
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml import Pipeline
import json
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

# %%
# Use Spark to read in the Maternal Health csv file; you can infer csv schemas.
data = spark.read.csv("Maternal Health Risk Data Set.csv", inferSchema=True, header=True)
data.show(5, truncate=15)
# Out:
# +---+----------+-----------+----------+--------+---------+---------+----------+
# |Age|SystolicBP|DiastolicBP|bloodsugar|bodyTemp|heartRate|riskLevel|   comment|
# +---+----------+-----------+----------+--------+---------+---------+----------+
# | 25|       130|         80|      15.0|    98.0|       86|high risk|no comment|
# | 35|       140|         90|      13.0|    98.0|       70|high risk|no comment|
# | 29|        90|         70|       8.0|   100.0|       80|high risk|no comment|
# | 30|       140|         85|       7.0|    98.0|       70|high risk|no comment|
# | 35|       120|         60|       6.1|    98.0|       76| low risk|no comment|
# +---+----------+-----------+----------+--------+---------+---------+----------+
# only showing top 5 rows

# %%
def data_prep(data):
    #######3.1
    data.filter((data['Age']==-9999999) | (data['Age']==1000) | (data['heartRate']==7))
    # drop the 'comment' column    
    data=data.drop('comment')
    #######3.2.1
    # delete row containing '" "'
    data=data.filter(data.riskLevel!=" ")
    # delete extreme 'Age' value rows
    data = data.filter(data.Age!=-9999999)
    data = data.filter(data.Age!=-1)
    data = data.filter(data.Age!=1000)
    #Replace part of string with another string
    data = data.withColumn('Age', regexp_replace('Age', '-23', '23'))
    # Type cast string column to integer column in pyspark
    data = data.withColumn("Age", data["Age"].cast(IntegerType()))
    # find average 'Age'
    data.agg({'Age': 'avg'})
    # exclude extreme 'heartRate' values
    data = data.filter(data.heartRate!=7)
    ##########3.2.2 Convert data types
    # Type cast in pyspark
    data=data.withColumn('Age', data['Age'].cast(DoubleType()))
    data=data.withColumn('SystolicBP', data['SystolicBP'].cast(DoubleType()))
    data = data.withColumn("DiastolicBP", data["DiastolicBP"].cast(DoubleType()))
    ##########3.2.3 'riskLevel' coding scheme
    # reclassify into "low risk" class
    f=data.where(data.riskLevel.startswith('L'))
    for i in range(0,f.count()):
        data=data.withColumn('riskLevel', F.regexp_replace('riskLevel', f.collect()[i]['riskLevel'], "low risk"))
    # reclassify into "mid risk" class
    f=data.where(data.riskLevel.startswith('M'))
    for i in range(0, f.count()):
        data=data.withColumn('riskLevel',
                     F.regexp_replace('riskLevel', f.collect()[i]['riskLevel'], 'mid risk'))
    # reclassify into "high risk" class
    f=data.where(data.riskLevel.startswith('H'))
    for i in range(0,f.count()):
        data=data.withColumn('riskLevel',
                     F.regexp_replace('riskLevel', f.collect()[i]['riskLevel'], 'high risk'))
    # Remove leading space of the column in pyspark
    data=data.withColumn('riskLevel', F.trim(data.riskLevel))
    ########3.2.4 Assign integer values to categorical variables
    indexer = StringIndexer(inputCol="riskLevel", outputCol="riskLevelIndex")
    data = indexer.fit(data).transform(data)
    ########3.2.5 Consistency in Attribute naming
    data=data.withColumnRenamed('bloodsugar', 'BS').withColumnRenamed('bodyTemp', 'BodyTemp')
    data=data.withColumnRenamed('heartRate', 'HeartRate').withColumnRenamed('riskLevel', 'RiskLevel')
    data=data.withColumnRenamed('riskLevelIndex', 'RiskLevelIndex')
    ########3.2.6 selecting the target and input variables
    assembler = VectorAssembler(
        inputCols=['Age','SystolicBP','DiastolicBP','BS','BodyTemp','HeartRate'],
        outputCol="features")
    data=assembler.transform(data)
    # target variable
    target=data.select(['RiskLevelIndex']).toPandas()
    ########3.2.7 standardizing the input attribute values
    standardScaler=StandardScaler()
    standardScaler.setInputCol('features')
    model=standardScaler.fit(data)
    model.setOutputCol('features_scaled')
    data=model.transform(data)
    #######3.3 constructing / deriving a new feature
    bucketizer = Bucketizer(splits=[ float('-inf'), 31.5, 45, float('Inf') ],
                            inputCol='Age', outputCol="Age_Tier")
    df_buck = bucketizer.setHandleInvalid("keep").transform(data)
    t = {0.0:"Young", 1.0: "Matured_Young", 2.0:"Middle_Age"}
    udf_foo = udf(lambda x: t[x], StringType())
    df_buck=df_buck.withColumn("Age_Tier", udf_foo("Age_Tier"))
    
    return data

# Use Spark to read in the Maternal Health csv file; you can infer csv schemas.
data = spark.read.csv("Maternal Health Risk Data Set.csv", inferSchema=True, header=True)
data = data_prep(data=data)

# %%
# 8.1 Pattern1

# %%
# calculate performance accuracy on all the features
data_changed=data.select(data.columns[0:8])
# collect the input features
assembler = VectorAssembler(
        inputCols=['Age','SystolicBP','DiastolicBP','BS','BodyTemp','HeartRate'], outputCol="features")
# transform the data
data_changed=assembler.transform(data_changed)
# standardize the feature values
standardScaler=StandardScaler()
standardScaler.setInputCol('features')
model=standardScaler.fit(data_changed)
model.setOutputCol('features_scaled')
data_changed=model.transform(data_changed)

# %%
# splitting data into training and test data set
train_data, test_data = data_changed.randomSplit(weights=[0.75,0.25], seed=1)
# definition to evaluate train accuracy, test accuracy
def testparams(**params):
    rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4, **params)
    model = rfc.fit(train_data)
    def model_score(evaluate_data):
        predictions=model.transform(evaluate_data)
        evaluator = MulticlassClassificationEvaluator(
            labelCol="RiskLevelIndex", predictionCol="prediction", metricName="accuracy")
        return evaluator.evaluate(predictions)
    return model_score(train_data), model_score(test_data)

# %%
# definition to evaluate train accuracy, test accuracy
def testparams(**params):
    rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4, **params)
    model = rfc.fit(train_data)
    def model_score(evaluate_data):
        predictions=model.transform(evaluate_data)
        evaluator = MulticlassClassificationEvaluator(
            labelCol="RiskLevelIndex", predictionCol="prediction", metricName="accuracy")
        return evaluator.evaluate(predictions)
    return model_score(train_data), model_score(test_data)

# %%
# testparams print train error (left), test error (right)
print('train error (left), test error (right)\n', testparams())
# fit model on train_data
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
model = rfc.fit(train_data)
# predict response
predictions = model.transform(test_data)
# Metrics
predictionRDD = predictions.select(['RiskLevelIndex', 'prediction']).rdd.map(lambda line: (line[1], line[0]))
metrics = MulticlassMetrics(predictionRDD)
# Confusion Matrix
print('\n Confusion Matrix \n', metrics.confusionMatrix().toArray())
# Out:
# train error (left), test error (right)
#  (0.7763659466327827, 0.6844444444444444)
#  Confusion Matrix
#  [[75. 17.  1.]
#  [16. 47.  4.]
#  [ 4.  6. 55.]]

# %%
# 8.1 Pattern2

# %%
# concatenate the columns to calculate correlation coefficients
data_corr=data_changed.select(data_changed.columns[0:6] + [data_changed.columns[-3]]).toPandas()
# correlation
corr_mat=data_corr.corr()
# view the correlation values
corr_mat['RiskLevelIndex']
# Out:
# Age               0.263775
# SystolicBP        0.396500
# DiastolicBP       0.346536
# BS                0.569161
# BodyTemp          0.165693
# HeartRate         0.188532
# RiskLevelIndex    1.000000
# Name: RiskLevelIndex, dtype: float64

# %%
# correlation in between features 'BodyTemp' and 'RiskLevel'
data_changed['BodyTemp', 'RiskLevelIndex'].toPandas().corr()
# Out:
#                 BodyTemp  RiskLevelIndex
# BodyTemp        1.000000        0.165693
# RiskLevelIndex  0.165693        1.000000

# %%
def parse_debug_string_lines(lines):
    
    block = []
    while lines:


        if lines[0].startswith('If'):
            bl = ' '.join(lines.pop(0).split()[1:]).replace('(', '').replace(')', '')
            block.append({'name': bl, 'children': parse_debug_string_lines(lines)})


            if lines[0].startswith('Else'):
                be = ' '.join(lines.pop(0).split()[1:]).replace('(', '').replace(')', '')
                block.append({'name': be, 'children': parse_debug_string_lines(lines)})
        elif not lines[0].startswith(('If', 'Else')):
            block2 = lines.pop(0)
            block.append({'name': block2})
        else:
            break
    
    return block


def debug_str_to_json(debug_string):
    data = []
    for line in debug_string.splitlines():
        if line.strip():
            line = line.strip()
            data.append(line)
        else:
            break
        if not line: break

    json = {'name': 'Root', 'children': parse_debug_string_lines(data[1:])}
    

    return json

# %%
# prepare data and model
pipeline = Pipeline(stages=[rfc])
model = pipeline.fit(data_changed)
tree_model_classifier = model.stages[0]

f_type_to_flist_dict = data_changed.schema['features'].metadata["ml_attr"]["attrs"]
f_index_to_name_dict = {}
for f_type, f_list in f_type_to_flist_dict.items():
   for f in f_list:
       f_index = f['idx']
       f_name = f['name']
       f_index_to_name_dict[f_index] = f_name

tree = tree_model_classifier.toDebugString
for i in range(len(f_index_to_name_dict)):
   tree = tree.replace('feature {}'.format(i), f_index_to_name_dict.get(i))

debug_str_to_json(tree)
# Out:
# {'name': 'Root',
#  'children': [{'name': 'Tree 0 (weight 1.0):'},
#   {'name': 'BS <= 2.5827513666338042',
#    'children': [{'name': 'SystolicBP <= 7.200871499187824',
#      'children': [{'name': 'BS <= 2.1436836343060572',
#        'children': [{'name': 'SystolicBP <= 6.76610189923686',
#          'children': [{'name': 'BodyTemp <= 72.37315033735982',
#            'children': [{'name': 'HeartRate <= 11.588905058122126',
#              'children': [{'name': 'Age <= 1.0773563138523257',
#                'children': [{'name': 'SystolicBP <= 6.113947499310417',
#                  'children': [{'name': 'Predict: 1.0'}]},
#                 {'name': 'SystolicBP > 6.113947499310417',
#                  'children': [{'name': 'BS <= 2.081393748404889',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'BS > 2.081393748404889',
#                    'children': [{'name': 'Predict: 0.0'}]}]}]},
#               {'name': 'Age > 1.0773563138523257',
#                'children': [{'name': 'BS <= 2.0510084382091973',
#                  'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                    'children': [{'name': 'Age <= 2.117562409985606',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'Age > 2.117562409985606',
#                      'children': [{'name': 'Predict: 1.0'}]}]},
#                   {'name': 'DiastolicBP > 5.2167636047766175',
#                    'children': [{'name': 'Predict: 0.0'}]}]},
#                 {'name': 'BS > 2.0510084382091973',
#                  'children': [{'name': 'Age <= 1.151656749290417',
#                    'children': [{'name': 'Predict: 0.0'}]},
#                   {'name': 'Age > 1.151656749290417',
#                    'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'DiastolicBP > 5.2167636047766175',
#                      'children': [{'name': 'Predict: 1.0'}]}]}]}]}]},
#             {'name': 'HeartRate > 11.588905058122126',
#              'children': [{'name': 'Predict: 0.0'}]}]},
#           {'name': 'BodyTemp > 72.37315033735982',
#            'children': [{'name': 'HeartRate <= 8.325362829110722',
#              'children': [{'name': 'Predict: 0.0'}]},
#             {'name': 'HeartRate > 8.325362829110722',
#              'children': [{'name': 'Age <= 1.0773563138523257',
#                'children': [{'name': 'Predict: 2.0'}]},
#               {'name': 'Age > 1.0773563138523257',
#                'children': [{'name': 'Age <= 1.3745580556046912',
#                  'children': [{'name': 'BS <= 2.081393748404889',
#                    'children': [{'name': 'SystolicBP <= 5.0270234994330085',
#                      'children': [{'name': 'Predict: 2.0'}]},
#                     {'name': 'SystolicBP > 5.0270234994330085',
#                      'children': [{'name': 'Predict: 0.0'}]}]},
#                   {'name': 'BS > 2.081393748404889',
#                    'children': [{'name': 'Predict: 1.0'}]}]},
#                 {'name': 'Age > 1.3745580556046912',
#                  'children': [{'name': 'BodyTemp <= 74.55525537265709',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'BodyTemp > 74.55525537265709',
#                    'children': [{'name': 'Predict: 0.0'}]}]}]}]}]}]},
#         {'name': 'SystolicBP > 6.76610189923686',
#          'children': [{'name': 'Predict: 1.0'}]}]},
#       {'name': 'BS > 2.1436836343060572',
#        'children': [{'name': 'SystolicBP <= 6.76610189923686',
#          'children': [{'name': 'BodyTemp <= 71.42757148873099',
#            'children': [{'name': 'HeartRate <= 10.789670226527495',
#              'children': [{'name': 'HeartRate <= 8.325362829110722',
#                'children': [{'name': 'Age <= 1.8203606682332398',
#                  'children': [{'name': 'SystolicBP <= 4.565080799485111',
#                    'children': [{'name': 'Predict: 0.0'}]},
#                   {'name': 'SystolicBP > 4.565080799485111',
#                    'children': [{'name': 'BS <= 2.354861540166115',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'BS > 2.354861540166115',
#                      'children': [{'name': 'Predict: 1.0'}]}]}]},
#                 {'name': 'Age > 1.8203606682332398',
#                  'children': [{'name': 'Predict: 0.0'}]}]},
#               {'name': 'HeartRate > 8.325362829110722',
#                'children': [{'name': 'Predict: 0.0'}]}]},
#             {'name': 'HeartRate > 10.789670226527495',
#              'children': [{'name': 'DiastolicBP <= 6.260116325731941',
#                'children': [{'name': 'Predict: 0.0'}]},
#               {'name': 'DiastolicBP > 6.260116325731941',
#                'children': [{'name': 'Predict: 1.0'}]}]}]},
#           {'name': 'BodyTemp > 71.42757148873099',
#            'children': [{'name': 'BS <= 2.2940909197747317',
#              'children': [{'name': 'HeartRate <= 8.325362829110722',
#                'children': [{'name': 'Age <= 1.0773563138523257',
#                  'children': [{'name': 'Predict: 0.0'}]},
#                 {'name': 'Age > 1.0773563138523257',
#                  'children': [{'name': 'Predict: 2.0'}]}]},
#               {'name': 'HeartRate > 8.325362829110722',
#                'children': [{'name': 'BodyTemp <= 73.827887027558',
#                  'children': [{'name': 'HeartRate <= 10.789670226527495',
#                    'children': [{'name': 'Age <= 2.117562409985606',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'Age > 2.117562409985606',
#                      'children': [{'name': 'Predict: 1.0'}]}]},
#                   {'name': 'HeartRate > 10.789670226527495',
#                    'children': [{'name': 'Predict: 1.0'}]}]},
#                 {'name': 'BodyTemp > 73.827887027558',
#                  'children': [{'name': 'Predict: 0.0'}]}]}]},
#             {'name': 'BS > 2.2940909197747317',
#              'children': [{'name': 'HeartRate <= 9.657420881768438',
#                'children': [{'name': 'Predict: 2.0'}]},
#               {'name': 'HeartRate > 9.657420881768438',
#                'children': [{'name': 'Age <= 2.117562409985606',
#                  'children': [{'name': 'Age <= 1.0773563138523257',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'Age > 1.0773563138523257',
#                    'children': [{'name': 'SystolicBP <= 5.0270234994330085',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'SystolicBP > 5.0270234994330085',
#                      'children': [{'name': 'Predict: 1.0'}]}]}]},
#                 {'name': 'Age > 2.117562409985606',
#                  'children': [{'name': 'Predict: 2.0'}]}]}]}]}]},
#         {'name': 'SystolicBP > 6.76610189923686',
#          'children': [{'name': 'Predict: 1.0'}]}]}]},
#     {'name': 'SystolicBP > 7.200871499187824',
#      'children': [{'name': 'BS <= 2.0510084382091973',
#        'children': [{'name': 'Predict: 1.0'}]},
#       {'name': 'BS > 2.0510084382091973',
#        'children': [{'name': 'Predict: 2.0'}]}]}]},
#   {'name': 'BS > 2.5827513666338042',
#    'children': [{'name': 'SystolicBP <= 7.200871499187824',
#      'children': [{'name': 'SystolicBP <= 4.755292499463657',
#        'children': [{'name': 'Predict: 1.0'}]},
#       {'name': 'SystolicBP > 4.755292499463657',
#        'children': [{'name': 'HeartRate <= 10.190244102831524',
#          'children': [{'name': 'Age <= 3.306369376995068',
#            'children': [{'name': 'SystolicBP <= 6.76610189923686',
#              'children': [{'name': 'BS <= 3.4943106725045583',
#                'children': [{'name': 'SystolicBP <= 5.0270234994330085',
#                  'children': [{'name': 'Predict: 2.0'}]},
#                 {'name': 'SystolicBP > 5.0270234994330085',
#                  'children': [{'name': 'Predict: 1.0'}]}]},
#               {'name': 'BS > 3.4943106725045583',
#                'children': [{'name': 'Predict: 2.0'}]}]},
#             {'name': 'SystolicBP > 6.76610189923686',
#              'children': [{'name': 'Predict: 1.0'}]}]},
#           {'name': 'Age > 3.306369376995068',
#            'children': [{'name': 'HeartRate <= 10.057038297565752',
#              'children': [{'name': 'BS <= 4.2539434273968535',
#                'children': [{'name': 'Age <= 4.123674166814074',
#                  'children': [{'name': 'Predict: 1.0'}]},
#                 {'name': 'Age > 4.123674166814074',
#                  'children': [{'name': 'Predict: 2.0'}]}]},
#               {'name': 'BS > 4.2539434273968535',
#                'children': [{'name': 'HeartRate <= 8.325362829110722',
#                  'children': [{'name': 'Age <= 4.123674166814074',
#                    'children': [{'name': 'Predict: 2.0'}]},
#                   {'name': 'Age > 4.123674166814074',
#                    'children': [{'name': 'Predict: 1.0'}]}]},
#                 {'name': 'HeartRate > 8.325362829110722',
#                  'children': [{'name': 'Predict: 2.0'}]}]}]},
#             {'name': 'HeartRate > 10.057038297565752',
#              'children': [{'name': 'Predict: 1.0'}]}]}]},
#         {'name': 'HeartRate > 10.190244102831524',
#          'children': [{'name': 'BodyTemp <= 73.827887027558',
#            'children': [{'name': 'Age <= 2.9348671998046107',
#              'children': [{'name': 'Predict: 2.0'}]},
#             {'name': 'Age > 2.9348671998046107',
#              'children': [{'name': 'SystolicBP <= 6.76610189923686',
#                'children': [{'name': 'BS <= 4.2539434273968535',
#                  'children': [{'name': 'Predict: 2.0'}]},
#                 {'name': 'BS > 4.2539434273968535',
#                  'children': [{'name': 'Predict: 1.0'}]}]},
#               {'name': 'SystolicBP > 6.76610189923686',
#                'children': [{'name': 'Predict: 2.0'}]}]}]},
#           {'name': 'BodyTemp > 73.827887027558',
#            'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#     {'name': 'SystolicBP > 7.200871499187824',
#      'children': [{'name': 'Predict: 2.0'},
#       {'name': 'Tree 1 (weight 1.0):'},
#       {'name': 'BS <= 2.5827513666338042',
#        'children': [{'name': 'DiastolicBP <= 7.015647606423727',
#          'children': [{'name': 'BS <= 2.1436836343060572',
#            'children': [{'name': 'Age <= 1.151656749290417',
#              'children': [{'name': 'Age <= 1.0773563138523257',
#                'children': [{'name': 'BodyTemp <= 72.37315033735982',
#                  'children': [{'name': 'BS <= 2.081393748404889',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'BS > 2.081393748404889',
#                    'children': [{'name': 'HeartRate <= 8.724980244908036',
#                      'children': [{'name': 'HeartRate <= 8.325362829110722',
#                        'children': [{'name': 'Predict: 0.0'}]},
#                       {'name': 'HeartRate > 8.325362829110722',
#                        'children': [{'name': 'Predict: 1.0'}]}]},
#                     {'name': 'HeartRate > 8.724980244908036',
#                      'children': [{'name': 'Predict: 0.0'}]}]}]},
#                 {'name': 'BodyTemp > 72.37315033735982',
#                  'children': [{'name': 'SystolicBP <= 5.0270234994330085',
#                    'children': [{'name': 'Predict: 2.0'}]},
#                   {'name': 'SystolicBP > 5.0270234994330085',
#                    'children': [{'name': 'Predict: 0.0'}]}]}]},
#               {'name': 'Age > 1.0773563138523257',
#                'children': [{'name': 'HeartRate <= 9.657420881768438',
#                  'children': [{'name': 'SystolicBP <= 4.565080799485111',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'SystolicBP > 4.565080799485111',
#                    'children': [{'name': 'Predict: 0.0'}]}]},
#                 {'name': 'HeartRate > 9.657420881768438',
#                  'children': [{'name': 'Predict: 0.0'}]}]}]},
#             {'name': 'Age > 1.151656749290417',
#              'children': [{'name': 'BodyTemp <= 71.64578199226071',
#                'children': [{'name': 'SystolicBP <= 6.76610189923686',
#                  'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                    'children': [{'name': 'DiastolicBP <= 5.432629684974271',
#                      'children': [{'name': 'SystolicBP <= 5.0270234994330085',
#                        'children': [{'name': 'Age <= 1.671759797357057',
#                          'children': [{'name': 'Predict: 1.0'}]},
#                         {'name': 'Age > 1.671759797357057',
#                          'children': [{'name': 'Predict: 0.0'}]}]},
#                       {'name': 'SystolicBP > 5.0270234994330085',
#                        'children': [{'name': 'SystolicBP <= 6.113947499310417',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'SystolicBP > 6.113947499310417',
#                          'children': [{'name': 'Predict: 1.0'}]}]}]},
#                     {'name': 'DiastolicBP > 5.432629684974271',
#                      'children': [{'name': 'HeartRate <= 10.523258615995953',
#                        'children': [{'name': 'BS <= 2.0510084382091973',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'BS > 2.0510084382091973',
#                          'children': [{'name': 'Predict: 1.0'}]}]},
#                       {'name': 'HeartRate > 10.523258615995953',
#                        'children': [{'name': 'Predict: 0.0'}]}]}]},
#                   {'name': 'DiastolicBP > 5.936317205435461',
#                    'children': [{'name': 'Age <= 1.671759797357057',
#                      'children': [{'name': 'BS <= 2.081393748404889',
#                        'children': [{'name': 'HeartRate <= 8.325362829110722',
#                          'children': [{'name': 'Predict: 1.0'}]},
#                         {'name': 'HeartRate > 8.325362829110722',
#                          'children': [{'name': 'Predict: 0.0'}]}]},
#                       {'name': 'BS > 2.081393748404889',
#                        'children': [{'name': 'Predict: 0.0'}]}]},
#                     {'name': 'Age > 1.671759797357057',
#                      'children': [{'name': 'Age <= 2.117562409985606',
#                        'children': [{'name': 'DiastolicBP <= 6.260116325731941',
#                          'children': [{'name': 'Predict: 1.0'}]},
#                         {'name': 'DiastolicBP > 6.260116325731941',
#                          'children': [{'name': 'Predict: 0.0'}]}]},
#                       {'name': 'Age > 2.117562409985606',
#                        'children': [{'name': 'HeartRate <= 10.789670226527495',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'HeartRate > 10.789670226527495',
#                          'children': [{'name': 'Predict: 1.0'}]}]}]}]}]},
#                 {'name': 'SystolicBP > 6.76610189923686',
#                  'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'DiastolicBP > 5.2167636047766175',
#                    'children': [{'name': 'Age <= 2.3404637162998796',
#                      'children': [{'name': 'Predict: 2.0'}]},
#                     {'name': 'Age > 2.3404637162998796',
#                      'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#               {'name': 'BodyTemp > 71.64578199226071',
#                'children': [{'name': 'HeartRate <= 10.789670226527495',
#                  'children': [{'name': 'Age <= 2.563365022614154',
#                    'children': [{'name': 'BodyTemp <= 74.55525537265709',
#                      'children': [{'name': 'DiastolicBP <= 4.785031444381311',
#                        'children': [{'name': 'Predict: 1.0'}]},
#                       {'name': 'DiastolicBP > 4.785031444381311',
#                        'children': [{'name': 'SystolicBP <= 6.113947499310417',
#                          'children': [{'name': 'Predict: 2.0'}]},
#                         {'name': 'SystolicBP > 6.113947499310417',
#                          'children': [{'name': 'Predict: 1.0'}]}]}]},
#                     {'name': 'BodyTemp > 74.55525537265709',
#                      'children': [{'name': 'Predict: 2.0'}]}]},
#                   {'name': 'Age > 2.563365022614154',
#                    'children': [{'name': 'BS <= 2.081393748404889',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'BS > 2.081393748404889',
#                      'children': [{'name': 'Predict: 0.0'}]}]}]},
#                 {'name': 'HeartRate > 10.789670226527495',
#                  'children': [{'name': 'Age <= 1.3002576201665998',
#                    'children': [{'name': 'Predict: 2.0'}]},
#                   {'name': 'Age > 1.3002576201665998',
#                    'children': [{'name': 'Predict: 1.0'}]}]}]}]}]},
#           {'name': 'BS > 2.1436836343060572',
#            'children': [{'name': 'BodyTemp <= 71.42757148873099',
#              'children': [{'name': 'BS <= 2.354861540166115',
#                'children': [{'name': 'HeartRate <= 10.190244102831524',
#                  'children': [{'name': 'Predict: 0.0'}]},
#                 {'name': 'HeartRate > 10.190244102831524',
#                  'children': [{'name': 'SystolicBP <= 7.0378328992062125',
#                    'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'DiastolicBP > 5.2167636047766175',
#                      'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                        'children': [{'name': 'BS <= 2.1725496789919645',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'BS > 2.1725496789919645',
#                          'children': [{'name': 'Predict: 1.0'}]}]},
#                       {'name': 'DiastolicBP > 5.936317205435461',
#                        'children': [{'name': 'Predict: 0.0'}]}]}]},
#                   {'name': 'SystolicBP > 7.0378328992062125',
#                    'children': [{'name': 'Predict: 1.0'}]}]}]},
#               {'name': 'BS > 2.354861540166115',
#                'children': [{'name': 'SystolicBP <= 6.76610189923686',
#                  'children': [{'name': 'Age <= 1.3002576201665998',
#                    'children': [{'name': 'Predict: 0.0'}]},
#                   {'name': 'Age > 1.3002576201665998',
#                    'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'DiastolicBP > 5.2167636047766175',
#                      'children': [{'name': 'DiastolicBP <= 6.655870806094304',
#                        'children': [{'name': 'BS <= 2.385246850361807',
#                          'children': [{'name': 'Predict: 1.0'}]},
#                         {'name': 'BS > 2.385246850361807',
#                          'children': [{'name': 'Predict: 0.0'}]}]},
#                       {'name': 'DiastolicBP > 6.655870806094304',
#                        'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                 {'name': 'SystolicBP > 6.76610189923686',
#                  'children': [{'name': 'Predict: 1.0'}]}]}]},
#             {'name': 'BodyTemp > 71.42757148873099',
#              'children': [{'name': 'Age <= 2.117562409985606',
#                'children': [{'name': 'Age <= 1.3002576201665998',
#                  'children': [{'name': 'SystolicBP <= 4.755292499463657',
#                    'children': [{'name': 'BS <= 2.2940909197747317',
#                      'children': [{'name': 'BodyTemp <= 73.827887027558',
#                        'children': [{'name': 'BodyTemp <= 73.1005186824589',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'BodyTemp > 73.1005186824589',
#                          'children': [{'name': 'Predict: 2.0'}]}]},
#                       {'name': 'BodyTemp > 73.827887027558',
#                        'children': [{'name': 'Predict: 0.0'}]}]},
#                     {'name': 'BS > 2.2940909197747317',
#                      'children': [{'name': 'Predict: 0.0'}]}]},
#                   {'name': 'SystolicBP > 4.755292499463657',
#                    'children': [{'name': 'DiastolicBP <= 4.6051430442166',
#                      'children': [{'name': 'BS <= 2.2940909197747317',
#                        'children': [{'name': 'Predict: 0.0'}]},
#                       {'name': 'BS > 2.2940909197747317',
#                        'children': [{'name': 'Predict: 2.0'}]}]},
#                     {'name': 'DiastolicBP > 4.6051430442166',
#                      'children': [{'name': 'SystolicBP <= 5.0270234994330085',
#                        'children': [{'name': 'Age <= 1.0773563138523257',
#                          'children': [{'name': 'Predict: 1.0'}]},
#                         {'name': 'Age > 1.0773563138523257',
#                          'children': [{'name': 'Predict: 0.0'}]}]},
#                       {'name': 'SystolicBP > 5.0270234994330085',
#                        'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                 {'name': 'Age > 1.3002576201665998',
#                  'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                    'children': [{'name': 'BodyTemp <= 73.827887027558',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'BodyTemp > 73.827887027558',
#                      'children': [{'name': 'Predict: 2.0'}]}]},
#                   {'name': 'DiastolicBP > 4.425254644051889',
#                    'children': [{'name': 'Age <= 1.3745580556046912',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'Age > 1.3745580556046912',
#                      'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#               {'name': 'Age > 2.117562409985606',
#                'children': [{'name': 'DiastolicBP <= 5.432629684974271',
#                  'children': [{'name': 'Predict: 2.0'}]},
#                 {'name': 'DiastolicBP > 5.432629684974271',
#                  'children': [{'name': 'SystolicBP <= 6.76610189923686',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'SystolicBP > 6.76610189923686',
#                    'children': [{'name': 'Predict: 2.0'}]}]}]}]}]}]},
#         {'name': 'DiastolicBP > 7.015647606423727',
#          'children': [{'name': 'HeartRate <= 8.325362829110722',
#            'children': [{'name': 'Predict: 1.0'}]},
#           {'name': 'HeartRate > 8.325362829110722',
#            'children': [{'name': 'Predict: 2.0'}]}]}]},
#       {'name': 'BS > 2.5827513666338042',
#        'children': [{'name': 'SystolicBP <= 7.200871499187824',
#          'children': [{'name': 'Age <= 3.6778715541855256',
#            'children': [{'name': 'BS <= 3.4943106725045583',
#              'children': [{'name': 'Age <= 2.117562409985606',
#                'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                  'children': [{'name': 'HeartRate <= 10.523258615995953',
#                    'children': [{'name': 'Predict: 2.0'}]},
#                   {'name': 'HeartRate > 10.523258615995953',
#                    'children': [{'name': 'Predict: 1.0'}]}]},
#                 {'name': 'DiastolicBP > 4.425254644051889',
#                  'children': [{'name': 'HeartRate <= 8.325362829110722',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'HeartRate > 8.325362829110722',
#                    'children': [{'name': 'Predict: 2.0'}]}]}]},
#               {'name': 'Age > 2.117562409985606',
#                'children': [{'name': 'Age <= 2.9348671998046107',
#                  'children': [{'name': 'DiastolicBP <= 5.432629684974271',
#                    'children': [{'name': 'Predict: 2.0'}]},
#                   {'name': 'DiastolicBP > 5.432629684974271',
#                    'children': [{'name': 'HeartRate <= 10.190244102831524',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'HeartRate > 10.190244102831524',
#                      'children': [{'name': 'Predict: 2.0'}]}]}]},
#                 {'name': 'Age > 2.9348671998046107',
#                  'children': [{'name': 'Age <= 3.306369376995068',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'Age > 3.306369376995068',
#                    'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#             {'name': 'BS > 3.4943106725045583',
#              'children': [{'name': 'Predict: 2.0'}]}]},
#           {'name': 'Age > 3.6778715541855256',
#            'children': [{'name': 'BS <= 4.2539434273968535',
#              'children': [{'name': 'Age <= 4.123674166814074',
#                'children': [{'name': 'Predict: 1.0'}]},
#               {'name': 'Age > 4.123674166814074',
#                'children': [{'name': 'Predict: 2.0'}]}]},
#             {'name': 'BS > 4.2539434273968535',
#              'children': [{'name': 'HeartRate <= 10.057038297565752',
#                'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                  'children': [{'name': 'Predict: 2.0'}]},
#                 {'name': 'DiastolicBP > 5.936317205435461',
#                  'children': [{'name': 'BS <= 5.013576182289149',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'BS > 5.013576182289149',
#                    'children': [{'name': 'Predict: 2.0'}]}]}]},
#               {'name': 'HeartRate > 10.057038297565752',
#                'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#         {'name': 'SystolicBP > 7.200871499187824',
#          'children': [{'name': 'Predict: 2.0'},
#           {'name': 'Tree 2 (weight 1.0):'},
#           {'name': 'DiastolicBP <= 6.655870806094304',
#            'children': [{'name': 'HeartRate <= 11.18928764232481',
#              'children': [{'name': 'BS <= 2.5827513666338042',
#                'children': [{'name': 'SystolicBP <= 6.76610189923686',
#                  'children': [{'name': 'BS <= 2.1436836343060572',
#                    'children': [{'name': 'BodyTemp <= 72.37315033735982',
#                      'children': [{'name': 'BS <= 2.081393748404889',
#                        'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                          'children': [{'name': 'Age <= 2.117562409985606',
#                            'children': [{'name': 'Predict: 0.0'}]},
#                           {'name': 'Age > 2.117562409985606',
#                            'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'DiastolicBP > 5.936317205435461',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]},
#                         {'name': 'BodyTemp > 71.42757148873099',
#                          'children': [{'name': 'Predict: 0.0'}]}]},
#                       {'name': 'BS > 2.081393748404889',
#                        'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                          'children': [{'name': 'Age <= 2.563365022614154',
#                            'children': [{'name': 'BS <= 2.1117790586005807',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'BS > 2.1117790586005807',
#                              'children': [{'name': 'Predict: 0.0'}]}]},
#                           {'name': 'Age > 2.563365022614154',
#                            'children': [{'name': 'Predict: 0.0'}]}]},
#                         {'name': 'DiastolicBP > 5.2167636047766175',
#                          'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                            'children': [{'name': 'BS <= 2.1284909792082116',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'BS > 2.1284909792082116',
#                              'children': [{'name': 'Predict: 0.0'}]}]},
#                           {'name': 'DiastolicBP > 5.936317205435461',
#                            'children': [{'name': 'HeartRate <= 9.657420881768438',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'HeartRate > 9.657420881768438',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]}]}]},
#                     {'name': 'BodyTemp > 72.37315033735982',
#                      'children': [{'name': 'Age <= 1.0773563138523257',
#                        'children': [{'name': 'BS <= 1.8838892321328924',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'BS > 1.8838892321328924',
#                          'children': [{'name': 'Predict: 2.0'}]}]},
#                       {'name': 'Age > 1.0773563138523257',
#                        'children': [{'name': 'HeartRate <= 8.99139185543958',
#                          'children': [{'name': 'Predict: 2.0'}]},
#                         {'name': 'HeartRate > 8.99139185543958',
#                          'children': [{'name': 'Age <= 2.563365022614154',
#                            'children': [{'name': 'Predict: 1.0'}]},
#                           {'name': 'Age > 2.563365022614154',
#                            'children': [{'name': 'BodyTemp <= 73.827887027558',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'BodyTemp > 73.827887027558',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]}]}]}]},
#                   {'name': 'BS > 2.1436836343060572',
#                    'children': [{'name': 'HeartRate <= 10.323449908097295',
#                      'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                        'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                          'children': [{'name': 'Age <= 1.5974593619189656',
#                            'children': [{'name': 'Predict: 0.0'}]},
#                           {'name': 'Age > 1.5974593619189656',
#                            'children': [{'name': 'Age <= 1.671759797357057',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'Age > 1.671759797357057',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]},
#                         {'name': 'DiastolicBP > 5.2167636047766175',
#                          'children': [{'name': 'BS <= 2.354861540166115',
#                            'children': [{'name': 'Predict: 0.0'}]},
#                           {'name': 'BS > 2.354861540166115',
#                            'children': [{'name': 'HeartRate <= 8.858186050173808',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'HeartRate > 8.858186050173808',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                       {'name': 'BodyTemp > 71.42757148873099',
#                        'children': [{'name': 'BS <= 2.2940909197747317',
#                          'children': [{'name': 'BS <= 2.2333202993833483',
#                            'children': [{'name': 'Predict: 2.0'}]},
#                           {'name': 'BS > 2.2333202993833483',
#                            'children': [{'name': 'HeartRate <= 8.325362829110722',
#                              'children': [{'name': 'Predict: 2.0'}]},
#                             {'name': 'HeartRate > 8.325362829110722',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]},
#                         {'name': 'BS > 2.2940909197747317',
#                          'children': [{'name': 'Age <= 1.3002576201665998',
#                            'children': [{'name': 'Predict: 2.0'}]},
#                           {'name': 'Age > 1.3002576201665998',
#                            'children': [{'name': 'Age <= 1.3745580556046912',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'Age > 1.3745580556046912',
#                              'children': [{'name': 'Predict: 2.0'}]}]}]}]}]},
#                     {'name': 'HeartRate > 10.323449908097295',
#                      'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                        'children': [{'name': 'Age <= 1.671759797357057',
#                          'children': [{'name': 'BS <= 2.354861540166115',
#                            'children': [{'name': 'Predict: 0.0'}]},
#                           {'name': 'BS > 2.354861540166115',
#                            'children': [{'name': 'BS <= 2.385246850361807',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'BS > 2.385246850361807',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]},
#                         {'name': 'Age > 1.671759797357057',
#                          'children': [{'name': 'BS <= 2.2333202993833483',
#                            'children': [{'name': 'Predict: 0.0'}]},
#                           {'name': 'BS > 2.2333202993833483',
#                            'children': [{'name': 'SystolicBP <= 6.113947499310417',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'SystolicBP > 6.113947499310417',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                       {'name': 'BodyTemp > 71.42757148873099',
#                        'children': [{'name': 'Age <= 2.117562409985606',
#                          'children': [{'name': 'BS <= 2.2940909197747317',
#                            'children': [{'name': 'Predict: 0.0'}]},
#                           {'name': 'BS > 2.2940909197747317',
#                            'children': [{'name': 'Predict: 1.0'}]}]},
#                         {'name': 'Age > 2.117562409985606',
#                          'children': [{'name': 'Predict: 2.0'}]}]}]}]}]},
#                 {'name': 'SystolicBP > 6.76610189923686',
#                  'children': [{'name': 'HeartRate <= 9.657420881768438',
#                    'children': [{'name': 'BS <= 2.1117790586005807',
#                      'children': [{'name': 'BS <= 2.0510084382091973',
#                        'children': [{'name': 'Predict: 1.0'}]},
#                       {'name': 'BS > 2.0510084382091973',
#                        'children': [{'name': 'BS <= 2.081393748404889',
#                          'children': [{'name': 'Predict: 2.0'}]},
#                         {'name': 'BS > 2.081393748404889',
#                          'children': [{'name': 'Predict: 1.0'}]}]}]},
#                     {'name': 'BS > 2.1117790586005807',
#                      'children': [{'name': 'Predict: 2.0'}]}]},
#                   {'name': 'HeartRate > 9.657420881768438',
#                    'children': [{'name': 'Predict: 1.0'}]}]}]},
#               {'name': 'BS > 2.5827513666338042',
#                'children': [{'name': 'DiastolicBP <= 5.432629684974271',
#                  'children': [{'name': 'Age <= 2.9348671998046107',
#                    'children': [{'name': 'Predict: 2.0'}]},
#                   {'name': 'Age > 2.9348671998046107',
#                    'children': [{'name': 'Predict: 1.0'}]}]},
#                 {'name': 'DiastolicBP > 5.432629684974271',
#                  'children': [{'name': 'BS <= 3.4943106725045583',
#                    'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                      'children': [{'name': 'BodyTemp <= 73.827887027558',
#                        'children': [{'name': 'Predict: 1.0'}]},
#                       {'name': 'BodyTemp > 73.827887027558',
#                        'children': [{'name': 'Predict: 2.0'}]}]},
#                     {'name': 'DiastolicBP > 5.936317205435461',
#                      'children': [{'name': 'Predict: 1.0'}]}]},
#                   {'name': 'BS > 3.4943106725045583',
#                    'children': [{'name': 'SystolicBP <= 7.200871499187824',
#                      'children': [{'name': 'SystolicBP <= 6.76610189923686',
#                        'children': [{'name': 'DiastolicBP <= 6.260116325731941',
#                          'children': [{'name': 'Predict: 2.0'}]},
#                         {'name': 'DiastolicBP > 6.260116325731941',
#                          'children': [{'name': 'BS <= 5.013576182289149',
#                            'children': [{'name': 'Predict: 1.0'}]},
#                           {'name': 'BS > 5.013576182289149',
#                            'children': [{'name': 'Predict: 2.0'}]}]}]},
#                       {'name': 'SystolicBP > 6.76610189923686',
#                        'children': [{'name': 'Predict: 1.0'}]}]},
#                     {'name': 'SystolicBP > 7.200871499187824',
#                      'children': [{'name': 'Predict: 2.0'}]}]}]}]}]},
#             {'name': 'HeartRate > 11.18928764232481',
#              'children': [{'name': 'SystolicBP <= 6.76610189923686',
#                'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                  'children': [{'name': 'Age <= 2.117562409985606',
#                    'children': [{'name': 'BS <= 2.5827513666338042',
#                      'children': [{'name': 'BodyTemp <= 73.827887027558',
#                        'children': [{'name': 'HeartRate <= 11.588905058122126',
#                          'children': [{'name': 'SystolicBP <= 4.565080799485111',
#                            'children': [{'name': 'Predict: 2.0'}]},
#                           {'name': 'SystolicBP > 4.565080799485111',
#                            'children': [{'name': 'Age <= 1.3002576201665998',
#                              'children': [{'name': 'Predict: 2.0'}]},
#                             {'name': 'Age > 1.3002576201665998',
#                              'children': [{'name': 'Predict: 1.0'}]}]}]},
#                         {'name': 'HeartRate > 11.588905058122126',
#                          'children': [{'name': 'Predict: 0.0'}]}]},
#                       {'name': 'BodyTemp > 73.827887027558',
#                        'children': [{'name': 'BS <= 2.0510084382091973',
#                          'children': [{'name': 'Predict: 2.0'}]},
#                         {'name': 'BS > 2.0510084382091973',
#                          'children': [{'name': 'BS <= 2.2940909197747317',
#                            'children': [{'name': 'Predict: 0.0'}]},
#                           {'name': 'BS > 2.2940909197747317',
#                            'children': [{'name': 'BS <= 2.385246850361807',
#                              'children': [{'name': 'Predict: 2.0'}]},
#                             {'name': 'BS > 2.385246850361807',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]}]}]},
#                     {'name': 'BS > 2.5827513666338042',
#                      'children': [{'name': 'Predict: 1.0'}]}]},
#                   {'name': 'Age > 2.117562409985606',
#                    'children': [{'name': 'Predict: 2.0'}]}]},
#                 {'name': 'DiastolicBP > 5.936317205435461',
#                  'children': [{'name': 'DiastolicBP <= 6.260116325731941',
#                    'children': [{'name': 'Predict: 0.0'}]},
#                   {'name': 'DiastolicBP > 6.260116325731941',
#                    'children': [{'name': 'Age <= 1.5231589264808743',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'Age > 1.5231589264808743',
#                      'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#               {'name': 'SystolicBP > 6.76610189923686',
#                'children': [{'name': 'Predict: 2.0'}]}]}]},
#           {'name': 'DiastolicBP > 6.655870806094304',
#            'children': [{'name': 'SystolicBP <= 7.200871499187824',
#              'children': [{'name': 'HeartRate <= 8.858186050173808',
#                'children': [{'name': 'Age <= 2.117562409985606',
#                  'children': [{'name': 'Age <= 1.0773563138523257',
#                    'children': [{'name': 'BS <= 2.081393748404889',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'BS > 2.081393748404889',
#                      'children': [{'name': 'Predict: 0.0'}]}]},
#                   {'name': 'Age > 1.0773563138523257',
#                    'children': [{'name': 'Predict: 1.0'}]}]},
#                 {'name': 'Age > 2.117562409985606',
#                  'children': [{'name': 'Predict: 0.0'}]}]},
#               {'name': 'HeartRate > 8.858186050173808',
#                'children': [{'name': 'Predict: 2.0'}]}]},
#             {'name': 'SystolicBP > 7.200871499187824',
#              'children': [{'name': 'Predict: 2.0'},
#               {'name': 'Tree 3 (weight 1.0):'},
#               {'name': 'SystolicBP <= 7.200871499187824',
#                'children': [{'name': 'BS <= 2.5827513666338042',
#                  'children': [{'name': 'BodyTemp <= 72.37315033735982',
#                    'children': [{'name': 'SystolicBP <= 7.0378328992062125',
#                      'children': [{'name': 'SystolicBP <= 6.113947499310417',
#                        'children': [{'name': 'HeartRate <= 11.18928764232481',
#                          'children': [{'name': 'BS <= 2.1117790586005807',
#                            'children': [{'name': 'Age <= 1.0773563138523257',
#                              'children': [{'name': 'SystolicBP <= 5.2715813994054255',
#                                'children': [{'name': 'Predict: 0.0'}]},
#                               {'name': 'SystolicBP > 5.2715813994054255',
#                                'children': [{'name': 'Predict: 1.0'}]}]},
#                             {'name': 'Age > 1.0773563138523257',
#                              'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                                'children': [{'name': 'Predict: 0.0'}]},
#                               {'name': 'DiastolicBP > 4.425254644051889',
#                                'children': [{'name': 'BS <= 1.8838892321328924',
#                                  'children': [{'name': 'Predict: 0.0'}]},
#                                 {'name': 'BS > 1.8838892321328924',
#                                  'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                           {'name': 'BS > 2.1117790586005807',
#                            'children': [{'name': 'Predict: 0.0'}]}]},
#                         {'name': 'HeartRate > 11.18928764232481',
#                          'children': [{'name': 'DiastolicBP <= 6.260116325731941',
#                            'children': [{'name': 'BS <= 2.081393748404889',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'BS > 2.081393748404889',
#                              'children': [{'name': 'Age <= 1.5974593619189656',
#                                'children': [{'name': 'Predict: 1.0'}]},
#                               {'name': 'Age > 1.5974593619189656',
#                                'children': [{'name': 'Predict: 2.0'}]}]}]},
#                           {'name': 'DiastolicBP > 6.260116325731941',
#                            'children': [{'name': 'Predict: 1.0'}]}]}]},
#                       {'name': 'SystolicBP > 6.113947499310417',
#                        'children': [{'name': 'Age <= 1.5231589264808743',
#                          'children': [{'name': 'BS <= 2.1284909792082116',
#                            'children': [{'name': 'Age <= 1.151656749290417',
#                              'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                                'children': [{'name': 'Predict: 0.0'}]},
#                               {'name': 'DiastolicBP > 5.936317205435461',
#                                'children': [{'name': 'Predict: 1.0'}]}]},
#                             {'name': 'Age > 1.151656749290417',
#                              'children': [{'name': 'DiastolicBP <= 5.432629684974271',
#                                'children': [{'name': 'HeartRate <= 8.858186050173808',
#                                  'children': [{'name': 'Predict: 1.0'}]},
#                                 {'name': 'HeartRate > 8.858186050173808',
#                                  'children': [{'name': 'Predict: 0.0'}]}]},
#                               {'name': 'DiastolicBP > 5.432629684974271',
#                                'children': [{'name': 'Predict: 1.0'}]}]}]},
#                           {'name': 'BS > 2.1284909792082116',
#                            'children': [{'name': 'HeartRate <= 8.325362829110722',
#                              'children': [{'name': 'Age <= 1.0773563138523257',
#                                'children': [{'name': 'Predict: 0.0'}]},
#                               {'name': 'Age > 1.0773563138523257',
#                                'children': [{'name': 'BS <= 2.385246850361807',
#                                  'children': [{'name': 'Predict: 1.0'}]},
#                                 {'name': 'BS > 2.385246850361807',
#                                  'children': [{'name': 'Predict: 0.0'}]}]}]},
#                             {'name': 'HeartRate > 8.325362829110722',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]},
#                         {'name': 'Age > 1.5231589264808743',
#                          'children': [{'name': 'SystolicBP <= 6.385678499279768',
#                            'children': [{'name': 'Predict: 1.0'}]},
#                           {'name': 'SystolicBP > 6.385678499279768',
#                            'children': [{'name': 'BS <= 2.1284909792082116',
#                              'children': [{'name': 'Age <= 2.117562409985606',
#                                'children': [{'name': 'Predict: 0.0'}]},
#                               {'name': 'Age > 2.117562409985606',
#                                'children': [{'name': 'DiastolicBP <= 6.655870806094304',
#                                  'children': [{'name': 'Predict: 1.0'}]},
#                                 {'name': 'DiastolicBP > 6.655870806094304',
#                                  'children': [{'name': 'Predict: 0.0'}]}]}]},
#                             {'name': 'BS > 2.1284909792082116',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]}]}]},
#                     {'name': 'SystolicBP > 7.0378328992062125',
#                      'children': [{'name': 'Predict: 1.0'}]}]},
#                   {'name': 'BodyTemp > 72.37315033735982',
#                    'children': [{'name': 'BS <= 2.1117790586005807',
#                      'children': [{'name': 'BodyTemp <= 73.827887027558',
#                        'children': [{'name': 'SystolicBP <= 5.0270234994330085',
#                          'children': [{'name': 'Predict: 1.0'}]},
#                         {'name': 'SystolicBP > 5.0270234994330085',
#                          'children': [{'name': 'SystolicBP <= 6.113947499310417',
#                            'children': [{'name': 'BS <= 2.081393748404889',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'BS > 2.081393748404889',
#                              'children': [{'name': 'Predict: 2.0'}]}]},
#                           {'name': 'SystolicBP > 6.113947499310417',
#                            'children': [{'name': 'Predict: 1.0'}]}]}]},
#                       {'name': 'BodyTemp > 73.827887027558',
#                        'children': [{'name': 'HeartRate <= 10.190244102831524',
#                          'children': [{'name': 'SystolicBP <= 5.2715813994054255',
#                            'children': [{'name': 'Predict: 0.0'}]},
#                           {'name': 'SystolicBP > 5.2715813994054255',
#                            'children': [{'name': 'Age <= 1.3745580556046912',
#                              'children': [{'name': 'BS <= 2.0510084382091973',
#                                'children': [{'name': 'Predict: 1.0'}]},
#                               {'name': 'BS > 2.0510084382091973',
#                                'children': [{'name': 'BS <= 2.081393748404889',
#                                  'children': [{'name': 'Predict: 0.0'}]},
#                                 {'name': 'BS > 2.081393748404889',
#                                  'children': [{'name': 'Predict: 1.0'}]}]}]},
#                             {'name': 'Age > 1.3745580556046912',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]},
# ...
#                                                                                                            'children': [{'name': 'Age <= 1.3002576201665998',
#                                                                                                              'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                             {'name': 'Age > 1.3002576201665998',
#                                                                                                              'children': [{'name': 'Predict: 0.0'}]}]}]},
#                                                                                                         {'name': 'HeartRate > 9.657420881768438',
#                                                                                                          'children': [{'name': 'BS <= 2.0510084382091973',
#                                                                                                            'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                           {'name': 'BS > 2.0510084382091973',
#                                                                                                            'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                                                                                                              'children': [{'name': 'BS <= 2.081393748404889',
#                                                                                                                'children': [{'name': 'Predict: 0.0'}]},
#                                                                                                               {'name': 'BS > 2.081393748404889',
#                                                                                                                'children': [{'name': 'Predict: 1.0'}]}]},
#                                                                                                             {'name': 'DiastolicBP > 5.936317205435461',
#                                                                                                              'children': [{'name': 'Predict: 0.0'}]}]}]}]}]},
#                                                                                                     {'name': 'BodyTemp > 73.827887027558',
#                                                                                                      'children': [{'name': 'HeartRate <= 10.190244102831524',
#                                                                                                        'children': [{'name': 'BS <= 2.2940909197747317',
#                                                                                                          'children': [{'name': 'Age <= 1.0773563138523257',
#                                                                                                            'children': [{'name': 'HeartRate <= 8.325362829110722',
#                                                                                                              'children': [{'name': 'Predict: 0.0'}]},
#                                                                                                             {'name': 'HeartRate > 8.325362829110722',
#                                                                                                              'children': [{'name': 'Predict: 1.0'}]}]},
#                                                                                                           {'name': 'Age > 1.0773563138523257',
#                                                                                                            'children': [{'name': 'Age <= 1.3002576201665998',
#                                                                                                              'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                             {'name': 'Age > 1.3002576201665998',
#                                                                                                              'children': [{'name': 'Predict: 0.0'}]}]}]},
#                                                                                                         {'name': 'BS > 2.2940909197747317',
#                                                                                                          'children': [{'name': 'Age <= 1.3002576201665998',
#                                                                                                            'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                           {'name': 'Age > 1.3002576201665998',
#                                                                                                            'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                                                                       {'name': 'HeartRate > 10.190244102831524',
#                                                                                                        'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                                                                                                 {'name': 'BS > 2.5827513666338042',
#                                                                                                  'children': [{'name': 'HeartRate <= 10.789670226527495',
#                                                                                                    'children': [{'name': 'HeartRate <= 8.325362829110722',
#                                                                                                      'children': [{'name': 'BS <= 3.4943106725045583',
#                                                                                                        'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                       {'name': 'BS > 3.4943106725045583',
#                                                                                                        'children': [{'name': 'BS <= 5.013576182289149',
#                                                                                                          'children': [{'name': 'Age <= 3.306369376995068',
#                                                                                                            'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                           {'name': 'Age > 3.306369376995068',
#                                                                                                            'children': [{'name': 'Predict: 1.0'}]}]},
#                                                                                                         {'name': 'BS > 5.013576182289149',
#                                                                                                          'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                                                                                     {'name': 'HeartRate > 8.325362829110722',
#                                                                                                      'children': [{'name': 'Age <= 2.191862845423697',
#                                                                                                        'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                       {'name': 'Age > 2.191862845423697',
#                                                                                                        'children': [{'name': 'Age <= 2.3404637162998796',
#                                                                                                          'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                         {'name': 'Age > 2.3404637162998796',
#                                                                                                          'children': [{'name': 'HeartRate <= 10.190244102831524',
#                                                                                                            'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                           {'name': 'HeartRate > 10.190244102831524',
#                                                                                                            'children': [{'name': 'Age <= 2.9348671998046107',
#                                                                                                              'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                             {'name': 'Age > 2.9348671998046107',
#                                                                                                              'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]},
#                                                                                                   {'name': 'HeartRate > 10.789670226527495',
#                                                                                                    'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                                                                                                      'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                     {'name': 'BodyTemp > 71.42757148873099',
#                                                                                                      'children': [{'name': 'Age <= 2.117562409985606',
#                                                                                                        'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                       {'name': 'Age > 2.117562409985606',
#                                                                                                        'children': [{'name': 'Predict: 2.0'}]}]}]}]}]},
#                                                                                               {'name': 'SystolicBP > 7.0378328992062125',
#                                                                                                'children': [{'name': 'HeartRate <= 10.523258615995953',
#                                                                                                  'children': [{'name': 'HeartRate <= 10.323449908097295',
#                                                                                                    'children': [{'name': 'Age <= 4.123674166814074',
#                                                                                                      'children': [{'name': 'SystolicBP <= 7.200871499187824',
#                                                                                                        'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                       {'name': 'SystolicBP > 7.200871499187824',
#                                                                                                        'children': [{'name': 'HeartRate <= 9.657420881768438',
#                                                                                                          'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                                                                                                            'children': [{'name': 'BS <= 2.0510084382091973',
#                                                                                                              'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                             {'name': 'BS > 2.0510084382091973',
#                                                                                                              'children': [{'name': 'Predict: 2.0'}]}]},
#                                                                                                           {'name': 'DiastolicBP > 5.936317205435461',
#                                                                                                            'children': [{'name': 'Predict: 2.0'}]}]},
#                                                                                                         {'name': 'HeartRate > 9.657420881768438',
#                                                                                                          'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                                                                                     {'name': 'Age > 4.123674166814074',
#                                                                                                      'children': [{'name': 'Predict: 2.0'}]}]},
#                                                                                                   {'name': 'HeartRate > 10.323449908097295',
#                                                                                                    'children': [{'name': 'Predict: 1.0'}]}]},
#                                                                                                 {'name': 'HeartRate > 10.523258615995953',
#                                                                                                  'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                                                                             {'name': 'DiastolicBP > 6.655870806094304',
#                                                                                              'children': [{'name': 'HeartRate <= 8.325362829110722',
#                                                                                                'children': [{'name': 'Age <= 2.117562409985606',
#                                                                                                  'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                 {'name': 'Age > 2.117562409985606',
#                                                                                                  'children': [{'name': 'Predict: 2.0'}]}]},
#                                                                                               {'name': 'HeartRate > 8.325362829110722',
#                                                                                                'children': [{'name': 'SystolicBP <= 6.76610189923686',
#                                                                                                  'children': [{'name': 'Age <= 3.306369376995068',
#                                                                                                    'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                   {'name': 'Age > 3.306369376995068',
#                                                                                                    'children': [{'name': 'Predict: 0.0'}]}]},
#                                                                                                 {'name': 'SystolicBP > 6.76610189923686',
#                                                                                                  'children': [{'name': 'Predict: 2.0'}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}

# %%
# 8.1 Pattern3

# %%
# calculate performance accuracy on all the features
data_changed=data.select(data.columns[0:8])
data_changed = data_changed.drop('SystolicBP')
# collect the input features
assembler = VectorAssembler(
        inputCols=['Age','DiastolicBP','BS','BodyTemp','HeartRate'], outputCol="features")
# transform the data
data_changed=assembler.transform(data_changed)
# standardize the feature values
standardScaler=StandardScaler()
standardScaler.setInputCol('features')
model=standardScaler.fit(data_changed)
model.setOutputCol('features_scaled')
data_changed=model.transform(data_changed)

# %%
# calculate performance accuracy on all the features
data_changed=data.select(data.columns[0:8])
data_changed = data_changed.drop('SystolicBP')
# collect the input features
assembler = VectorAssembler(
        inputCols=['Age','DiastolicBP','BS','BodyTemp','HeartRate'], outputCol="features")
# transform the data
data_changed=assembler.transform(data_changed)
# standardize the feature values
standardScaler=StandardScaler()
standardScaler.setInputCol('features')
model=standardScaler.fit(data_changed)
model.setOutputCol('features_scaled')
data_changed=model.transform(data_changed)
# splitting data into training and test data set
train_data, test_data = data_changed.randomSplit(weights=[0.75,0.25], seed=1)
# definition to evaluate train accuracy, test accuracy
def testparams(**params):
    rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4, **params)
    model = rfc.fit(train_data)
    def model_score(evaluate_data):
        predictions=model.transform(evaluate_data)
        evaluator = MulticlassClassificationEvaluator(
            labelCol="RiskLevelIndex", predictionCol="prediction", metricName="accuracy")
        return evaluator.evaluate(predictions)
    return model_score(train_data), model_score(test_data)

# %%
# definition to evaluate train accuracy, test accuracy
def testparams(**params):
    rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4, **params)
    model = rfc.fit(train_data)
    def model_score(evaluate_data):
        predictions=model.transform(evaluate_data)
        evaluator = MulticlassClassificationEvaluator(
            labelCol="RiskLevelIndex", predictionCol="prediction", metricName="accuracy")
        return evaluator.evaluate(predictions)
    return model_score(train_data), model_score(test_data)

# %%
# testparams print train error (left), test error (right)
print('train error (left), test error (right)\n', testparams())
# fit model on train_data
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
model = rfc.fit(train_data)
# predict response
predictions = model.transform(test_data)
# Metrics
predictionRDD = predictions.select(['RiskLevelIndex', 'prediction']).rdd.map(lambda line: (line[1], line[0]))
metrics = MulticlassMetrics(predictionRDD)
# Confusion Matrix
print('\n Confusion Matrix \n', metrics.confusionMatrix().toArray())
# Out:
# train error (left), test error (right)
#  (0.747141041931385, 0.7288888888888889)
#
#  Confusion Matrix
#  [[71. 14.  1.]
#  [13. 62.  3.]
#  [ 1.  5. 55.]]

# %%
# 8.1 Pattern4

# %%
testparams(numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
# Out:
# (0.8856416772554002, 0.8355555555555556)

# %%
# 8.1 Pattern5

# %%
# rfc model
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)

# Evaluate model
evaluator = MulticlassClassificationEvaluator(
            labelCol="RiskLevelIndex", predictionCol="prediction", metricName="accuracy")

params_grid = ParamGridBuilder().build()

# create 10-fold cross validator with 10 repeats
accuracy=[]
for i in range(0,10):
    # shuffle data
    shuffledDF = data_changed.orderBy(rand())
    # split data into train and test data set
    train_data, test_data = shuffledDF.randomSplit(weights=[0.75,0.25], seed=1)
    # 10-fold CrossValidator
    rfcv = CrossValidator(estimator=rfc, estimatorParamMaps=params_grid, evaluator=evaluator, numFolds=10, seed=1)
    # run cross validations
    cvmodel = rfcv.fit(train_data)
    # model predictions
    predictions = cvmodel.transform(test_data)
    accuracy.append(evaluator.evaluate(predictions))
np.average(accuracy)
# Out:
# 0.8355555555555556

# %%
# 8.2

# %%
# 8.2.1

# %%
def parse_debug_string_lines(lines):
    
    block = []
    while lines:

        if lines[0].startswith('If'):
            bl = ' '.join(lines.pop(0).split()[1:]).replace('(', '').replace(')', '')
            block.append({'name': bl, 'children': parse_debug_string_lines(lines)})

            if lines[0].startswith('Else'):
                be = ' '.join(lines.pop(0).split()[1:]).replace('(', '').replace(')', '')
                block.append({'name': be, 'children': parse_debug_string_lines(lines)})
        elif not lines[0].startswith(('If', 'Else')):
            block2 = lines.pop(0)
            block.append({'name': block2})
        else:
            break
    
    return block

def debug_str_to_json(debug_string):
    data = []
    for line in debug_string.splitlines():
        if line.strip():
            line = line.strip()
            data.append(line)
        else:
            break
        if not line: break

    json = {'name': 'Root', 'children': parse_debug_string_lines(data[1:])}
    
    return json

# %%
# rfc model
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
# prepare data and model
pipeline = Pipeline(stages=[rfc])
model = pipeline.fit(data_changed)
tree_model_classifier = model.stages[0]

f_type_to_flist_dict = data_changed.schema['features'].metadata["ml_attr"]["attrs"]
f_index_to_name_dict = {}
for f_type, f_list in f_type_to_flist_dict.items():
   for f in f_list:
       f_index = f['idx']
       f_name = f['name']
       f_index_to_name_dict[f_index] = f_name

tree = tree_model_classifier.toDebugString
for i in range(len(f_index_to_name_dict)):
   tree = tree.replace('feature {}'.format(i), f_index_to_name_dict.get(i))

debug_str_to_json(tree)
# Out:
# {'name': 'Root',
#  'children': [{'name': 'Tree 0 (weight 1.0):'},
#   {'name': 'BS <= 2.5827513666338042',
#    'children': [{'name': 'DiastolicBP <= 7.015647606423727',
#      'children': [{'name': 'BodyTemp <= 72.37315033735982',
#        'children': [{'name': 'DiastolicBP <= 3.5617903232612766',
#          'children': [{'name': 'Predict: 0.0'}]},
#         {'name': 'DiastolicBP > 3.5617903232612766',
#          'children': [{'name': 'Age <= 1.0773563138523257',
#            'children': [{'name': 'BS <= 2.081393748404889',
#              'children': [{'name': 'Predict: 1.0'}]},
#             {'name': 'BS > 2.081393748404889',
#              'children': [{'name': 'Predict: 0.0'}]}]},
#           {'name': 'Age > 1.0773563138523257',
#            'children': [{'name': 'BS <= 2.1284909792082116',
#              'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                'children': [{'name': 'DiastolicBP <= 4.785031444381311',
#                  'children': [{'name': 'Age <= 1.3745580556046912',
#                    'children': [{'name': 'DiastolicBP <= 3.957544803623641',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'DiastolicBP > 3.957544803623641',
#                      'children': [{'name': 'Predict: 0.0'}]}]},
#                   {'name': 'Age > 1.3745580556046912',
#                    'children': [{'name': 'Predict: 0.0'}]}]},
#                 {'name': 'DiastolicBP > 4.785031444381311',
#                  'children': [{'name': 'HeartRate <= 10.323449908097295',
#                    'children': [{'name': 'Age <= 1.3745580556046912',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'Age > 1.3745580556046912',
#                      'children': [{'name': 'Predict: 1.0'}]}]},
#                   {'name': 'HeartRate > 10.323449908097295',
#                    'children': [{'name': 'BS <= 2.1117790586005807',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'BS > 2.1117790586005807',
#                      'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#               {'name': 'DiastolicBP > 5.936317205435461',
#                'children': [{'name': 'BS <= 2.0510084382091973',
#                  'children': [{'name': 'Predict: 0.0'}]},
#                 {'name': 'BS > 2.0510084382091973',
#                  'children': [{'name': 'Age <= 1.671759797357057',
#                    'children': [{'name': 'BS <= 2.081393748404889',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'BS > 2.081393748404889',
#                      'children': [{'name': 'Predict: 0.0'}]}]},
#                   {'name': 'Age > 1.671759797357057',
#                    'children': [{'name': 'Age <= 1.8203606682332398',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'Age > 1.8203606682332398',
#                      'children': [{'name': 'Predict: 0.0'}]}]}]}]}]},
#             {'name': 'BS > 2.1284909792082116',
#              'children': [{'name': 'BS <= 2.354861540166115',
#                'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                  'children': [{'name': 'Age <= 2.191862845423697',
#                    'children': [{'name': 'Age <= 2.117562409985606',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'Age > 2.117562409985606',
#                      'children': [{'name': 'Predict: 1.0'}]}]},
#                   {'name': 'Age > 2.191862845423697',
#                    'children': [{'name': 'Predict: 0.0'}]}]},
#                 {'name': 'DiastolicBP > 5.2167636047766175',
#                  'children': [{'name': 'HeartRate <= 9.657420881768438',
#                    'children': [{'name': 'Predict: 0.0'}]},
#                   {'name': 'HeartRate > 9.657420881768438',
#                    'children': [{'name': 'Age <= 1.5231589264808743',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'Age > 1.5231589264808743',
#                      'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#               {'name': 'BS > 2.354861540166115',
#                'children': [{'name': 'HeartRate <= 10.323449908097295',
#                  'children': [{'name': 'Age <= 1.8203606682332398',
#                    'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'DiastolicBP > 5.936317205435461',
#                      'children': [{'name': 'Predict: 1.0'}]}]},
#                   {'name': 'Age > 1.8203606682332398',
#                    'children': [{'name': 'Predict: 0.0'}]}]},
#                 {'name': 'HeartRate > 10.323449908097295',
#                  'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]},
#       {'name': 'BodyTemp > 72.37315033735982',
#        'children': [{'name': 'HeartRate <= 8.99139185543958',
#          'children': [{'name': 'BS <= 1.8838892321328924',
#            'children': [{'name': 'BodyTemp <= 74.55525537265709',
#              'children': [{'name': 'Predict: 0.0'}]},
#             {'name': 'BodyTemp > 74.55525537265709',
#              'children': [{'name': 'Predict: 2.0'}]}]},
#           {'name': 'BS > 1.8838892321328924',
#            'children': [{'name': 'BS <= 2.2940909197747317',
#              'children': [{'name': 'Age <= 1.0773563138523257',
#                'children': [{'name': 'Predict: 0.0'}]},
#               {'name': 'Age > 1.0773563138523257',
#                'children': [{'name': 'Predict: 2.0'}]}]},
#             {'name': 'BS > 2.2940909197747317',
#              'children': [{'name': 'Predict: 2.0'}]}]}]},
#         {'name': 'HeartRate > 8.99139185543958',
#          'children': [{'name': 'Age <= 1.3002576201665998',
#            'children': [{'name': 'HeartRate <= 10.789670226527495',
#              'children': [{'name': 'BS <= 2.1117790586005807',
#                'children': [{'name': 'Predict: 1.0'}]},
#               {'name': 'BS > 2.1117790586005807',
#                'children': [{'name': 'BS <= 2.2940909197747317',
#                  'children': [{'name': 'Age <= 1.0773563138523257',
#                    'children': [{'name': 'BS <= 2.1284909792082116',
#                      'children': [{'name': 'Predict: 2.0'}]},
#                     {'name': 'BS > 2.1284909792082116',
#                      'children': [{'name': 'Predict: 0.0'}]}]},
#                   {'name': 'Age > 1.0773563138523257',
#                    'children': [{'name': 'Predict: 0.0'}]}]},
#                 {'name': 'BS > 2.2940909197747317',
#                  'children': [{'name': 'Age <= 1.0773563138523257',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'Age > 1.0773563138523257',
#                    'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'DiastolicBP > 4.425254644051889',
#                      'children': [{'name': 'Predict: 2.0'}]}]}]}]}]},
#             {'name': 'HeartRate > 10.789670226527495',
#              'children': [{'name': 'BS <= 2.0510084382091973',
#                'children': [{'name': 'Predict: 2.0'}]},
#               {'name': 'BS > 2.0510084382091973',
#                'children': [{'name': 'BodyTemp <= 73.827887027558',
#                  'children': [{'name': 'Predict: 2.0'}]},
#                 {'name': 'BodyTemp > 73.827887027558',
#                  'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#           {'name': 'Age > 1.3002576201665998',
#            'children': [{'name': 'BS <= 2.1436836343060572',
#              'children': [{'name': 'Age <= 1.3745580556046912',
#                'children': [{'name': 'BS <= 2.081393748404889',
#                  'children': [{'name': 'Predict: 0.0'}]},
#                 {'name': 'BS > 2.081393748404889',
#                  'children': [{'name': 'Predict: 1.0'}]}]},
#               {'name': 'Age > 1.3745580556046912',
#                'children': [{'name': 'BodyTemp <= 74.55525537265709',
#                  'children': [{'name': 'BodyTemp <= 73.827887027558',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'BodyTemp > 73.827887027558',
#                    'children': [{'name': 'Age <= 2.117562409985606',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'Age > 2.117562409985606',
#                      'children': [{'name': 'Predict: 0.0'}]}]}]},
#                 {'name': 'BodyTemp > 74.55525537265709',
#                  'children': [{'name': 'Predict: 0.0'}]}]}]},
#             {'name': 'BS > 2.1436836343060572',
#              'children': [{'name': 'Age <= 2.117562409985606',
#                'children': [{'name': 'Age <= 1.3745580556046912',
#                  'children': [{'name': 'Predict: 1.0'}]},
#                 {'name': 'Age > 1.3745580556046912',
#                  'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                    'children': [{'name': 'BS <= 2.385246850361807',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'BS > 2.385246850361807',
#                      'children': [{'name': 'Predict: 2.0'}]}]},
#                   {'name': 'DiastolicBP > 4.425254644051889',
#                    'children': [{'name': 'Predict: 0.0'}]}]}]},
#               {'name': 'Age > 2.117562409985606',
#                'children': [{'name': 'BS <= 2.2940909197747317',
#                  'children': [{'name': 'BS <= 2.2333202993833483',
#                    'children': [{'name': 'Predict: 2.0'}]},
#                   {'name': 'BS > 2.2333202993833483',
#                    'children': [{'name': 'Predict: 1.0'}]}]},
#                 {'name': 'BS > 2.2940909197747317',
#                  'children': [{'name': 'Predict: 2.0'}]}]}]}]}]}]}]},
#     {'name': 'DiastolicBP > 7.015647606423727',
#      'children': [{'name': 'HeartRate <= 8.325362829110722',
#        'children': [{'name': 'Predict: 1.0'}]},
#       {'name': 'HeartRate > 8.325362829110722',
#        'children': [{'name': 'Predict: 2.0'}]}]}]},
#   {'name': 'BS > 2.5827513666338042',
#    'children': [{'name': 'DiastolicBP <= 6.260116325731941',
#      'children': [{'name': 'BodyTemp <= 73.827887027558',
#        'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#          'children': [{'name': 'HeartRate <= 8.99139185543958',
#            'children': [{'name': 'Predict: 1.0'}]},
#           {'name': 'HeartRate > 8.99139185543958',
#            'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#              'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                'children': [{'name': 'Predict: 2.0'}]},
#               {'name': 'BodyTemp > 71.42757148873099',
#                'children': [{'name': 'Age <= 1.3002576201665998',
#                  'children': [{'name': 'Predict: 2.0'}]},
#                 {'name': 'Age > 1.3002576201665998',
#                  'children': [{'name': 'Predict: 1.0'}]}]}]},
#             {'name': 'DiastolicBP > 4.425254644051889',
#              'children': [{'name': 'BS <= 5.013576182289149',
#                'children': [{'name': 'Predict: 2.0'}]},
#               {'name': 'BS > 5.013576182289149',
#                'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#         {'name': 'DiastolicBP > 5.936317205435461',
#          'children': [{'name': 'Age <= 1.5231589264808743',
#            'children': [{'name': 'Predict: 1.0'}]},
#           {'name': 'Age > 1.5231589264808743',
#            'children': [{'name': 'Age <= 3.306369376995068',
#              'children': [{'name': 'Predict: 2.0'}]},
#             {'name': 'Age > 3.306369376995068',
#              'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#       {'name': 'BodyTemp > 73.827887027558',
#        'children': [{'name': 'Age <= 2.9348671998046107',
#          'children': [{'name': 'Age <= 1.3002576201665998',
#            'children': [{'name': 'Age <= 1.0773563138523257',
#              'children': [{'name': 'Predict: 2.0'}]},
#             {'name': 'Age > 1.0773563138523257',
#              'children': [{'name': 'Predict: 1.0'}]}]},
#           {'name': 'Age > 1.3002576201665998',
#            'children': [{'name': 'Predict: 2.0'}]}]},
#         {'name': 'Age > 2.9348671998046107',
#          'children': [{'name': 'Predict: 1.0'}]}]}]},
#     {'name': 'DiastolicBP > 6.260116325731941',
#      'children': [{'name': 'HeartRate <= 10.057038297565752',
#        'children': [{'name': 'HeartRate <= 9.657420881768438',
#          'children': [{'name': 'DiastolicBP <= 6.655870806094304',
#            'children': [{'name': 'Age <= 3.306369376995068',
#              'children': [{'name': 'Predict: 2.0'}]},
#             {'name': 'Age > 3.306369376995068',
#              'children': [{'name': 'BS <= 4.2539434273968535',
#                'children': [{'name': 'Predict: 1.0'}]},
#               {'name': 'BS > 4.2539434273968535',
#                'children': [{'name': 'Predict: 2.0'}]}]}]},
#           {'name': 'DiastolicBP > 6.655870806094304',
#            'children': [{'name': 'Predict: 2.0'}]}]},
#         {'name': 'HeartRate > 9.657420881768438',
#          'children': [{'name': 'Predict: 2.0'}]}]},
#       {'name': 'HeartRate > 10.057038297565752',
#        'children': [{'name': 'HeartRate <= 10.789670226527495',
#          'children': [{'name': 'BS <= 3.4943106725045583',
#            'children': [{'name': 'Predict: 2.0'}]},
#           {'name': 'BS > 3.4943106725045583',
#            'children': [{'name': 'HeartRate <= 10.323449908097295',
#              'children': [{'name': 'Predict: 2.0'}]},
#             {'name': 'HeartRate > 10.323449908097295',
#              'children': [{'name': 'BS <= 4.2539434273968535',
#                'children': [{'name': 'Predict: 2.0'}]},
#               {'name': 'BS > 4.2539434273968535',
#                'children': [{'name': 'Age <= 2.117562409985606',
#                  'children': [{'name': 'Predict: 2.0'}]},
#                 {'name': 'Age > 2.117562409985606',
#                  'children': [{'name': 'Predict: 1.0'}]}]}]}]}]},
#         {'name': 'HeartRate > 10.789670226527495',
#          'children': [{'name': 'Predict: 2.0'},
#           {'name': 'Tree 1 (weight 1.0):'},
#           {'name': 'DiastolicBP <= 6.655870806094304',
#            'children': [{'name': 'BS <= 2.5827513666338042',
#              'children': [{'name': 'BS <= 2.1436836343060572',
#                'children': [{'name': 'DiastolicBP <= 3.5617903232612766',
#                  'children': [{'name': 'Predict: 0.0'}]},
#                 {'name': 'DiastolicBP > 3.5617903232612766',
#                  'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                    'children': [{'name': 'BodyTemp <= 71.64578199226071',
#                      'children': [{'name': 'HeartRate <= 10.523258615995953',
#                        'children': [{'name': 'DiastolicBP <= 4.92894216451308',
#                          'children': [{'name': 'HeartRate <= 8.325362829110722',
#                            'children': [{'name': 'Predict: 0.0'}]},
#                           {'name': 'HeartRate > 8.325362829110722',
#                            'children': [{'name': 'Age <= 1.3745580556046912',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'Age > 1.3745580556046912',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]},
#                         {'name': 'DiastolicBP > 4.92894216451308',
#                          'children': [{'name': 'Age <= 1.3745580556046912',
#                            'children': [{'name': 'Predict: 0.0'}]},
#                           {'name': 'Age > 1.3745580556046912',
#                            'children': [{'name': 'BS <= 1.8838892321328924',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'BS > 1.8838892321328924',
#                              'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                       {'name': 'HeartRate > 10.523258615995953',
#                        'children': [{'name': 'Age <= 1.151656749290417',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'Age > 1.151656749290417',
#                          'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                            'children': [{'name': 'HeartRate <= 11.18928764232481',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'HeartRate > 11.18928764232481',
#                              'children': [{'name': 'Predict: 1.0'}]}]},
#                           {'name': 'DiastolicBP > 4.425254644051889',
#                            'children': [{'name': 'BS <= 2.0510084382091973',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'BS > 2.0510084382091973',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]}]}]},
#                     {'name': 'BodyTemp > 71.64578199226071',
#                      'children': [{'name': 'Age <= 2.563365022614154',
#                        'children': [{'name': 'BodyTemp <= 73.827887027558',
#                          'children': [{'name': 'DiastolicBP <= 4.785031444381311',
#                            'children': [{'name': 'Predict: 1.0'}]},
#                           {'name': 'DiastolicBP > 4.785031444381311',
#                            'children': [{'name': 'BS <= 2.081393748404889',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'BS > 2.081393748404889',
#                              'children': [{'name': 'Predict: 1.0'}]}]}]},
#                         {'name': 'BodyTemp > 73.827887027558',
#                          'children': [{'name': 'DiastolicBP <= 4.785031444381311',
#                            'children': [{'name': 'Age <= 1.0773563138523257',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'Age > 1.0773563138523257',
#                              'children': [{'name': 'Predict: 2.0'}]}]},
#                           {'name': 'DiastolicBP > 4.785031444381311',
#                            'children': [{'name': 'BS <= 2.1117790586005807',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'BS > 2.1117790586005807',
#                              'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#                       {'name': 'Age > 2.563365022614154',
#                        'children': [{'name': 'BodyTemp <= 73.827887027558',
#                          'children': [{'name': 'Predict: 1.0'}]},
#                         {'name': 'BodyTemp > 73.827887027558',
#                          'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                   {'name': 'DiastolicBP > 5.936317205435461',
#                    'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                      'children': [{'name': 'BS <= 2.0510084382091973',
#                        'children': [{'name': 'Predict: 0.0'}]},
#                       {'name': 'BS > 2.0510084382091973',
#                        'children': [{'name': 'DiastolicBP <= 6.440004725896651',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'DiastolicBP > 6.440004725896651',
#                          'children': [{'name': 'HeartRate <= 8.858186050173808',
#                            'children': [{'name': 'Predict: 1.0'}]},
#                           {'name': 'HeartRate > 8.858186050173808',
#                            'children': [{'name': 'BS <= 2.081393748404889',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'BS > 2.081393748404889',
#                              'children': [{'name': 'Predict: 1.0'}]}]}]}]}]},
#                     {'name': 'BodyTemp > 71.42757148873099',
#                      'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#               {'name': 'BS > 2.1436836343060572',
#                'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                  'children': [{'name': 'HeartRate <= 10.323449908097295',
#                    'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'DiastolicBP > 4.425254644051889',
#                      'children': [{'name': 'HeartRate <= 9.657420881768438',
#                        'children': [{'name': 'BS <= 2.354861540166115',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'BS > 2.354861540166115',
#                          'children': [{'name': 'HeartRate <= 8.858186050173808',
#                            'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'DiastolicBP > 5.2167636047766175',
#                              'children': [{'name': 'Predict: 1.0'}]}]},
#                           {'name': 'HeartRate > 8.858186050173808',
#                            'children': [{'name': 'Predict: 0.0'}]}]}]},
#                       {'name': 'HeartRate > 9.657420881768438',
#                        'children': [{'name': 'Predict: 0.0'}]}]}]},
#                   {'name': 'HeartRate > 10.323449908097295',
#                    'children': [{'name': 'Age <= 2.117562409985606',
#                      'children': [{'name': 'HeartRate <= 10.789670226527495',
#                        'children': [{'name': 'Predict: 0.0'}]},
#                       {'name': 'HeartRate > 10.789670226527495',
#                        'children': [{'name': 'HeartRate <= 11.18928764232481',
#                          'children': [{'name': 'BS <= 2.2940909197747317',
#                            'children': [{'name': 'Predict: 0.0'}]},
#                           {'name': 'BS > 2.2940909197747317',
#                            'children': [{'name': 'Predict: 1.0'}]}]},
#                         {'name': 'HeartRate > 11.18928764232481',
#                          'children': [{'name': 'Predict: 0.0'}]}]}]},
#                     {'name': 'Age > 2.117562409985606',
#                      'children': [{'name': 'Age <= 2.191862845423697',
#                        'children': [{'name': 'Predict: 1.0'}]},
#                       {'name': 'Age > 2.191862845423697',
#                        'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                          'children': [{'name': 'Predict: 1.0'}]},
#                         {'name': 'DiastolicBP > 5.2167636047766175',
#                          'children': [{'name': 'Predict: 0.0'}]}]}]}]}]},
#                 {'name': 'BodyTemp > 71.42757148873099',
#                  'children': [{'name': 'BS <= 2.2940909197747317',
#                    'children': [{'name': 'BS <= 2.2333202993833483',
#                      'children': [{'name': 'Predict: 2.0'}]},
#                     {'name': 'BS > 2.2333202993833483',
#                      'children': [{'name': 'Age <= 1.3002576201665998',
#                        'children': [{'name': 'Predict: 0.0'}]},
#                       {'name': 'Age > 1.3002576201665998',
#                        'children': [{'name': 'BodyTemp <= 73.827887027558',
#                          'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                            'children': [{'name': 'HeartRate <= 9.657420881768438',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'HeartRate > 9.657420881768438',
#                              'children': [{'name': 'Predict: 1.0'}]}]},
#                           {'name': 'DiastolicBP > 5.936317205435461',
#                            'children': [{'name': 'Predict: 0.0'}]}]},
#                         {'name': 'BodyTemp > 73.827887027558',
#                          'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#                   {'name': 'BS > 2.2940909197747317',
#                    'children': [{'name': 'HeartRate <= 9.657420881768438',
#                      'children': [{'name': 'Predict: 2.0'}]},
#                     {'name': 'HeartRate > 9.657420881768438',
#                      'children': [{'name': 'HeartRate <= 10.789670226527495',
#                        'children': [{'name': 'DiastolicBP <= 4.785031444381311',
#                          'children': [{'name': 'Predict: 1.0'}]},
#                         {'name': 'DiastolicBP > 4.785031444381311',
#                          'children': [{'name': 'BodyTemp <= 73.1005186824589',
#                            'children': [{'name': 'Predict: 2.0'}]},
#                           {'name': 'BodyTemp > 73.1005186824589',
#                            'children': [{'name': 'Predict: 1.0'}]}]}]},
#                       {'name': 'HeartRate > 10.789670226527495',
#                        'children': [{'name': 'Age <= 1.3002576201665998',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'Age > 1.3002576201665998',
#                          'children': [{'name': 'Age <= 2.117562409985606',
#                            'children': [{'name': 'Predict: 1.0'}]},
#                           {'name': 'Age > 2.117562409985606',
#                            'children': [{'name': 'Predict: 2.0'}]}]}]}]}]}]}]}]},
#             {'name': 'BS > 2.5827513666338042',
#              'children': [{'name': 'HeartRate <= 9.657420881768438',
#                'children': [{'name': 'HeartRate <= 8.858186050173808',
#                  'children': [{'name': 'Age <= 1.5231589264808743',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'Age > 1.5231589264808743',
#                    'children': [{'name': 'HeartRate <= 8.325362829110722',
#                      'children': [{'name': 'BS <= 5.013576182289149',
#                        'children': [{'name': 'Age <= 3.306369376995068',
#                          'children': [{'name': 'Predict: 2.0'}]},
#                         {'name': 'Age > 3.306369376995068',
#                          'children': [{'name': 'Predict: 1.0'}]}]},
#                       {'name': 'BS > 5.013576182289149',
#                        'children': [{'name': 'Predict: 2.0'}]}]},
#                     {'name': 'HeartRate > 8.325362829110722',
#                      'children': [{'name': 'Predict: 2.0'}]}]}]},
#                 {'name': 'HeartRate > 8.858186050173808',
#                  'children': [{'name': 'HeartRate <= 8.99139185543958',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'HeartRate > 8.99139185543958',
#                    'children': [{'name': 'Age <= 2.9348671998046107',
#                      'children': [{'name': 'Predict: 2.0'}]},
#                     {'name': 'Age > 2.9348671998046107',
#                      'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                        'children': [{'name': 'Predict: 2.0'}]},
#                       {'name': 'DiastolicBP > 5.936317205435461',
#                        'children': [{'name': 'BS <= 4.2539434273968535',
#                          'children': [{'name': 'Predict: 1.0'}]},
#                         {'name': 'BS > 4.2539434273968535',
#                          'children': [{'name': 'Predict: 2.0'}]}]}]}]}]}]},
#               {'name': 'HeartRate > 9.657420881768438',
#                'children': [{'name': 'BS <= 3.4943106725045583',
#                  'children': [{'name': 'Age <= 2.117562409985606',
#                    'children': [{'name': 'HeartRate <= 10.789670226527495',
#                      'children': [{'name': 'Predict: 2.0'}]},
#                     {'name': 'HeartRate > 10.789670226527495',
#                      'children': [{'name': 'Predict: 1.0'}]}]},
#                   {'name': 'Age > 2.117562409985606',
#                    'children': [{'name': 'HeartRate <= 10.190244102831524',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'HeartRate > 10.190244102831524',
#                      'children': [{'name': 'Predict: 2.0'}]}]}]},
#                 {'name': 'BS > 3.4943106725045583',
#                  'children': [{'name': 'HeartRate <= 10.789670226527495',
#                    'children': [{'name': 'BS <= 4.2539434273968535',
#                      'children': [{'name': 'Predict: 2.0'}]},
#                     {'name': 'BS > 4.2539434273968535',
#                      'children': [{'name': 'Age <= 2.9348671998046107',
#                        'children': [{'name': 'Predict: 2.0'}]},
#                       {'name': 'Age > 2.9348671998046107',
#                        'children': [{'name': 'Age <= 3.306369376995068',
#                          'children': [{'name': 'HeartRate <= 10.190244102831524',
#                            'children': [{'name': 'Predict: 2.0'}]},
#                           {'name': 'HeartRate > 10.190244102831524',
#                            'children': [{'name': 'Predict: 1.0'}]}]},
#                         {'name': 'Age > 3.306369376995068',
#                          'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#                   {'name': 'HeartRate > 10.789670226527495',
#                    'children': [{'name': 'Predict: 2.0'}]}]}]}]}]},
#           {'name': 'DiastolicBP > 6.655870806094304',
#            'children': [{'name': 'BS <= 1.8838892321328924',
#              'children': [{'name': 'Predict: 0.0'}]},
#             {'name': 'BS > 1.8838892321328924',
#              'children': [{'name': 'Age <= 1.0773563138523257',
#                'children': [{'name': 'Predict: 0.0'}]},
#               {'name': 'Age > 1.0773563138523257',
#                'children': [{'name': 'HeartRate <= 10.057038297565752',
#                  'children': [{'name': 'HeartRate <= 9.657420881768438',
#                    'children': [{'name': 'DiastolicBP <= 7.015647606423727',
#                      'children': [{'name': 'Age <= 3.6778715541855256',
#                        'children': [{'name': 'HeartRate <= 8.858186050173808',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'HeartRate > 8.858186050173808',
#                          'children': [{'name': 'Predict: 2.0'}]}]},
#                       {'name': 'Age > 3.6778715541855256',
#                        'children': [{'name': 'Predict: 2.0'}]}]},
#                     {'name': 'DiastolicBP > 7.015647606423727',
#                      'children': [{'name': 'HeartRate <= 8.325362829110722',
#                        'children': [{'name': 'Predict: 1.0'}]},
#                       {'name': 'HeartRate > 8.325362829110722',
#                        'children': [{'name': 'Predict: 2.0'}]}]}]},
#                   {'name': 'HeartRate > 9.657420881768438',
#                    'children': [{'name': 'Predict: 1.0'}]}]},
#                 {'name': 'HeartRate > 10.057038297565752',
#                  'children': [{'name': 'Predict: 2.0'},
#                   {'name': 'Tree 2 (weight 1.0):'},
#                   {'name': 'BS <= 2.5827513666338042',
#                    'children': [{'name': 'BS <= 2.1436836343060572',
#                      'children': [{'name': 'DiastolicBP <= 7.015647606423727',
#                        'children': [{'name': 'BodyTemp <= 72.37315033735982',
#                          'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                            'children': [{'name': 'HeartRate <= 10.190244102831524',
#                              'children': [{'name': 'Age <= 1.151656749290417',
#                                'children': [{'name': 'Predict: 1.0'}]},
#                               {'name': 'Age > 1.151656749290417',
#                                'children': [{'name': 'HeartRate <= 9.657420881768438',
#                                  'children': [{'name': 'Predict: 0.0'}]},
#                                 {'name': 'HeartRate > 9.657420881768438',
#                                  'children': [{'name': 'Age <= 1.671759797357057',
#                                    'children': [{'name': 'Predict: 1.0'}]},
#                                   {'name': 'Age > 1.671759797357057',
#                                    'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                             {'name': 'HeartRate > 10.190244102831524',
#                              'children': [{'name': 'HeartRate <= 11.18928764232481',
#                                'children': [{'name': 'Age <= 1.151656749290417',
#                                  'children': [{'name': 'Predict: 0.0'}]},
#                                 {'name': 'Age > 1.151656749290417',
#                                  'children': [{'name': 'HeartRate <= 10.323449908097295',
#                                    'children': [{'name': 'Predict: 1.0'}]},
#                                   {'name': 'HeartRate > 10.323449908097295',
#                                    'children': [{'name': 'Predict: 0.0'}]}]}]},
#                               {'name': 'HeartRate > 11.18928764232481',
#                                'children': [{'name': 'Predict: 1.0'}]}]}]},
#                           {'name': 'DiastolicBP > 4.425254644051889',
#                            'children': [{'name': 'BS <= 1.8838892321328924',
#                              'children': [{'name': 'HeartRate <= 10.057038297565752',
#                                'children': [{'name': 'Predict: 0.0'}]},
#                               {'name': 'HeartRate > 10.057038297565752',
#                                'children': [{'name': 'Age <= 2.117562409985606',
#                                  'children': [{'name': 'Predict: 0.0'}]},
#                                 {'name': 'Age > 2.117562409985606',
#                                  'children': [{'name': 'Predict: 1.0'}]}]}]},
#                             {'name': 'BS > 1.8838892321328924',
#                              'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                                'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                                  'children': [{'name': 'Age <= 1.151656749290417',
#                                    'children': [{'name': 'Predict: 0.0'}]},
#                                   {'name': 'Age > 1.151656749290417',
#                                    'children': [{'name': 'Predict: 1.0'}]}]},
#                                 {'name': 'BodyTemp > 71.42757148873099',
#                                  'children': [{'name': 'Predict: 0.0'}]}]},
#                               {'name': 'DiastolicBP > 5.936317205435461',
#                                'children': [{'name': 'DiastolicBP <= 6.260116325731941',
#                                  'children': [{'name': 'Age <= 1.5974593619189656',
#                                    'children': [{'name': 'Predict: 0.0'}]},
#                                   {'name': 'Age > 1.5974593619189656',
#                                    'children': [{'name': 'BS <= 2.1117790586005807',
#                                      'children': [{'name': 'Predict: 0.0'}]},
#                                     {'name': 'BS > 2.1117790586005807',
#                                      'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                 {'name': 'DiastolicBP > 6.260116325731941',
#                                  'children': [{'name': 'HeartRate <= 8.858186050173808',
#                                    'children': [{'name': 'BS <= 2.081393748404889',
#                                      'children': [{'name': 'Predict: 1.0'}]},
#                                     {'name': 'BS > 2.081393748404889',
#                                      'children': [{'name': 'Predict: 0.0'}]}]},
#                                   {'name': 'HeartRate > 8.858186050173808',
#                                    'children': [{'name': 'BS <= 2.081393748404889',
#                                      'children': [{'name': 'Predict: 0.0'}]},
#                                     {'name': 'BS > 2.081393748404889',
#                                      'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]}]},
#                         {'name': 'BodyTemp > 72.37315033735982',
#                          'children': [{'name': 'HeartRate <= 8.99139185543958',
#                            'children': [{'name': 'BodyTemp <= 74.55525537265709',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'BodyTemp > 74.55525537265709',
#                              'children': [{'name': 'Predict: 2.0'}]}]},
#                           {'name': 'HeartRate > 8.99139185543958',
#                            'children': [{'name': 'BodyTemp <= 73.827887027558',
#                              'children': [{'name': 'DiastolicBP <= 5.432629684974271',
#                                'children': [{'name': 'BS <= 2.1117790586005807',
#                                  'children': [{'name': 'Predict: 1.0'}]},
#                                 {'name': 'BS > 2.1117790586005807',
#                                  'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                                    'children': [{'name': 'Predict: 1.0'}]},
#                                   {'name': 'DiastolicBP > 4.425254644051889',
#                                    'children': [{'name': 'Age <= 1.0773563138523257',
#                                      'children': [{'name': 'Predict: 2.0'}]},
#                                     {'name': 'Age > 1.0773563138523257',
#                                      'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                               {'name': 'DiastolicBP > 5.432629684974271',
#                                'children': [{'name': 'Age <= 2.117562409985606',
#                                  'children': [{'name': 'Predict: 1.0'}]},
#                                 {'name': 'Age > 2.117562409985606',
#                                  'children': [{'name': 'BS <= 2.081393748404889',
#                                    'children': [{'name': 'BodyTemp <= 73.1005186824589',
#                                      'children': [{'name': 'Predict: 1.0'}]},
#                                     {'name': 'BodyTemp > 73.1005186824589',
#                                      'children': [{'name': 'Predict: 0.0'}]}]},
#                                   {'name': 'BS > 2.081393748404889',
#                                    'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                             {'name': 'BodyTemp > 73.827887027558',
#                              'children': [{'name': 'HeartRate <= 10.789670226527495',
#                                'children': [{'name': 'Age <= 2.117562409985606',
#                                  'children': [{'name': 'BS <= 2.1117790586005807',
#                                    'children': [{'name': 'Predict: 1.0'}]},
#                                   {'name': 'BS > 2.1117790586005807',
#                                    'children': [{'name': 'Predict: 2.0'}]}]},
#                                 {'name': 'Age > 2.117562409985606',
#                                  'children': [{'name': 'Predict: 0.0'}]}]},
#                               {'name': 'HeartRate > 10.789670226527495',
#                                'children': [{'name': 'Predict: 2.0'}]}]}]}]}]},
#                       {'name': 'DiastolicBP > 7.015647606423727',
#                        'children': [{'name': 'Predict: 2.0'}]}]},
#                     {'name': 'BS > 2.1436836343060572',
#                      'children': [{'name': 'BS <= 2.354861540166115',
#                        'children': [{'name': 'HeartRate <= 10.323449908097295',
#                          'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                            'children': [{'name': 'DiastolicBP <= 7.015647606423727',
#                              'children': [{'name': 'Age <= 1.8203606682332398',
#                                'children': [{'name': 'DiastolicBP <= 5.612518085138982',
#                                  'children': [{'name': 'Age <= 1.5974593619189656',
#                                    'children': [{'name': 'Predict: 0.0'}]},
#                                   {'name': 'Age > 1.5974593619189656',
#                                    'children': [{'name': 'Age <= 1.671759797357057',
#                                      'children': [{'name': 'Predict: 1.0'}]},
#                                     {'name': 'Age > 1.671759797357057',
#                                      'children': [{'name': 'Predict: 0.0'}]}]}]},
#                                 {'name': 'DiastolicBP > 5.612518085138982',
#                                  'children': [{'name': 'Age <= 1.151656749290417',
#                                    'children': [{'name': 'BS <= 2.2940909197747317',
#                                      'children': [{'name': 'Predict: 1.0'}]},
#                                     {'name': 'BS > 2.2940909197747317',
#                                      'children': [{'name': 'Predict: 0.0'}]}]},
#                                   {'name': 'Age > 1.151656749290417',
#                                    'children': [{'name': 'Predict: 0.0'}]}]}]},
#                               {'name': 'Age > 1.8203606682332398',
#                                'children': [{'name': 'Predict: 0.0'}]}]},
#                             {'name': 'DiastolicBP > 7.015647606423727',
#                              'children': [{'name': 'Predict: 2.0'}]}]},
#                           {'name': 'BodyTemp > 71.42757148873099',
#                            'children': [{'name': 'Age <= 1.5231589264808743',
#                              'children': [{'name': 'BS <= 2.2940909197747317',
#                                'children': [{'name': 'Predict: 0.0'}]},
#                               {'name': 'BS > 2.2940909197747317',
#                                'children': [{'name': 'Predict: 2.0'}]}]},
#                             {'name': 'Age > 1.5231589264808743',
#                              'children': [{'name': 'Age <= 2.191862845423697',
#                                'children': [{'name': 'Predict: 2.0'}]},
#                               {'name': 'Age > 2.191862845423697',
#                                'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                         {'name': 'HeartRate > 10.323449908097295',
#                          'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                            'children': [{'name': 'Age <= 1.5231589264808743',
#                              'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                                'children': [{'name': 'Age <= 1.3002576201665998',
#                                  'children': [{'name': 'BodyTemp <= 73.827887027558',
#                                    'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                                      'children': [{'name': 'Predict: 0.0'}]},
#                                     {'name': 'BodyTemp > 71.42757148873099',
#                                      'children': [{'name': 'Predict: 2.0'}]}]},
#                                   {'name': 'BodyTemp > 73.827887027558',
#                                    'children': [{'name': 'Predict: 0.0'}]}]},
#                                 {'name': 'Age > 1.3002576201665998',
#                                  'children': [{'name': 'Predict: 1.0'}]}]},
#                               {'name': 'DiastolicBP > 4.425254644051889',
#                                'children': [{'name': 'Predict: 0.0'}]}]},
#                             {'name': 'Age > 1.5231589264808743',
#                              'children': [{'name': 'Predict: 1.0'}]}]},
#                           {'name': 'DiastolicBP > 5.2167636047766175',
#                            'children': [{'name': 'Predict: 0.0'}]}]}]},
#                       {'name': 'BS > 2.354861540166115',
#                        'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                          'children': [{'name': 'HeartRate <= 10.323449908097295',
#                            'children': [{'name': 'DiastolicBP <= 7.015647606423727',
#                              'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                                'children': [{'name': 'Age <= 1.8203606682332398',
#                                  'children': [{'name': 'Predict: 0.0'}]},
#                                 {'name': 'Age > 1.8203606682332398',
#                                  'children': [{'name': 'DiastolicBP <= 4.785031444381311',
#                                    'children': [{'name': 'Age <= 2.3404637162998796',
#                                      'children': [{'name': 'Predict: 1.0'}]},
#                                     {'name': 'Age > 2.3404637162998796',
#                                      'children': [{'name': 'Predict: 0.0'}]}]},
#                                   {'name': 'DiastolicBP > 4.785031444381311',
#                                    'children': [{'name': 'Predict: 0.0'}]}]}]},
#                               {'name': 'DiastolicBP > 5.2167636047766175',
#                                'children': [{'name': 'BS <= 2.385246850361807',
#                                  'children': [{'name': 'Age <= 2.563365022614154',
#                                    'children': [{'name': 'HeartRate <= 8.325362829110722',
#                                      'children': [{'name': 'Predict: 1.0'}]},
#                                     {'name': 'HeartRate > 8.325362829110722',
#                                      'children': [{'name': 'Predict: 0.0'}]}]},
#                                   {'name': 'Age > 2.563365022614154',
#                                    'children': [{'name': 'Predict: 1.0'}]}]},
#                                 {'name': 'BS > 2.385246850361807',
#                                  'children': [{'name': 'DiastolicBP <= 6.260116325731941',
#                                    'children': [{'name': 'Predict: 0.0'}]},
#                                   {'name': 'DiastolicBP > 6.260116325731941',
#                                    'children': [{'name': 'Age <= 1.8203606682332398',
#                                      'children': [{'name': 'Predict: 1.0'}]},
#                                     {'name': 'Age > 1.8203606682332398',
#                                      'children': [{'name': 'Predict: 0.0'}]}]}]}]}]},
#                             {'name': 'DiastolicBP > 7.015647606423727',
#                              'children': [{'name': 'Predict: 2.0'}]}]},
#                           {'name': 'HeartRate > 10.323449908097295',
#                            'children': [{'name': 'DiastolicBP <= 6.655870806094304',
#                              'children': [{'name': 'DiastolicBP <= 4.785031444381311',
#                                'children': [{'name': 'Predict: 0.0'}]},
#                               {'name': 'DiastolicBP > 4.785031444381311',
#                                'children': [{'name': 'HeartRate <= 11.18928764232481',
#                                  'children': [{'name': 'Predict: 1.0'}]},
#                                 {'name': 'HeartRate > 11.18928764232481',
#                                  'children': [{'name': 'Predict: 0.0'}]}]}]},
#                             {'name': 'DiastolicBP > 6.655870806094304',
#                              'children': [{'name': 'Predict: 2.0'}]}]}]},
#                         {'name': 'BodyTemp > 71.42757148873099',
#                          'children': [{'name': 'HeartRate <= 9.657420881768438',
#                            'children': [{'name': 'Predict: 2.0'}]},
#                           {'name': 'HeartRate > 9.657420881768438',
#                            'children': [{'name': 'Age <= 2.117562409985606',
#                              'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                                'children': [{'name': 'BS <= 2.385246850361807',
#                                  'children': [{'name': 'Predict: 1.0'}]},
#                                 {'name': 'BS > 2.385246850361807',
#                                  'children': [{'name': 'Age <= 1.3002576201665998',
#                                    'children': [{'name': 'Predict: 0.0'}]},
#                                   {'name': 'Age > 1.3002576201665998',
#                                    'children': [{'name': 'Predict: 2.0'}]}]}]},
#                               {'name': 'DiastolicBP > 4.425254644051889',
#                                'children': [{'name': 'HeartRate <= 10.789670226527495',
# ...
#                                                                                                                                               {'name': 'BodyTemp > 74.55525537265709',
#                                                                                                                                                'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#                                                                                                                                         {'name': 'Age > 2.117562409985606',
#                                                                                                                                          'children': [{'name': 'Age <= 2.3404637162998796',
#                                                                                                                                            'children': [{'name': 'Age <= 2.191862845423697',
#                                                                                                                                              'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                             {'name': 'Age > 2.191862845423697',
#                                                                                                                                              'children': [{'name': 'BS <= 2.2940909197747317',
#                                                                                                                                                'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                                                               {'name': 'BS > 2.2940909197747317',
#                                                                                                                                                'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                                                                                                                           {'name': 'Age > 2.3404637162998796',
#                                                                                                                                            'children': [{'name': 'Predict: 2.0'}]}]}]}]}]},
#                                                                                                                                   {'name': 'DiastolicBP > 7.015647606423727',
#                                                                                                                                    'children': [{'name': 'HeartRate <= 8.325362829110722',
#                                                                                                                                      'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                                                     {'name': 'HeartRate > 8.325362829110722',
#                                                                                                                                      'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                                                                                                                 {'name': 'BS > 2.5827513666338042',
#                                                                                                                                  'children': [{'name': 'BodyTemp <= 73.827887027558',
#                                                                                                                                    'children': [{'name': 'BS <= 3.4943106725045583',
#                                                                                                                                      'children': [{'name': 'HeartRate <= 9.657420881768438',
#                                                                                                                                        'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                       {'name': 'HeartRate > 9.657420881768438',
#                                                                                                                                        'children': [{'name': 'HeartRate <= 10.190244102831524',
#                                                                                                                                          'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                                                         {'name': 'HeartRate > 10.190244102831524',
#                                                                                                                                          'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                                                                                                                                            'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                           {'name': 'BodyTemp > 71.42757148873099',
#                                                                                                                                            'children': [{'name': 'Age <= 1.3002576201665998',
#                                                                                                                                              'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                             {'name': 'Age > 1.3002576201665998',
#                                                                                                                                              'children': [{'name': 'Predict: 1.0'}]}]}]}]}]},
#                                                                                                                                     {'name': 'BS > 3.4943106725045583',
#                                                                                                                                      'children': [{'name': 'DiastolicBP <= 6.260116325731941',
#                                                                                                                                        'children': [{'name': 'HeartRate <= 9.657420881768438',
#                                                                                                                                          'children': [{'name': 'Age <= 3.306369376995068',
#                                                                                                                                            'children': [{'name': 'BS <= 5.013576182289149',
#                                                                                                                                              'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                             {'name': 'BS > 5.013576182289149',
#                                                                                                                                              'children': [{'name': 'Predict: 1.0'}]}]},
#                                                                                                                                           {'name': 'Age > 3.306369376995068',
#                                                                                                                                            'children': [{'name': 'HeartRate <= 8.99139185543958',
#                                                                                                                                              'children': [{'name': 'Age <= 4.123674166814074',
#                                                                                                                                                'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                                                               {'name': 'Age > 4.123674166814074',
#                                                                                                                                                'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                                                                                                                                                  'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                                 {'name': 'DiastolicBP > 5.936317205435461',
#                                                                                                                                                  'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                                                                                                             {'name': 'HeartRate > 8.99139185543958',
#                                                                                                                                              'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                                                                                                                         {'name': 'HeartRate > 9.657420881768438',
#                                                                                                                                          'children': [{'name': 'Predict: 2.0'}]}]},
#                                                                                                                                       {'name': 'DiastolicBP > 6.260116325731941',
#                                                                                                                                        'children': [{'name': 'BS <= 5.013576182289149',
#                                                                                                                                          'children': [{'name': 'HeartRate <= 9.657420881768438',
#                                                                                                                                            'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                           {'name': 'HeartRate > 9.657420881768438',
#                                                                                                                                            'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                                                                                                                                              'children': [{'name': 'HeartRate <= 10.789670226527495',
#                                                                                                                                                'children': [{'name': 'HeartRate <= 10.323449908097295',
#                                                                                                                                                  'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                                 {'name': 'HeartRate > 10.323449908097295',
#                                                                                                                                                  'children': [{'name': 'Age <= 2.117562409985606',
#                                                                                                                                                    'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                                   {'name': 'Age > 2.117562409985606',
#                                                                                                                                                    'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                                                                                                               {'name': 'HeartRate > 10.789670226527495',
#                                                                                                                                                'children': [{'name': 'Predict: 2.0'}]}]},
#                                                                                                                                             {'name': 'BodyTemp > 71.42757148873099',
#                                                                                                                                              'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                                                                                                                         {'name': 'BS > 5.013576182289149',
#                                                                                                                                          'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#                                                                                                                                   {'name': 'BodyTemp > 73.827887027558',
#                                                                                                                                    'children': [{'name': 'BS <= 3.4943106725045583',
#                                                                                                                                      'children': [{'name': 'HeartRate <= 10.190244102831524',
#                                                                                                                                        'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                       {'name': 'HeartRate > 10.190244102831524',
#                                                                                                                                        'children': [{'name': 'Age <= 1.3002576201665998',
#                                                                                                                                          'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                                                         {'name': 'Age > 1.3002576201665998',
#                                                                                                                                          'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                                                                                                                     {'name': 'BS > 3.4943106725045583',
#                                                                                                                                      'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}

# %%
# 8.2.4

# %%
pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 17.0 MB/s eta 0:00:0000:0100:01
# Collecting joblib>=1.0.0
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 KB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in ./.local/lib/python3.10/site-packages (from scikit-learn->sklearn) (1.8.1)
# Requirement already satisfied: numpy>=1.17.3 in ./.local/lib/python3.10/site-packages (from scikit-learn->sklearn) (1.22.4)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=fd96267261c1b3791765c5b3924fe955812b19de1eab29ebe2a5a5c81f27bf20
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/9b/13/01/6f3a7fd641f90e1f6c8c7cded057f3394f451f340371c68f3d
# Successfully built sklearn
# Installing collected packages: threadpoolctl, joblib, scikit-learn, sklearn
# Successfully installed joblib-1.2.0 scikit-learn-1.1.2 sklearn-0.0 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import tree

# plot pruned tree of max_depth=10
features = ['Age', 'DiastolicBP', 'BS', 'BodyTemp', 'HeartRate']
target = 'RiskLevelIndex'
dataset = data_changed.toPandas()[features+[target]]

# Regression tree on maternal data
fig = plt.figure(figsize=(13,7))
regr= tree.DecisionTreeRegressor(max_depth=10) 
regr.fit(dataset[features], dataset[target])
tree.plot_tree(regr)
# Out:
# [Text(0.7039811643835616, 0.9545454545454546, 'X[2] <= 7.95\nsquared_error = 0.65\nsamples = 1012\nvalue = 0.868'),
#  Text(0.5633561643835616, 0.8636363636363636, 'X[1] <= 97.5\nsquared_error = 0.443\nsamples = 750\nvalue = 0.569'),
#  Text(0.449486301369863, 0.7727272727272727, 'X[3] <= 99.5\nsquared_error = 0.378\nsamples = 719\nvalue = 0.513'),
#  Text(0.2422945205479452, 0.6818181818181818, 'X[2] <= 7.055\nsquared_error = 0.297\nsamples = 579\nvalue = 0.411'),
#  Text(0.1113013698630137, 0.5909090909090909, 'X[0] <= 15.5\nsquared_error = 0.327\nsamples = 331\nvalue = 0.544'),
#  Text(0.06164383561643835, 0.5, 'X[0] <= 13.5\nsquared_error = 0.205\nsamples = 52\nvalue = 0.288'),
#  Text(0.03424657534246575, 0.4090909090909091, 'X[2] <= 6.85\nsquared_error = 0.227\nsamples = 20\nvalue = 0.65'),
#  Text(0.0136986301369863, 0.3181818181818182, 'X[4] <= 73.5\nsquared_error = 0.083\nsamples = 11\nvalue = 0.909'),
#  Text(0.00684931506849315, 0.22727272727272727, 'squared_error = 0.0\nsamples = 8\nvalue = 1.0'),
#  Text(0.02054794520547945, 0.22727272727272727, 'X[4] <= 78.5\nsquared_error = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(0.0136986301369863, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.0273972602739726, 0.13636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.0547945205479452, 0.3181818181818182, 'X[4] <= 67.5\nsquared_error = 0.222\nsamples = 9\nvalue = 0.333'),
#  Text(0.04794520547945205, 0.22727272727272727, 'X[4] <= 62.5\nsquared_error = 0.24\nsamples = 5\nvalue = 0.6'),
#  Text(0.0410958904109589, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.0547945205479452, 0.13636363636363635, 'squared_error = 0.188\nsamples = 4\nvalue = 0.75'),
#  Text(0.06164383561643835, 0.22727272727272727, 'squared_error = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(0.08904109589041095, 0.4090909090909091, 'X[2] <= 6.2\nsquared_error = 0.059\nsamples = 32\nvalue = 0.062'),
#  Text(0.0821917808219178, 0.3181818181818182, 'X[4] <= 73.5\nsquared_error = 0.173\nsamples = 9\nvalue = 0.222'),
#  Text(0.07534246575342465, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.08904109589041095, 0.22727272727272727, 'squared_error = 0.0\nsamples = 7\nvalue = 0.0'),
#  Text(0.0958904109589041, 0.3181818181818182, 'squared_error = 0.0\nsamples = 23\nvalue = 0.0'),
#  Text(0.16095890410958905, 0.5, 'X[2] <= 6.6\nsquared_error = 0.335\nsamples = 279\nvalue = 0.591'),
#  Text(0.11643835616438356, 0.4090909090909091, 'X[4] <= 75.5\nsquared_error = 0.224\nsamples = 56\nvalue = 0.339'),
#  Text(0.1095890410958904, 0.3181818181818182, 'squared_error = 0.0\nsamples = 21\nvalue = 0.0'),
#  Text(0.1232876712328767, 0.3181818181818182, 'X[0] <= 27.0\nsquared_error = 0.248\nsamples = 35\nvalue = 0.543'),
#  Text(0.11643835616438356, 0.22727272727272727, 'squared_error = 0.0\nsamples = 6\nvalue = 0.0'),
#  Text(0.13013698630136986, 0.22727272727272727, 'X[1] <= 65.0\nsquared_error = 0.226\nsamples = 29\nvalue = 0.655'),
#  Text(0.1232876712328767, 0.13636363636363635, 'X[0] <= 33.0\nsquared_error = 0.24\nsamples = 25\nvalue = 0.6'),
#  Text(0.11643835616438356, 0.045454545454545456, 'squared_error = 0.227\nsamples = 20\nvalue = 0.65'),
#  Text(0.13013698630136986, 0.045454545454545456, 'squared_error = 0.24\nsamples = 5\nvalue = 0.4'),
#  Text(0.136986301369863, 0.13636363636363635, 'squared_error = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(0.2054794520547945, 0.4090909090909091, 'X[1] <= 67.5\nsquared_error = 0.343\nsamples = 223\nvalue = 0.655'),
#  Text(0.17123287671232876, 0.3181818181818182, 'X[0] <= 18.5\nsquared_error = 0.247\nsamples = 56\nvalue = 0.446'),
#  Text(0.15753424657534246, 0.22727272727272727, 'X[0] <= 17.0\nsquared_error = 0.122\nsamples = 7\nvalue = 0.857'),
#  Text(0.1506849315068493, 0.13636363636363635, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.1643835616438356, 0.13636363636363635, 'squared_error = 0.188\nsamples = 4\nvalue = 0.75'),
#  Text(0.18493150684931506, 0.22727272727272727, 'X[4] <= 68.0\nsquared_error = 0.237\nsamples = 49\nvalue = 0.388'),
#  Text(0.1780821917808219, 0.13636363636363635, 'squared_error = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(0.1917808219178082, 0.13636363636363635, 'X[0] <= 21.5\nsquared_error = 0.244\nsamples = 45\nvalue = 0.422'),
#  Text(0.18493150684931506, 0.045454545454545456, 'squared_error = 0.222\nsamples = 9\nvalue = 0.667'),
#  Text(0.19863013698630136, 0.045454545454545456, 'squared_error = 0.231\nsamples = 36\nvalue = 0.361'),
#  Text(0.23972602739726026, 0.3181818181818182, 'X[1] <= 92.5\nsquared_error = 0.355\nsamples = 167\nvalue = 0.725'),
#  Text(0.2328767123287671, 0.22727272727272727, 'X[0] <= 22.5\nsquared_error = 0.348\nsamples = 166\nvalue = 0.717'),
#  Text(0.2191780821917808, 0.13636363636363635, 'X[0] <= 19.5\nsquared_error = 0.239\nsamples = 63\nvalue = 0.603'),
#  Text(0.21232876712328766, 0.045454545454545456, 'squared_error = 0.21\nsamples = 50\nvalue = 0.7'),
#  Text(0.22602739726027396, 0.045454545454545456, 'squared_error = 0.178\nsamples = 13\nvalue = 0.231'),
#  Text(0.2465753424657534, 0.13636363636363635, 'X[0] <= 24.0\nsquared_error = 0.401\nsamples = 103\nvalue = 0.786'),
#  Text(0.23972602739726026, 0.045454545454545456, 'squared_error = 0.372\nsamples = 21\nvalue = 1.095'),
#  Text(0.2534246575342466, 0.045454545454545456, 'squared_error = 0.378\nsamples = 82\nvalue = 0.707'),
#  Text(0.2465753424657534, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(0.3732876712328767, 0.5909090909090909, 'X[4] <= 77.5\nsquared_error = 0.203\nsamples = 248\nvalue = 0.234'),
#  Text(0.3082191780821918, 0.5, 'X[1] <= 72.5\nsquared_error = 0.176\nsamples = 189\nvalue = 0.175'),
#  Text(0.2671232876712329, 0.4090909090909091, 'X[1] <= 62.5\nsquared_error = 0.031\nsamples = 63\nvalue = 0.032'),
#  Text(0.2602739726027397, 0.3181818181818182, 'squared_error = 0.0\nsamples = 35\nvalue = 0.0'),
#  Text(0.273972602739726, 0.3181818181818182, 'X[0] <= 22.5\nsquared_error = 0.066\nsamples = 28\nvalue = 0.071'),
#  Text(0.2671232876712329, 0.22727272727272727, 'X[0] <= 21.5\nsquared_error = 0.188\nsamples = 8\nvalue = 0.25'),
#  Text(0.2602739726027397, 0.13636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.273972602739726, 0.13636363636363635, 'X[2] <= 7.35\nsquared_error = 0.222\nsamples = 6\nvalue = 0.333'),
#  Text(0.2671232876712329, 0.045454545454545456, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.2808219178082192, 0.045454545454545456, 'squared_error = 0.25\nsamples = 4\nvalue = 0.5'),
#  Text(0.2808219178082192, 0.22727272727272727, 'squared_error = 0.0\nsamples = 20\nvalue = 0.0'),
#  Text(0.3493150684931507, 0.4090909090909091, 'X[2] <= 7.6\nsquared_error = 0.233\nsamples = 126\nvalue = 0.246'),
#  Text(0.3219178082191781, 0.3181818181818182, 'X[4] <= 72.5\nsquared_error = 0.132\nsamples = 77\nvalue = 0.156'),
#  Text(0.3082191780821918, 0.22727272727272727, 'X[0] <= 23.5\nsquared_error = 0.094\nsamples = 57\nvalue = 0.105'),
#  Text(0.3013698630136986, 0.13636363636363635, 'X[1] <= 78.0\nsquared_error = 0.156\nsamples = 31\nvalue = 0.194'),
#  Text(0.2945205479452055, 0.045454545454545456, 'squared_error = 0.0\nsamples = 8\nvalue = 0.0'),
#  Text(0.3082191780821918, 0.045454545454545456, 'squared_error = 0.193\nsamples = 23\nvalue = 0.261'),
#  Text(0.3150684931506849, 0.13636363636363635, 'squared_error = 0.0\nsamples = 26\nvalue = 0.0'),
#  Text(0.3356164383561644, 0.22727272727272727, 'X[2] <= 7.35\nsquared_error = 0.21\nsamples = 20\nvalue = 0.3'),
#  Text(0.3287671232876712, 0.13636363636363635, 'squared_error = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(0.3424657534246575, 0.13636363636363635, 'X[4] <= 76.5\nsquared_error = 0.234\nsamples = 16\nvalue = 0.375'),
#  Text(0.3356164383561644, 0.045454545454545456, 'squared_error = 0.188\nsamples = 8\nvalue = 0.25'),
#  Text(0.3493150684931507, 0.045454545454545456, 'squared_error = 0.25\nsamples = 8\nvalue = 0.5'),
#  Text(0.3767123287671233, 0.3181818181818182, 'X[0] <= 17.0\nsquared_error = 0.36\nsamples = 49\nvalue = 0.388'),
#  Text(0.3698630136986301, 0.22727272727272727, 'squared_error = 0.0\nsamples = 7\nvalue = 0.0'),
#  Text(0.3835616438356164, 0.22727272727272727, 'X[1] <= 77.5\nsquared_error = 0.391\nsamples = 42\nvalue = 0.452'),
#  Text(0.3698630136986301, 0.13636363636363635, 'X[0] <= 30.0\nsquared_error = 0.96\nsamples = 5\nvalue = 0.8'),
#  Text(0.363013698630137, 0.045454545454545456, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.3767123287671233, 0.045454545454545456, 'squared_error = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(0.3972602739726027, 0.13636363636363635, 'X[2] <= 7.75\nsquared_error = 0.295\nsamples = 37\nvalue = 0.405'),
#  Text(0.3904109589041096, 0.045454545454545456, 'squared_error = 0.0\nsamples = 9\nvalue = 0.0'),
#  Text(0.4041095890410959, 0.045454545454545456, 'squared_error = 0.32\nsamples = 28\nvalue = 0.536'),
#  Text(0.4383561643835616, 0.5, 'X[4] <= 79.0\nsquared_error = 0.244\nsamples = 59\nvalue = 0.424'),
#  Text(0.4315068493150685, 0.4090909090909091, 'squared_error = 0.0\nsamples = 14\nvalue = 1.0'),
#  Text(0.4452054794520548, 0.4090909090909091, 'X[1] <= 87.5\nsquared_error = 0.185\nsamples = 45\nvalue = 0.244'),
#  Text(0.4246575342465753, 0.3181818181818182, 'X[0] <= 25.0\nsquared_error = 0.119\nsamples = 29\nvalue = 0.138'),
#  Text(0.4178082191780822, 0.22727272727272727, 'squared_error = 0.0\nsamples = 19\nvalue = 0.0'),
#  Text(0.4315068493150685, 0.22727272727272727, 'X[2] <= 7.7\nsquared_error = 0.24\nsamples = 10\nvalue = 0.4'),
#  Text(0.4246575342465753, 0.13636363636363635, 'X[1] <= 70.0\nsquared_error = 0.188\nsamples = 8\nvalue = 0.25'),
#  Text(0.4178082191780822, 0.045454545454545456, 'squared_error = 0.222\nsamples = 6\nvalue = 0.333'),
#  Text(0.4315068493150685, 0.045454545454545456, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.4383561643835616, 0.13636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.4657534246575342, 0.3181818181818182, 'X[2] <= 7.65\nsquared_error = 0.246\nsamples = 16\nvalue = 0.438'),
#  Text(0.4589041095890411, 0.22727272727272727, 'X[2] <= 7.3\nsquared_error = 0.213\nsamples = 13\nvalue = 0.308'),
#  Text(0.4520547945205479, 0.13636363636363635, 'squared_error = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(0.4657534246575342, 0.13636363636363635, 'X[4] <= 81.0\nsquared_error = 0.247\nsamples = 9\nvalue = 0.444'),
#  Text(0.4589041095890411, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.4726027397260274, 0.045454545454545456, 'squared_error = 0.25\nsamples = 8\nvalue = 0.5'),
#  Text(0.4726027397260274, 0.22727272727272727, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.6566780821917808, 0.6818181818181818, 'X[2] <= 7.6\nsquared_error = 0.489\nsamples = 140\nvalue = 0.936'),
#  Text(0.601027397260274, 0.5909090909090909, 'X[2] <= 7.35\nsquared_error = 0.458\nsamples = 113\nvalue = 0.858'),
#  Text(0.5513698630136986, 0.5, 'X[2] <= 6.95\nsquared_error = 0.336\nsamples = 74\nvalue = 1.041'),
#  Text(0.5205479452054794, 0.4090909090909091, 'X[0] <= 17.5\nsquared_error = 0.284\nsamples = 54\nvalue = 0.889'),
#  Text(0.4931506849315068, 0.3181818181818182, 'X[0] <= 14.5\nsquared_error = 0.343\nsamples = 19\nvalue = 1.158'),
#  Text(0.4863013698630137, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.5, 0.22727272727272727, 'X[2] <= 6.5\nsquared_error = 0.208\nsamples = 17\nvalue = 1.294'),
#  Text(0.4931506849315068, 0.13636363636363635, 'squared_error = 0.0\nsamples = 4\nvalue = 2.0'),
#  Text(0.5068493150684932, 0.13636363636363635, 'X[1] <= 69.0\nsquared_error = 0.071\nsamples = 13\nvalue = 1.077'),
#  Text(0.5, 0.045454545454545456, 'squared_error = 0.0\nsamples = 8\nvalue = 1.0'),
#  Text(0.5136986301369864, 0.045454545454545456, 'squared_error = 0.16\nsamples = 5\nvalue = 1.2'),
#  Text(0.547945205479452, 0.3181818181818182, 'X[3] <= 102.5\nsquared_error = 0.191\nsamples = 35\nvalue = 0.743'),
#  Text(0.541095890410959, 0.22727272727272727, 'X[0] <= 62.5\nsquared_error = 0.152\nsamples = 32\nvalue = 0.812'),
#  Text(0.5342465753424658, 0.13636363636363635, 'X[2] <= 6.75\nsquared_error = 0.135\nsamples = 31\nvalue = 0.839'),
#  Text(0.5273972602739726, 0.045454545454545456, 'squared_error = 0.0\nsamples = 12\nvalue = 1.0'),
#  Text(0.541095890410959, 0.045454545454545456, 'squared_error = 0.194\nsamples = 19\nvalue = 0.737'),
#  Text(0.547945205479452, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.5547945205479452, 0.22727272727272727, 'squared_error = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(0.5821917808219178, 0.4090909090909091, 'X[3] <= 100.5\nsquared_error = 0.248\nsamples = 20\nvalue = 1.45'),
#  Text(0.5753424657534246, 0.3181818181818182, 'X[2] <= 7.105\nsquared_error = 0.13\nsamples = 13\nvalue = 1.154'),
#  Text(0.5684931506849316, 0.22727272727272727, 'squared_error = 0.0\nsamples = 11\nvalue = 1.0'),
#  Text(0.5821917808219178, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(0.589041095890411, 0.3181818181818182, 'squared_error = 0.0\nsamples = 7\nvalue = 2.0'),
#  Text(0.6506849315068494, 0.5, 'X[0] <= 20.5\nsquared_error = 0.506\nsamples = 39\nvalue = 0.513'),
#  Text(0.6232876712328768, 0.4090909090909091, 'X[4] <= 78.0\nsquared_error = 0.356\nsamples = 30\nvalue = 0.333'),
#  Text(0.6027397260273972, 0.3181818181818182, 'X[4] <= 68.5\nsquared_error = 0.16\nsamples = 20\nvalue = 0.2'),
#  Text(0.5958904109589042, 0.22727272727272727, 'X[4] <= 63.0\nsquared_error = 0.24\nsamples = 10\nvalue = 0.4'),
#  Text(0.589041095890411, 0.13636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.6027397260273972, 0.13636363636363635, 'X[0] <= 14.5\nsquared_error = 0.25\nsamples = 8\nvalue = 0.5'),
#  Text(0.5958904109589042, 0.045454545454545456, 'squared_error = 0.25\nsamples = 4\nvalue = 0.5'),
#  Text(0.6095890410958904, 0.045454545454545456, 'squared_error = 0.25\nsamples = 4\nvalue = 0.5'),
#  Text(0.6095890410958904, 0.22727272727272727, 'squared_error = 0.0\nsamples = 10\nvalue = 0.0'),
#  Text(0.6438356164383562, 0.3181818181818182, 'X[3] <= 101.5\nsquared_error = 0.64\nsamples = 10\nvalue = 0.6'),
#  Text(0.636986301369863, 0.22727272727272727, 'X[1] <= 62.5\nsquared_error = 0.667\nsamples = 6\nvalue = 1.0'),
#  Text(0.6301369863013698, 0.13636363636363635, 'X[0] <= 17.5\nsquared_error = 0.222\nsamples = 3\nvalue = 1.333'),
#  Text(0.6232876712328768, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(0.636986301369863, 0.045454545454545456, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.6438356164383562, 0.13636363636363635, 'squared_error = 0.889\nsamples = 3\nvalue = 0.667'),
#  Text(0.6506849315068494, 0.22727272727272727, 'squared_error = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(0.678082191780822, 0.4090909090909091, 'X[1] <= 85.0\nsquared_error = 0.543\nsamples = 9\nvalue = 1.111'),
#  Text(0.6712328767123288, 0.3181818181818182, 'X[0] <= 27.5\nsquared_error = 0.245\nsamples = 7\nvalue = 1.429'),
#  Text(0.6643835616438356, 0.22727272727272727, 'squared_error = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(0.678082191780822, 0.22727272727272727, 'squared_error = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(0.684931506849315, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.7123287671232876, 0.5909090909090909, 'X[4] <= 71.5\nsquared_error = 0.488\nsamples = 27\nvalue = 1.259'),
#  Text(0.7054794520547946, 0.5, 'squared_error = 0.0\nsamples = 6\nvalue = 2.0'),
#  Text(0.7191780821917808, 0.5, 'X[0] <= 29.0\nsquared_error = 0.426\nsamples = 21\nvalue = 1.048'),
#  Text(0.7123287671232876, 0.4090909090909091, 'X[1] <= 62.5\nsquared_error = 0.263\nsamples = 17\nvalue = 0.824'),
#  Text(0.6986301369863014, 0.3181818181818182, 'X[0] <= 22.5\nsquared_error = 0.245\nsamples = 7\nvalue = 0.429'),
#  Text(0.6917808219178082, 0.22727272727272727, 'squared_error = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(0.7054794520547946, 0.22727272727272727, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.726027397260274, 0.3181818181818182, 'X[4] <= 83.0\nsquared_error = 0.09\nsamples = 10\nvalue = 1.1'),
#  Text(0.7191780821917808, 0.22727272727272727, 'squared_error = 0.0\nsamples = 9\nvalue = 1.0'),
#  Text(0.7328767123287672, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(0.726027397260274, 0.4090909090909091, 'squared_error = 0.0\nsamples = 4\nvalue = 2.0'),
#  Text(0.6772260273972602, 0.7727272727272727, 'X[4] <= 63.0\nsquared_error = 0.177\nsamples = 31\nvalue = 1.871'),
#  Text(0.6703767123287672, 0.6818181818181818, 'squared_error = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(0.6840753424657534, 0.6818181818181818, 'squared_error = 0.0\nsamples = 28\nvalue = 2.0'),
#  Text(0.8446061643835616, 0.8636363636363636, 'X[2] <= 9.5\nsquared_error = 0.262\nsamples = 262\nvalue = 1.721'),
#  Text(0.8047945205479452, 0.7727272727272727, 'X[1] <= 95.0\nsquared_error = 0.386\nsamples = 53\nvalue = 1.377'),
#  Text(0.797945205479452, 0.6818181818181818, 'X[1] <= 72.5\nsquared_error = 0.379\nsamples = 47\nvalue = 1.298'),
#  Text(0.7671232876712328, 0.5909090909090909, 'X[4] <= 83.0\nsquared_error = 0.25\nsamples = 33\nvalue = 1.485'),
#  Text(0.7534246575342466, 0.5, 'X[4] <= 79.0\nsquared_error = 0.188\nsamples = 16\nvalue = 1.75'),
#  Text(0.7465753424657534, 0.4090909090909091, 'X[1] <= 64.0\nsquared_error = 0.25\nsamples = 8\nvalue = 1.5'),
#  Text(0.7397260273972602, 0.3181818181818182, 'squared_error = 0.0\nsamples = 4\nvalue = 2.0'),
#  Text(0.7534246575342466, 0.3181818181818182, 'squared_error = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(0.7602739726027398, 0.4090909090909091, 'squared_error = 0.0\nsamples = 8\nvalue = 2.0'),
#  Text(0.7808219178082192, 0.5, 'X[2] <= 8.5\nsquared_error = 0.18\nsamples = 17\nvalue = 1.235'),
#  Text(0.773972602739726, 0.4090909090909091, 'squared_error = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(0.7876712328767124, 0.4090909090909091, 'X[0] <= 22.5\nsquared_error = 0.116\nsamples = 15\nvalue = 1.133'),
#  Text(0.7808219178082192, 0.3181818181818182, 'squared_error = 0.173\nsamples = 9\nvalue = 1.222'),
#  Text(0.7945205479452054, 0.3181818181818182, 'squared_error = 0.0\nsamples = 6\nvalue = 1.0'),
#  Text(0.8287671232876712, 0.5909090909090909, 'X[3] <= 101.5\nsquared_error = 0.408\nsamples = 14\nvalue = 0.857'),
#  Text(0.821917808219178, 0.5, 'X[2] <= 8.5\nsquared_error = 0.222\nsamples = 12\nvalue = 0.667'),
#  Text(0.815068493150685, 0.4090909090909091, 'X[0] <= 28.5\nsquared_error = 0.222\nsamples = 6\nvalue = 0.333'),
#  Text(0.8082191780821918, 0.3181818181818182, 'X[1] <= 80.0\nsquared_error = 0.25\nsamples = 4\nvalue = 0.5'),
#  Text(0.8013698630136986, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.815068493150685, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.821917808219178, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.8287671232876712, 0.4090909090909091, 'squared_error = 0.0\nsamples = 6\nvalue = 1.0'),
#  Text(0.8356164383561644, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(0.8116438356164384, 0.6818181818181818, 'squared_error = 0.0\nsamples = 6\nvalue = 2.0'),
#  Text(0.884417808219178, 0.7727272727272727, 'X[0] <= 41.0\nsquared_error = 0.193\nsamples = 209\nvalue = 1.809'),
#  Text(0.8493150684931506, 0.6818181818181818, 'X[0] <= 38.5\nsquared_error = 0.021\nsamples = 94\nvalue = 1.979'),
#  Text(0.8424657534246576, 0.5909090909090909, 'squared_error = 0.0\nsamples = 62\nvalue = 2.0'),
#  Text(0.8561643835616438, 0.5909090909090909, 'X[2] <= 11.5\nsquared_error = 0.059\nsamples = 32\nvalue = 1.938'),
#  Text(0.8493150684931506, 0.5, 'squared_error = 0.173\nsamples = 9\nvalue = 1.778'),
#  Text(0.863013698630137, 0.5, 'squared_error = 0.0\nsamples = 23\nvalue = 2.0'),
#  Text(0.9195205479452054, 0.6818181818181818, 'X[1] <= 87.5\nsquared_error = 0.291\nsamples = 115\nvalue = 1.67'),
#  Text(0.8904109589041096, 0.5909090909090909, 'X[2] <= 12.5\nsquared_error = 0.4\nsamples = 53\nvalue = 1.472'),
#  Text(0.8767123287671232, 0.5, 'X[2] <= 11.5\nsquared_error = 0.529\nsamples = 27\nvalue = 1.37'),
#  Text(0.8698630136986302, 0.4090909090909091, 'squared_error = 0.576\nsamples = 24\nvalue = 1.417'),
#  Text(0.8835616438356164, 0.4090909090909091, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.9041095890410958, 0.5, 'X[3] <= 101.5\nsquared_error = 0.244\nsamples = 26\nvalue = 1.577'),
#  Text(0.8972602739726028, 0.4090909090909091, 'X[4] <= 73.0\nsquared_error = 0.234\nsamples = 24\nvalue = 1.625'),
#  Text(0.8904109589041096, 0.3181818181818182, 'X[0] <= 44.0\nsquared_error = 0.245\nsamples = 21\nvalue = 1.571'),
#  Text(0.8767123287671232, 0.22727272727272727, 'X[0] <= 42.5\nsquared_error = 0.222\nsamples = 6\nvalue = 1.333'),
#  Text(0.8698630136986302, 0.13636363636363635, 'squared_error = 0.25\nsamples = 4\nvalue = 1.5'),
#  Text(0.8835616438356164, 0.13636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.9041095890410958, 0.22727272727272727, 'X[4] <= 63.0\nsquared_error = 0.222\nsamples = 15\nvalue = 1.667'),
#  Text(0.8972602739726028, 0.13636363636363635, 'squared_error = 0.247\nsamples = 9\nvalue = 1.444'),
#  Text(0.910958904109589, 0.13636363636363635, 'squared_error = 0.0\nsamples = 6\nvalue = 2.0'),
#  Text(0.9041095890410958, 0.3181818181818182, 'squared_error = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(0.910958904109589, 0.4090909090909091, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.9486301369863014, 0.5909090909090909, 'X[2] <= 13.5\nsquared_error = 0.135\nsamples = 62\nvalue = 1.839'),
#  Text(0.9315068493150684, 0.5, 'X[4] <= 73.5\nsquared_error = 0.24\nsamples = 5\nvalue = 1.4'),
#  Text(0.9246575342465754, 0.4090909090909091, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.9383561643835616, 0.4090909090909091, 'squared_error = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(0.9657534246575342, 0.5, 'X[0] <= 46.0\nsquared_error = 0.108\nsamples = 57\nvalue = 1.877'),
#  Text(0.952054794520548, 0.4090909090909091, 'X[2] <= 17.0\nsquared_error = 0.245\nsamples = 7\nvalue = 1.571'),
#  Text(0.9452054794520548, 0.3181818181818182, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.958904109589041, 0.3181818181818182, 'squared_error = 0.0\nsamples = 4\nvalue = 2.0'),
#  Text(0.9794520547945206, 0.4090909090909091, 'X[1] <= 97.5\nsquared_error = 0.074\nsamples = 50\nvalue = 1.92'),
#  Text(0.9726027397260274, 0.3181818181818182, 'squared_error = 0.0\nsamples = 28\nvalue = 2.0'),
#  Text(0.9863013698630136, 0.3181818181818182, 'X[0] <= 52.0\nsquared_error = 0.149\nsamples = 22\nvalue = 1.818'),
#  Text(0.9794520547945206, 0.22727272727272727, 'X[4] <= 75.5\nsquared_error = 0.231\nsamples = 11\nvalue = 1.636'),
#  Text(0.9726027397260274, 0.13636363636363635, 'squared_error = 0.247\nsamples = 9\nvalue = 1.556'),
#  Text(0.9863013698630136, 0.13636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(0.9931506849315068, 0.22727272727272727, 'squared_error = 0.0\nsamples = 11\nvalue = 2.0')]

# %%
# 8.2.5

# %%
from pyspark.mllib.evaluation import BinaryClassificationMetrics

class CurveMetrics(BinaryClassificationMetrics):
    def __init__(self, *args):
        super(CurveMetrics, self).__init__(*args)

    def _to_list(self, rdd):
        points = []
        # Note this collect could be inefficient for large datasets 
        # considering there may be one probability per datapoint (at most)
        # The Scala version takes a numBins parameter, 
        # but it doesn't seem possible to pass this from Python to Java
        for row in rdd.collect():
            # Results are returned as type scala.Tuple2, 
            # which doesn't appear to have a py4j mapping
            points += [(float(row._1()), float(row._2()))]
        return points

    def get_curve(self, method):
        rdd = getattr(self._java_model, method)().toJavaRDD()
        return self._to_list(rdd)

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
# measure model performance
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
model = rfc.fit(train_data)
# predict response
predictions = model.transform(test_data)
# BinaryClassificationEva.luator
evaluator = BinaryClassificationEvaluator(labelCol="RiskLevelIndex", rawPredictionCol="prediction", metricName='areaUnderROC')
# Make predicitons
predictionAndTarget = predictions.select("RiskLevelIndex", "prediction")
# measure area under curve
auc = evaluator.evaluate(predictionAndTarget)

# %%
# Returns as a list (false positive rate, true positive rate)
preds = predictions.select('RiskLevelIndex','probability').rdd.map(lambda row: (float(row['probability'][1]),
                                                                                float(row['RiskLevelIndex'])))
roc = CurveMetrics(preds).get_curve('roc')

plt.figure()
x_val = [x[0] for x in roc]
y_val = [x[1] for x in roc]
plt.title('ROC, AUC= '+str(auc))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(x_val, y_val)

# %%
from pyspark.mllib.evaluation import MulticlassMetrics
# Metrics
predictionRDD = predictions.select(['RiskLevelIndex', 'prediction']).rdd.map(lambda line: (line[1], line[0]))
metrics = MulticlassMetrics(predictionRDD)

# Confusion Matrix
print('Confusion Matrix \n', metrics.confusionMatrix().toArray())
print('\nAccuracy =', metrics.accuracy)
# Out:
# Confusion Matrix
#  [[71. 14.  1.]
#  [13. 62.  3.]
#  [ 1.  5. 55.]]
#
# Accuracy = 0.8355555555555556

# %%
# 8.3

# %%
def parse_debug_string_lines(lines):
    
    block = []
    while lines:

        if lines[0].startswith('If'):
            bl = ' '.join(lines.pop(0).split()[1:]).replace('(', '').replace(')', '')
            block.append({'name': bl, 'children': parse_debug_string_lines(lines)})

            if lines[0].startswith('Else'):
                be = ' '.join(lines.pop(0).split()[1:]).replace('(', '').replace(')', '')
                block.append({'name': be, 'children': parse_debug_string_lines(lines)})
        elif not lines[0].startswith(('If', 'Else')):
            block2 = lines.pop(0)
            block.append({'name': block2})
        else:
            break
    
    return block

def debug_str_to_json(debug_string):
    data = []
    for line in debug_string.splitlines():
        if line.strip():
            line = line.strip()
            data.append(line)
        else:
            break
        if not line: break

    json = {'name': 'Root', 'children': parse_debug_string_lines(data[1:])}
    
    return json

# %%
# rfc model
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
# prepare data and model
pipeline = Pipeline(stages=[rfc])
model = pipeline.fit(data_changed)
tree_model_classifier = model.stages[0]

f_type_to_flist_dict = data_changed.schema['features'].metadata["ml_attr"]["attrs"]
f_index_to_name_dict = {}
for f_type, f_list in f_type_to_flist_dict.items():
   for f in f_list:
       f_index = f['idx']
       f_name = f['name']
       f_index_to_name_dict[f_index] = f_name

tree = tree_model_classifier.toDebugString
for i in range(len(f_index_to_name_dict)):
   tree = tree.replace('feature {}'.format(i), f_index_to_name_dict.get(i))

debug_str_to_json(tree)
# Out:
# {'name': 'Root',
#  'children': [{'name': 'Tree 0 (weight 1.0):'},
#   {'name': 'BS <= 2.5827513666338042',
#    'children': [{'name': 'DiastolicBP <= 7.015647606423727',
#      'children': [{'name': 'BodyTemp <= 72.37315033735982',
#        'children': [{'name': 'DiastolicBP <= 3.5617903232612766',
#          'children': [{'name': 'Predict: 0.0'}]},
#         {'name': 'DiastolicBP > 3.5617903232612766',
#          'children': [{'name': 'Age <= 1.0773563138523257',
#            'children': [{'name': 'BS <= 2.081393748404889',
#              'children': [{'name': 'Predict: 1.0'}]},
#             {'name': 'BS > 2.081393748404889',
#              'children': [{'name': 'Predict: 0.0'}]}]},
#           {'name': 'Age > 1.0773563138523257',
#            'children': [{'name': 'BS <= 2.1284909792082116',
#              'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                'children': [{'name': 'DiastolicBP <= 4.785031444381311',
#                  'children': [{'name': 'Age <= 1.3745580556046912',
#                    'children': [{'name': 'DiastolicBP <= 3.957544803623641',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'DiastolicBP > 3.957544803623641',
#                      'children': [{'name': 'Predict: 0.0'}]}]},
#                   {'name': 'Age > 1.3745580556046912',
#                    'children': [{'name': 'Predict: 0.0'}]}]},
#                 {'name': 'DiastolicBP > 4.785031444381311',
#                  'children': [{'name': 'HeartRate <= 10.323449908097295',
#                    'children': [{'name': 'Age <= 1.3745580556046912',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'Age > 1.3745580556046912',
#                      'children': [{'name': 'Predict: 1.0'}]}]},
#                   {'name': 'HeartRate > 10.323449908097295',
#                    'children': [{'name': 'BS <= 2.1117790586005807',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'BS > 2.1117790586005807',
#                      'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#               {'name': 'DiastolicBP > 5.936317205435461',
#                'children': [{'name': 'BS <= 2.0510084382091973',
#                  'children': [{'name': 'Predict: 0.0'}]},
#                 {'name': 'BS > 2.0510084382091973',
#                  'children': [{'name': 'Age <= 1.671759797357057',
#                    'children': [{'name': 'BS <= 2.081393748404889',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'BS > 2.081393748404889',
#                      'children': [{'name': 'Predict: 0.0'}]}]},
#                   {'name': 'Age > 1.671759797357057',
#                    'children': [{'name': 'Age <= 1.8203606682332398',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'Age > 1.8203606682332398',
#                      'children': [{'name': 'Predict: 0.0'}]}]}]}]}]},
#             {'name': 'BS > 2.1284909792082116',
#              'children': [{'name': 'BS <= 2.354861540166115',
#                'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                  'children': [{'name': 'Age <= 2.191862845423697',
#                    'children': [{'name': 'Age <= 2.117562409985606',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'Age > 2.117562409985606',
#                      'children': [{'name': 'Predict: 1.0'}]}]},
#                   {'name': 'Age > 2.191862845423697',
#                    'children': [{'name': 'Predict: 0.0'}]}]},
#                 {'name': 'DiastolicBP > 5.2167636047766175',
#                  'children': [{'name': 'HeartRate <= 9.657420881768438',
#                    'children': [{'name': 'Predict: 0.0'}]},
#                   {'name': 'HeartRate > 9.657420881768438',
#                    'children': [{'name': 'Age <= 1.5231589264808743',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'Age > 1.5231589264808743',
#                      'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#               {'name': 'BS > 2.354861540166115',
#                'children': [{'name': 'HeartRate <= 10.323449908097295',
#                  'children': [{'name': 'Age <= 1.8203606682332398',
#                    'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'DiastolicBP > 5.936317205435461',
#                      'children': [{'name': 'Predict: 1.0'}]}]},
#                   {'name': 'Age > 1.8203606682332398',
#                    'children': [{'name': 'Predict: 0.0'}]}]},
#                 {'name': 'HeartRate > 10.323449908097295',
#                  'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]},
#       {'name': 'BodyTemp > 72.37315033735982',
#        'children': [{'name': 'HeartRate <= 8.99139185543958',
#          'children': [{'name': 'BS <= 1.8838892321328924',
#            'children': [{'name': 'BodyTemp <= 74.55525537265709',
#              'children': [{'name': 'Predict: 0.0'}]},
#             {'name': 'BodyTemp > 74.55525537265709',
#              'children': [{'name': 'Predict: 2.0'}]}]},
#           {'name': 'BS > 1.8838892321328924',
#            'children': [{'name': 'BS <= 2.2940909197747317',
#              'children': [{'name': 'Age <= 1.0773563138523257',
#                'children': [{'name': 'Predict: 0.0'}]},
#               {'name': 'Age > 1.0773563138523257',
#                'children': [{'name': 'Predict: 2.0'}]}]},
#             {'name': 'BS > 2.2940909197747317',
#              'children': [{'name': 'Predict: 2.0'}]}]}]},
#         {'name': 'HeartRate > 8.99139185543958',
#          'children': [{'name': 'Age <= 1.3002576201665998',
#            'children': [{'name': 'HeartRate <= 10.789670226527495',
#              'children': [{'name': 'BS <= 2.1117790586005807',
#                'children': [{'name': 'Predict: 1.0'}]},
#               {'name': 'BS > 2.1117790586005807',
#                'children': [{'name': 'BS <= 2.2940909197747317',
#                  'children': [{'name': 'Age <= 1.0773563138523257',
#                    'children': [{'name': 'BS <= 2.1284909792082116',
#                      'children': [{'name': 'Predict: 2.0'}]},
#                     {'name': 'BS > 2.1284909792082116',
#                      'children': [{'name': 'Predict: 0.0'}]}]},
#                   {'name': 'Age > 1.0773563138523257',
#                    'children': [{'name': 'Predict: 0.0'}]}]},
#                 {'name': 'BS > 2.2940909197747317',
#                  'children': [{'name': 'Age <= 1.0773563138523257',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'Age > 1.0773563138523257',
#                    'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'DiastolicBP > 4.425254644051889',
#                      'children': [{'name': 'Predict: 2.0'}]}]}]}]}]},
#             {'name': 'HeartRate > 10.789670226527495',
#              'children': [{'name': 'BS <= 2.0510084382091973',
#                'children': [{'name': 'Predict: 2.0'}]},
#               {'name': 'BS > 2.0510084382091973',
#                'children': [{'name': 'BodyTemp <= 73.827887027558',
#                  'children': [{'name': 'Predict: 2.0'}]},
#                 {'name': 'BodyTemp > 73.827887027558',
#                  'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#           {'name': 'Age > 1.3002576201665998',
#            'children': [{'name': 'BS <= 2.1436836343060572',
#              'children': [{'name': 'Age <= 1.3745580556046912',
#                'children': [{'name': 'BS <= 2.081393748404889',
#                  'children': [{'name': 'Predict: 0.0'}]},
#                 {'name': 'BS > 2.081393748404889',
#                  'children': [{'name': 'Predict: 1.0'}]}]},
#               {'name': 'Age > 1.3745580556046912',
#                'children': [{'name': 'BodyTemp <= 74.55525537265709',
#                  'children': [{'name': 'BodyTemp <= 73.827887027558',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'BodyTemp > 73.827887027558',
#                    'children': [{'name': 'Age <= 2.117562409985606',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'Age > 2.117562409985606',
#                      'children': [{'name': 'Predict: 0.0'}]}]}]},
#                 {'name': 'BodyTemp > 74.55525537265709',
#                  'children': [{'name': 'Predict: 0.0'}]}]}]},
#             {'name': 'BS > 2.1436836343060572',
#              'children': [{'name': 'Age <= 2.117562409985606',
#                'children': [{'name': 'Age <= 1.3745580556046912',
#                  'children': [{'name': 'Predict: 1.0'}]},
#                 {'name': 'Age > 1.3745580556046912',
#                  'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                    'children': [{'name': 'BS <= 2.385246850361807',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'BS > 2.385246850361807',
#                      'children': [{'name': 'Predict: 2.0'}]}]},
#                   {'name': 'DiastolicBP > 4.425254644051889',
#                    'children': [{'name': 'Predict: 0.0'}]}]}]},
#               {'name': 'Age > 2.117562409985606',
#                'children': [{'name': 'BS <= 2.2940909197747317',
#                  'children': [{'name': 'BS <= 2.2333202993833483',
#                    'children': [{'name': 'Predict: 2.0'}]},
#                   {'name': 'BS > 2.2333202993833483',
#                    'children': [{'name': 'Predict: 1.0'}]}]},
#                 {'name': 'BS > 2.2940909197747317',
#                  'children': [{'name': 'Predict: 2.0'}]}]}]}]}]}]}]},
#     {'name': 'DiastolicBP > 7.015647606423727',
#      'children': [{'name': 'HeartRate <= 8.325362829110722',
#        'children': [{'name': 'Predict: 1.0'}]},
#       {'name': 'HeartRate > 8.325362829110722',
#        'children': [{'name': 'Predict: 2.0'}]}]}]},
#   {'name': 'BS > 2.5827513666338042',
#    'children': [{'name': 'DiastolicBP <= 6.260116325731941',
#      'children': [{'name': 'BodyTemp <= 73.827887027558',
#        'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#          'children': [{'name': 'HeartRate <= 8.99139185543958',
#            'children': [{'name': 'Predict: 1.0'}]},
#           {'name': 'HeartRate > 8.99139185543958',
#            'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#              'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                'children': [{'name': 'Predict: 2.0'}]},
#               {'name': 'BodyTemp > 71.42757148873099',
#                'children': [{'name': 'Age <= 1.3002576201665998',
#                  'children': [{'name': 'Predict: 2.0'}]},
#                 {'name': 'Age > 1.3002576201665998',
#                  'children': [{'name': 'Predict: 1.0'}]}]}]},
#             {'name': 'DiastolicBP > 4.425254644051889',
#              'children': [{'name': 'BS <= 5.013576182289149',
#                'children': [{'name': 'Predict: 2.0'}]},
#               {'name': 'BS > 5.013576182289149',
#                'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#         {'name': 'DiastolicBP > 5.936317205435461',
#          'children': [{'name': 'Age <= 1.5231589264808743',
#            'children': [{'name': 'Predict: 1.0'}]},
#           {'name': 'Age > 1.5231589264808743',
#            'children': [{'name': 'Age <= 3.306369376995068',
#              'children': [{'name': 'Predict: 2.0'}]},
#             {'name': 'Age > 3.306369376995068',
#              'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#       {'name': 'BodyTemp > 73.827887027558',
#        'children': [{'name': 'Age <= 2.9348671998046107',
#          'children': [{'name': 'Age <= 1.3002576201665998',
#            'children': [{'name': 'Age <= 1.0773563138523257',
#              'children': [{'name': 'Predict: 2.0'}]},
#             {'name': 'Age > 1.0773563138523257',
#              'children': [{'name': 'Predict: 1.0'}]}]},
#           {'name': 'Age > 1.3002576201665998',
#            'children': [{'name': 'Predict: 2.0'}]}]},
#         {'name': 'Age > 2.9348671998046107',
#          'children': [{'name': 'Predict: 1.0'}]}]}]},
#     {'name': 'DiastolicBP > 6.260116325731941',
#      'children': [{'name': 'HeartRate <= 10.057038297565752',
#        'children': [{'name': 'HeartRate <= 9.657420881768438',
#          'children': [{'name': 'DiastolicBP <= 6.655870806094304',
#            'children': [{'name': 'Age <= 3.306369376995068',
#              'children': [{'name': 'Predict: 2.0'}]},
#             {'name': 'Age > 3.306369376995068',
#              'children': [{'name': 'BS <= 4.2539434273968535',
#                'children': [{'name': 'Predict: 1.0'}]},
#               {'name': 'BS > 4.2539434273968535',
#                'children': [{'name': 'Predict: 2.0'}]}]}]},
#           {'name': 'DiastolicBP > 6.655870806094304',
#            'children': [{'name': 'Predict: 2.0'}]}]},
#         {'name': 'HeartRate > 9.657420881768438',
#          'children': [{'name': 'Predict: 2.0'}]}]},
#       {'name': 'HeartRate > 10.057038297565752',
#        'children': [{'name': 'HeartRate <= 10.789670226527495',
#          'children': [{'name': 'BS <= 3.4943106725045583',
#            'children': [{'name': 'Predict: 2.0'}]},
#           {'name': 'BS > 3.4943106725045583',
#            'children': [{'name': 'HeartRate <= 10.323449908097295',
#              'children': [{'name': 'Predict: 2.0'}]},
#             {'name': 'HeartRate > 10.323449908097295',
#              'children': [{'name': 'BS <= 4.2539434273968535',
#                'children': [{'name': 'Predict: 2.0'}]},
#               {'name': 'BS > 4.2539434273968535',
#                'children': [{'name': 'Age <= 2.117562409985606',
#                  'children': [{'name': 'Predict: 2.0'}]},
#                 {'name': 'Age > 2.117562409985606',
#                  'children': [{'name': 'Predict: 1.0'}]}]}]}]}]},
#         {'name': 'HeartRate > 10.789670226527495',
#          'children': [{'name': 'Predict: 2.0'},
#           {'name': 'Tree 1 (weight 1.0):'},
#           {'name': 'DiastolicBP <= 6.655870806094304',
#            'children': [{'name': 'BS <= 2.5827513666338042',
#              'children': [{'name': 'BS <= 2.1436836343060572',
#                'children': [{'name': 'DiastolicBP <= 3.5617903232612766',
#                  'children': [{'name': 'Predict: 0.0'}]},
#                 {'name': 'DiastolicBP > 3.5617903232612766',
#                  'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                    'children': [{'name': 'BodyTemp <= 71.64578199226071',
#                      'children': [{'name': 'HeartRate <= 10.523258615995953',
#                        'children': [{'name': 'DiastolicBP <= 4.92894216451308',
#                          'children': [{'name': 'HeartRate <= 8.325362829110722',
#                            'children': [{'name': 'Predict: 0.0'}]},
#                           {'name': 'HeartRate > 8.325362829110722',
#                            'children': [{'name': 'Age <= 1.3745580556046912',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'Age > 1.3745580556046912',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]},
#                         {'name': 'DiastolicBP > 4.92894216451308',
#                          'children': [{'name': 'Age <= 1.3745580556046912',
#                            'children': [{'name': 'Predict: 0.0'}]},
#                           {'name': 'Age > 1.3745580556046912',
#                            'children': [{'name': 'BS <= 1.8838892321328924',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'BS > 1.8838892321328924',
#                              'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                       {'name': 'HeartRate > 10.523258615995953',
#                        'children': [{'name': 'Age <= 1.151656749290417',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'Age > 1.151656749290417',
#                          'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                            'children': [{'name': 'HeartRate <= 11.18928764232481',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'HeartRate > 11.18928764232481',
#                              'children': [{'name': 'Predict: 1.0'}]}]},
#                           {'name': 'DiastolicBP > 4.425254644051889',
#                            'children': [{'name': 'BS <= 2.0510084382091973',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'BS > 2.0510084382091973',
#                              'children': [{'name': 'Predict: 0.0'}]}]}]}]}]},
#                     {'name': 'BodyTemp > 71.64578199226071',
#                      'children': [{'name': 'Age <= 2.563365022614154',
#                        'children': [{'name': 'BodyTemp <= 73.827887027558',
#                          'children': [{'name': 'DiastolicBP <= 4.785031444381311',
#                            'children': [{'name': 'Predict: 1.0'}]},
#                           {'name': 'DiastolicBP > 4.785031444381311',
#                            'children': [{'name': 'BS <= 2.081393748404889',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'BS > 2.081393748404889',
#                              'children': [{'name': 'Predict: 1.0'}]}]}]},
#                         {'name': 'BodyTemp > 73.827887027558',
#                          'children': [{'name': 'DiastolicBP <= 4.785031444381311',
#                            'children': [{'name': 'Age <= 1.0773563138523257',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'Age > 1.0773563138523257',
#                              'children': [{'name': 'Predict: 2.0'}]}]},
#                           {'name': 'DiastolicBP > 4.785031444381311',
#                            'children': [{'name': 'BS <= 2.1117790586005807',
#                              'children': [{'name': 'Predict: 1.0'}]},
#                             {'name': 'BS > 2.1117790586005807',
#                              'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#                       {'name': 'Age > 2.563365022614154',
#                        'children': [{'name': 'BodyTemp <= 73.827887027558',
#                          'children': [{'name': 'Predict: 1.0'}]},
#                         {'name': 'BodyTemp > 73.827887027558',
#                          'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                   {'name': 'DiastolicBP > 5.936317205435461',
#                    'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                      'children': [{'name': 'BS <= 2.0510084382091973',
#                        'children': [{'name': 'Predict: 0.0'}]},
#                       {'name': 'BS > 2.0510084382091973',
#                        'children': [{'name': 'DiastolicBP <= 6.440004725896651',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'DiastolicBP > 6.440004725896651',
#                          'children': [{'name': 'HeartRate <= 8.858186050173808',
#                            'children': [{'name': 'Predict: 1.0'}]},
#                           {'name': 'HeartRate > 8.858186050173808',
#                            'children': [{'name': 'BS <= 2.081393748404889',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'BS > 2.081393748404889',
#                              'children': [{'name': 'Predict: 1.0'}]}]}]}]}]},
#                     {'name': 'BodyTemp > 71.42757148873099',
#                      'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#               {'name': 'BS > 2.1436836343060572',
#                'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                  'children': [{'name': 'HeartRate <= 10.323449908097295',
#                    'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                      'children': [{'name': 'Predict: 0.0'}]},
#                     {'name': 'DiastolicBP > 4.425254644051889',
#                      'children': [{'name': 'HeartRate <= 9.657420881768438',
#                        'children': [{'name': 'BS <= 2.354861540166115',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'BS > 2.354861540166115',
#                          'children': [{'name': 'HeartRate <= 8.858186050173808',
#                            'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'DiastolicBP > 5.2167636047766175',
#                              'children': [{'name': 'Predict: 1.0'}]}]},
#                           {'name': 'HeartRate > 8.858186050173808',
#                            'children': [{'name': 'Predict: 0.0'}]}]}]},
#                       {'name': 'HeartRate > 9.657420881768438',
#                        'children': [{'name': 'Predict: 0.0'}]}]}]},
#                   {'name': 'HeartRate > 10.323449908097295',
#                    'children': [{'name': 'Age <= 2.117562409985606',
#                      'children': [{'name': 'HeartRate <= 10.789670226527495',
#                        'children': [{'name': 'Predict: 0.0'}]},
#                       {'name': 'HeartRate > 10.789670226527495',
#                        'children': [{'name': 'HeartRate <= 11.18928764232481',
#                          'children': [{'name': 'BS <= 2.2940909197747317',
#                            'children': [{'name': 'Predict: 0.0'}]},
#                           {'name': 'BS > 2.2940909197747317',
#                            'children': [{'name': 'Predict: 1.0'}]}]},
#                         {'name': 'HeartRate > 11.18928764232481',
#                          'children': [{'name': 'Predict: 0.0'}]}]}]},
#                     {'name': 'Age > 2.117562409985606',
#                      'children': [{'name': 'Age <= 2.191862845423697',
#                        'children': [{'name': 'Predict: 1.0'}]},
#                       {'name': 'Age > 2.191862845423697',
#                        'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                          'children': [{'name': 'Predict: 1.0'}]},
#                         {'name': 'DiastolicBP > 5.2167636047766175',
#                          'children': [{'name': 'Predict: 0.0'}]}]}]}]}]},
#                 {'name': 'BodyTemp > 71.42757148873099',
#                  'children': [{'name': 'BS <= 2.2940909197747317',
#                    'children': [{'name': 'BS <= 2.2333202993833483',
#                      'children': [{'name': 'Predict: 2.0'}]},
#                     {'name': 'BS > 2.2333202993833483',
#                      'children': [{'name': 'Age <= 1.3002576201665998',
#                        'children': [{'name': 'Predict: 0.0'}]},
#                       {'name': 'Age > 1.3002576201665998',
#                        'children': [{'name': 'BodyTemp <= 73.827887027558',
#                          'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                            'children': [{'name': 'HeartRate <= 9.657420881768438',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'HeartRate > 9.657420881768438',
#                              'children': [{'name': 'Predict: 1.0'}]}]},
#                           {'name': 'DiastolicBP > 5.936317205435461',
#                            'children': [{'name': 'Predict: 0.0'}]}]},
#                         {'name': 'BodyTemp > 73.827887027558',
#                          'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#                   {'name': 'BS > 2.2940909197747317',
#                    'children': [{'name': 'HeartRate <= 9.657420881768438',
#                      'children': [{'name': 'Predict: 2.0'}]},
#                     {'name': 'HeartRate > 9.657420881768438',
#                      'children': [{'name': 'HeartRate <= 10.789670226527495',
#                        'children': [{'name': 'DiastolicBP <= 4.785031444381311',
#                          'children': [{'name': 'Predict: 1.0'}]},
#                         {'name': 'DiastolicBP > 4.785031444381311',
#                          'children': [{'name': 'BodyTemp <= 73.1005186824589',
#                            'children': [{'name': 'Predict: 2.0'}]},
#                           {'name': 'BodyTemp > 73.1005186824589',
#                            'children': [{'name': 'Predict: 1.0'}]}]}]},
#                       {'name': 'HeartRate > 10.789670226527495',
#                        'children': [{'name': 'Age <= 1.3002576201665998',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'Age > 1.3002576201665998',
#                          'children': [{'name': 'Age <= 2.117562409985606',
#                            'children': [{'name': 'Predict: 1.0'}]},
#                           {'name': 'Age > 2.117562409985606',
#                            'children': [{'name': 'Predict: 2.0'}]}]}]}]}]}]}]}]},
#             {'name': 'BS > 2.5827513666338042',
#              'children': [{'name': 'HeartRate <= 9.657420881768438',
#                'children': [{'name': 'HeartRate <= 8.858186050173808',
#                  'children': [{'name': 'Age <= 1.5231589264808743',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'Age > 1.5231589264808743',
#                    'children': [{'name': 'HeartRate <= 8.325362829110722',
#                      'children': [{'name': 'BS <= 5.013576182289149',
#                        'children': [{'name': 'Age <= 3.306369376995068',
#                          'children': [{'name': 'Predict: 2.0'}]},
#                         {'name': 'Age > 3.306369376995068',
#                          'children': [{'name': 'Predict: 1.0'}]}]},
#                       {'name': 'BS > 5.013576182289149',
#                        'children': [{'name': 'Predict: 2.0'}]}]},
#                     {'name': 'HeartRate > 8.325362829110722',
#                      'children': [{'name': 'Predict: 2.0'}]}]}]},
#                 {'name': 'HeartRate > 8.858186050173808',
#                  'children': [{'name': 'HeartRate <= 8.99139185543958',
#                    'children': [{'name': 'Predict: 1.0'}]},
#                   {'name': 'HeartRate > 8.99139185543958',
#                    'children': [{'name': 'Age <= 2.9348671998046107',
#                      'children': [{'name': 'Predict: 2.0'}]},
#                     {'name': 'Age > 2.9348671998046107',
#                      'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                        'children': [{'name': 'Predict: 2.0'}]},
#                       {'name': 'DiastolicBP > 5.936317205435461',
#                        'children': [{'name': 'BS <= 4.2539434273968535',
#                          'children': [{'name': 'Predict: 1.0'}]},
#                         {'name': 'BS > 4.2539434273968535',
#                          'children': [{'name': 'Predict: 2.0'}]}]}]}]}]}]},
#               {'name': 'HeartRate > 9.657420881768438',
#                'children': [{'name': 'BS <= 3.4943106725045583',
#                  'children': [{'name': 'Age <= 2.117562409985606',
#                    'children': [{'name': 'HeartRate <= 10.789670226527495',
#                      'children': [{'name': 'Predict: 2.0'}]},
#                     {'name': 'HeartRate > 10.789670226527495',
#                      'children': [{'name': 'Predict: 1.0'}]}]},
#                   {'name': 'Age > 2.117562409985606',
#                    'children': [{'name': 'HeartRate <= 10.190244102831524',
#                      'children': [{'name': 'Predict: 1.0'}]},
#                     {'name': 'HeartRate > 10.190244102831524',
#                      'children': [{'name': 'Predict: 2.0'}]}]}]},
#                 {'name': 'BS > 3.4943106725045583',
#                  'children': [{'name': 'HeartRate <= 10.789670226527495',
#                    'children': [{'name': 'BS <= 4.2539434273968535',
#                      'children': [{'name': 'Predict: 2.0'}]},
#                     {'name': 'BS > 4.2539434273968535',
#                      'children': [{'name': 'Age <= 2.9348671998046107',
#                        'children': [{'name': 'Predict: 2.0'}]},
#                       {'name': 'Age > 2.9348671998046107',
#                        'children': [{'name': 'Age <= 3.306369376995068',
#                          'children': [{'name': 'HeartRate <= 10.190244102831524',
#                            'children': [{'name': 'Predict: 2.0'}]},
#                           {'name': 'HeartRate > 10.190244102831524',
#                            'children': [{'name': 'Predict: 1.0'}]}]},
#                         {'name': 'Age > 3.306369376995068',
#                          'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#                   {'name': 'HeartRate > 10.789670226527495',
#                    'children': [{'name': 'Predict: 2.0'}]}]}]}]}]},
#           {'name': 'DiastolicBP > 6.655870806094304',
#            'children': [{'name': 'BS <= 1.8838892321328924',
#              'children': [{'name': 'Predict: 0.0'}]},
#             {'name': 'BS > 1.8838892321328924',
#              'children': [{'name': 'Age <= 1.0773563138523257',
#                'children': [{'name': 'Predict: 0.0'}]},
#               {'name': 'Age > 1.0773563138523257',
#                'children': [{'name': 'HeartRate <= 10.057038297565752',
#                  'children': [{'name': 'HeartRate <= 9.657420881768438',
#                    'children': [{'name': 'DiastolicBP <= 7.015647606423727',
#                      'children': [{'name': 'Age <= 3.6778715541855256',
#                        'children': [{'name': 'HeartRate <= 8.858186050173808',
#                          'children': [{'name': 'Predict: 0.0'}]},
#                         {'name': 'HeartRate > 8.858186050173808',
#                          'children': [{'name': 'Predict: 2.0'}]}]},
#                       {'name': 'Age > 3.6778715541855256',
#                        'children': [{'name': 'Predict: 2.0'}]}]},
#                     {'name': 'DiastolicBP > 7.015647606423727',
#                      'children': [{'name': 'HeartRate <= 8.325362829110722',
#                        'children': [{'name': 'Predict: 1.0'}]},
#                       {'name': 'HeartRate > 8.325362829110722',
#                        'children': [{'name': 'Predict: 2.0'}]}]}]},
#                   {'name': 'HeartRate > 9.657420881768438',
#                    'children': [{'name': 'Predict: 1.0'}]}]},
#                 {'name': 'HeartRate > 10.057038297565752',
#                  'children': [{'name': 'Predict: 2.0'},
#                   {'name': 'Tree 2 (weight 1.0):'},
#                   {'name': 'BS <= 2.5827513666338042',
#                    'children': [{'name': 'BS <= 2.1436836343060572',
#                      'children': [{'name': 'DiastolicBP <= 7.015647606423727',
#                        'children': [{'name': 'BodyTemp <= 72.37315033735982',
#                          'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                            'children': [{'name': 'HeartRate <= 10.190244102831524',
#                              'children': [{'name': 'Age <= 1.151656749290417',
#                                'children': [{'name': 'Predict: 1.0'}]},
#                               {'name': 'Age > 1.151656749290417',
#                                'children': [{'name': 'HeartRate <= 9.657420881768438',
#                                  'children': [{'name': 'Predict: 0.0'}]},
#                                 {'name': 'HeartRate > 9.657420881768438',
#                                  'children': [{'name': 'Age <= 1.671759797357057',
#                                    'children': [{'name': 'Predict: 1.0'}]},
#                                   {'name': 'Age > 1.671759797357057',
#                                    'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                             {'name': 'HeartRate > 10.190244102831524',
#                              'children': [{'name': 'HeartRate <= 11.18928764232481',
#                                'children': [{'name': 'Age <= 1.151656749290417',
#                                  'children': [{'name': 'Predict: 0.0'}]},
#                                 {'name': 'Age > 1.151656749290417',
#                                  'children': [{'name': 'HeartRate <= 10.323449908097295',
#                                    'children': [{'name': 'Predict: 1.0'}]},
#                                   {'name': 'HeartRate > 10.323449908097295',
#                                    'children': [{'name': 'Predict: 0.0'}]}]}]},
#                               {'name': 'HeartRate > 11.18928764232481',
#                                'children': [{'name': 'Predict: 1.0'}]}]}]},
#                           {'name': 'DiastolicBP > 4.425254644051889',
#                            'children': [{'name': 'BS <= 1.8838892321328924',
#                              'children': [{'name': 'HeartRate <= 10.057038297565752',
#                                'children': [{'name': 'Predict: 0.0'}]},
#                               {'name': 'HeartRate > 10.057038297565752',
#                                'children': [{'name': 'Age <= 2.117562409985606',
#                                  'children': [{'name': 'Predict: 0.0'}]},
#                                 {'name': 'Age > 2.117562409985606',
#                                  'children': [{'name': 'Predict: 1.0'}]}]}]},
#                             {'name': 'BS > 1.8838892321328924',
#                              'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                                'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                                  'children': [{'name': 'Age <= 1.151656749290417',
#                                    'children': [{'name': 'Predict: 0.0'}]},
#                                   {'name': 'Age > 1.151656749290417',
#                                    'children': [{'name': 'Predict: 1.0'}]}]},
#                                 {'name': 'BodyTemp > 71.42757148873099',
#                                  'children': [{'name': 'Predict: 0.0'}]}]},
#                               {'name': 'DiastolicBP > 5.936317205435461',
#                                'children': [{'name': 'DiastolicBP <= 6.260116325731941',
#                                  'children': [{'name': 'Age <= 1.5974593619189656',
#                                    'children': [{'name': 'Predict: 0.0'}]},
#                                   {'name': 'Age > 1.5974593619189656',
#                                    'children': [{'name': 'BS <= 2.1117790586005807',
#                                      'children': [{'name': 'Predict: 0.0'}]},
#                                     {'name': 'BS > 2.1117790586005807',
#                                      'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                 {'name': 'DiastolicBP > 6.260116325731941',
#                                  'children': [{'name': 'HeartRate <= 8.858186050173808',
#                                    'children': [{'name': 'BS <= 2.081393748404889',
#                                      'children': [{'name': 'Predict: 1.0'}]},
#                                     {'name': 'BS > 2.081393748404889',
#                                      'children': [{'name': 'Predict: 0.0'}]}]},
#                                   {'name': 'HeartRate > 8.858186050173808',
#                                    'children': [{'name': 'BS <= 2.081393748404889',
#                                      'children': [{'name': 'Predict: 0.0'}]},
#                                     {'name': 'BS > 2.081393748404889',
#                                      'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]}]},
#                         {'name': 'BodyTemp > 72.37315033735982',
#                          'children': [{'name': 'HeartRate <= 8.99139185543958',
#                            'children': [{'name': 'BodyTemp <= 74.55525537265709',
#                              'children': [{'name': 'Predict: 0.0'}]},
#                             {'name': 'BodyTemp > 74.55525537265709',
#                              'children': [{'name': 'Predict: 2.0'}]}]},
#                           {'name': 'HeartRate > 8.99139185543958',
#                            'children': [{'name': 'BodyTemp <= 73.827887027558',
#                              'children': [{'name': 'DiastolicBP <= 5.432629684974271',
#                                'children': [{'name': 'BS <= 2.1117790586005807',
#                                  'children': [{'name': 'Predict: 1.0'}]},
#                                 {'name': 'BS > 2.1117790586005807',
#                                  'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                                    'children': [{'name': 'Predict: 1.0'}]},
#                                   {'name': 'DiastolicBP > 4.425254644051889',
#                                    'children': [{'name': 'Age <= 1.0773563138523257',
#                                      'children': [{'name': 'Predict: 2.0'}]},
#                                     {'name': 'Age > 1.0773563138523257',
#                                      'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                               {'name': 'DiastolicBP > 5.432629684974271',
#                                'children': [{'name': 'Age <= 2.117562409985606',
#                                  'children': [{'name': 'Predict: 1.0'}]},
#                                 {'name': 'Age > 2.117562409985606',
#                                  'children': [{'name': 'BS <= 2.081393748404889',
#                                    'children': [{'name': 'BodyTemp <= 73.1005186824589',
#                                      'children': [{'name': 'Predict: 1.0'}]},
#                                     {'name': 'BodyTemp > 73.1005186824589',
#                                      'children': [{'name': 'Predict: 0.0'}]}]},
#                                   {'name': 'BS > 2.081393748404889',
#                                    'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                             {'name': 'BodyTemp > 73.827887027558',
#                              'children': [{'name': 'HeartRate <= 10.789670226527495',
#                                'children': [{'name': 'Age <= 2.117562409985606',
#                                  'children': [{'name': 'BS <= 2.1117790586005807',
#                                    'children': [{'name': 'Predict: 1.0'}]},
#                                   {'name': 'BS > 2.1117790586005807',
#                                    'children': [{'name': 'Predict: 2.0'}]}]},
#                                 {'name': 'Age > 2.117562409985606',
#                                  'children': [{'name': 'Predict: 0.0'}]}]},
#                               {'name': 'HeartRate > 10.789670226527495',
#                                'children': [{'name': 'Predict: 2.0'}]}]}]}]}]},
#                       {'name': 'DiastolicBP > 7.015647606423727',
#                        'children': [{'name': 'Predict: 2.0'}]}]},
#                     {'name': 'BS > 2.1436836343060572',
#                      'children': [{'name': 'BS <= 2.354861540166115',
#                        'children': [{'name': 'HeartRate <= 10.323449908097295',
#                          'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                            'children': [{'name': 'DiastolicBP <= 7.015647606423727',
#                              'children': [{'name': 'Age <= 1.8203606682332398',
#                                'children': [{'name': 'DiastolicBP <= 5.612518085138982',
#                                  'children': [{'name': 'Age <= 1.5974593619189656',
#                                    'children': [{'name': 'Predict: 0.0'}]},
#                                   {'name': 'Age > 1.5974593619189656',
#                                    'children': [{'name': 'Age <= 1.671759797357057',
#                                      'children': [{'name': 'Predict: 1.0'}]},
#                                     {'name': 'Age > 1.671759797357057',
#                                      'children': [{'name': 'Predict: 0.0'}]}]}]},
#                                 {'name': 'DiastolicBP > 5.612518085138982',
#                                  'children': [{'name': 'Age <= 1.151656749290417',
#                                    'children': [{'name': 'BS <= 2.2940909197747317',
#                                      'children': [{'name': 'Predict: 1.0'}]},
#                                     {'name': 'BS > 2.2940909197747317',
#                                      'children': [{'name': 'Predict: 0.0'}]}]},
#                                   {'name': 'Age > 1.151656749290417',
#                                    'children': [{'name': 'Predict: 0.0'}]}]}]},
#                               {'name': 'Age > 1.8203606682332398',
#                                'children': [{'name': 'Predict: 0.0'}]}]},
#                             {'name': 'DiastolicBP > 7.015647606423727',
#                              'children': [{'name': 'Predict: 2.0'}]}]},
#                           {'name': 'BodyTemp > 71.42757148873099',
#                            'children': [{'name': 'Age <= 1.5231589264808743',
#                              'children': [{'name': 'BS <= 2.2940909197747317',
#                                'children': [{'name': 'Predict: 0.0'}]},
#                               {'name': 'BS > 2.2940909197747317',
#                                'children': [{'name': 'Predict: 2.0'}]}]},
#                             {'name': 'Age > 1.5231589264808743',
#                              'children': [{'name': 'Age <= 2.191862845423697',
#                                'children': [{'name': 'Predict: 2.0'}]},
#                               {'name': 'Age > 2.191862845423697',
#                                'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                         {'name': 'HeartRate > 10.323449908097295',
#                          'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                            'children': [{'name': 'Age <= 1.5231589264808743',
#                              'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                                'children': [{'name': 'Age <= 1.3002576201665998',
#                                  'children': [{'name': 'BodyTemp <= 73.827887027558',
#                                    'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                                      'children': [{'name': 'Predict: 0.0'}]},
#                                     {'name': 'BodyTemp > 71.42757148873099',
#                                      'children': [{'name': 'Predict: 2.0'}]}]},
#                                   {'name': 'BodyTemp > 73.827887027558',
#                                    'children': [{'name': 'Predict: 0.0'}]}]},
#                                 {'name': 'Age > 1.3002576201665998',
#                                  'children': [{'name': 'Predict: 1.0'}]}]},
#                               {'name': 'DiastolicBP > 4.425254644051889',
#                                'children': [{'name': 'Predict: 0.0'}]}]},
#                             {'name': 'Age > 1.5231589264808743',
#                              'children': [{'name': 'Predict: 1.0'}]}]},
#                           {'name': 'DiastolicBP > 5.2167636047766175',
#                            'children': [{'name': 'Predict: 0.0'}]}]}]},
#                       {'name': 'BS > 2.354861540166115',
#                        'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                          'children': [{'name': 'HeartRate <= 10.323449908097295',
#                            'children': [{'name': 'DiastolicBP <= 7.015647606423727',
#                              'children': [{'name': 'DiastolicBP <= 5.2167636047766175',
#                                'children': [{'name': 'Age <= 1.8203606682332398',
#                                  'children': [{'name': 'Predict: 0.0'}]},
#                                 {'name': 'Age > 1.8203606682332398',
#                                  'children': [{'name': 'DiastolicBP <= 4.785031444381311',
#                                    'children': [{'name': 'Age <= 2.3404637162998796',
#                                      'children': [{'name': 'Predict: 1.0'}]},
#                                     {'name': 'Age > 2.3404637162998796',
#                                      'children': [{'name': 'Predict: 0.0'}]}]},
#                                   {'name': 'DiastolicBP > 4.785031444381311',
#                                    'children': [{'name': 'Predict: 0.0'}]}]}]},
#                               {'name': 'DiastolicBP > 5.2167636047766175',
#                                'children': [{'name': 'BS <= 2.385246850361807',
#                                  'children': [{'name': 'Age <= 2.563365022614154',
#                                    'children': [{'name': 'HeartRate <= 8.325362829110722',
#                                      'children': [{'name': 'Predict: 1.0'}]},
#                                     {'name': 'HeartRate > 8.325362829110722',
#                                      'children': [{'name': 'Predict: 0.0'}]}]},
#                                   {'name': 'Age > 2.563365022614154',
#                                    'children': [{'name': 'Predict: 1.0'}]}]},
#                                 {'name': 'BS > 2.385246850361807',
#                                  'children': [{'name': 'DiastolicBP <= 6.260116325731941',
#                                    'children': [{'name': 'Predict: 0.0'}]},
#                                   {'name': 'DiastolicBP > 6.260116325731941',
#                                    'children': [{'name': 'Age <= 1.8203606682332398',
#                                      'children': [{'name': 'Predict: 1.0'}]},
#                                     {'name': 'Age > 1.8203606682332398',
#                                      'children': [{'name': 'Predict: 0.0'}]}]}]}]}]},
#                             {'name': 'DiastolicBP > 7.015647606423727',
#                              'children': [{'name': 'Predict: 2.0'}]}]},
#                           {'name': 'HeartRate > 10.323449908097295',
#                            'children': [{'name': 'DiastolicBP <= 6.655870806094304',
#                              'children': [{'name': 'DiastolicBP <= 4.785031444381311',
#                                'children': [{'name': 'Predict: 0.0'}]},
#                               {'name': 'DiastolicBP > 4.785031444381311',
#                                'children': [{'name': 'HeartRate <= 11.18928764232481',
#                                  'children': [{'name': 'Predict: 1.0'}]},
#                                 {'name': 'HeartRate > 11.18928764232481',
#                                  'children': [{'name': 'Predict: 0.0'}]}]}]},
#                             {'name': 'DiastolicBP > 6.655870806094304',
#                              'children': [{'name': 'Predict: 2.0'}]}]}]},
#                         {'name': 'BodyTemp > 71.42757148873099',
#                          'children': [{'name': 'HeartRate <= 9.657420881768438',
#                            'children': [{'name': 'Predict: 2.0'}]},
#                           {'name': 'HeartRate > 9.657420881768438',
#                            'children': [{'name': 'Age <= 2.117562409985606',
#                              'children': [{'name': 'DiastolicBP <= 4.425254644051889',
#                                'children': [{'name': 'BS <= 2.385246850361807',
#                                  'children': [{'name': 'Predict: 1.0'}]},
#                                 {'name': 'BS > 2.385246850361807',
#                                  'children': [{'name': 'Age <= 1.3002576201665998',
#                                    'children': [{'name': 'Predict: 0.0'}]},
#                                   {'name': 'Age > 1.3002576201665998',
#                                    'children': [{'name': 'Predict: 2.0'}]}]}]},
#                               {'name': 'DiastolicBP > 4.425254644051889',
#                                'children': [{'name': 'HeartRate <= 10.789670226527495',
# ...
#                                                                                                                                               {'name': 'BodyTemp > 74.55525537265709',
#                                                                                                                                                'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#                                                                                                                                         {'name': 'Age > 2.117562409985606',
#                                                                                                                                          'children': [{'name': 'Age <= 2.3404637162998796',
#                                                                                                                                            'children': [{'name': 'Age <= 2.191862845423697',
#                                                                                                                                              'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                             {'name': 'Age > 2.191862845423697',
#                                                                                                                                              'children': [{'name': 'BS <= 2.2940909197747317',
#                                                                                                                                                'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                                                               {'name': 'BS > 2.2940909197747317',
#                                                                                                                                                'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                                                                                                                           {'name': 'Age > 2.3404637162998796',
#                                                                                                                                            'children': [{'name': 'Predict: 2.0'}]}]}]}]}]},
#                                                                                                                                   {'name': 'DiastolicBP > 7.015647606423727',
#                                                                                                                                    'children': [{'name': 'HeartRate <= 8.325362829110722',
#                                                                                                                                      'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                                                     {'name': 'HeartRate > 8.325362829110722',
#                                                                                                                                      'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                                                                                                                 {'name': 'BS > 2.5827513666338042',
#                                                                                                                                  'children': [{'name': 'BodyTemp <= 73.827887027558',
#                                                                                                                                    'children': [{'name': 'BS <= 3.4943106725045583',
#                                                                                                                                      'children': [{'name': 'HeartRate <= 9.657420881768438',
#                                                                                                                                        'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                       {'name': 'HeartRate > 9.657420881768438',
#                                                                                                                                        'children': [{'name': 'HeartRate <= 10.190244102831524',
#                                                                                                                                          'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                                                         {'name': 'HeartRate > 10.190244102831524',
#                                                                                                                                          'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                                                                                                                                            'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                           {'name': 'BodyTemp > 71.42757148873099',
#                                                                                                                                            'children': [{'name': 'Age <= 1.3002576201665998',
#                                                                                                                                              'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                             {'name': 'Age > 1.3002576201665998',
#                                                                                                                                              'children': [{'name': 'Predict: 1.0'}]}]}]}]}]},
#                                                                                                                                     {'name': 'BS > 3.4943106725045583',
#                                                                                                                                      'children': [{'name': 'DiastolicBP <= 6.260116325731941',
#                                                                                                                                        'children': [{'name': 'HeartRate <= 9.657420881768438',
#                                                                                                                                          'children': [{'name': 'Age <= 3.306369376995068',
#                                                                                                                                            'children': [{'name': 'BS <= 5.013576182289149',
#                                                                                                                                              'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                             {'name': 'BS > 5.013576182289149',
#                                                                                                                                              'children': [{'name': 'Predict: 1.0'}]}]},
#                                                                                                                                           {'name': 'Age > 3.306369376995068',
#                                                                                                                                            'children': [{'name': 'HeartRate <= 8.99139185543958',
#                                                                                                                                              'children': [{'name': 'Age <= 4.123674166814074',
#                                                                                                                                                'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                                                               {'name': 'Age > 4.123674166814074',
#                                                                                                                                                'children': [{'name': 'DiastolicBP <= 5.936317205435461',
#                                                                                                                                                  'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                                 {'name': 'DiastolicBP > 5.936317205435461',
#                                                                                                                                                  'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                                                                                                             {'name': 'HeartRate > 8.99139185543958',
#                                                                                                                                              'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                                                                                                                         {'name': 'HeartRate > 9.657420881768438',
#                                                                                                                                          'children': [{'name': 'Predict: 2.0'}]}]},
#                                                                                                                                       {'name': 'DiastolicBP > 6.260116325731941',
#                                                                                                                                        'children': [{'name': 'BS <= 5.013576182289149',
#                                                                                                                                          'children': [{'name': 'HeartRate <= 9.657420881768438',
#                                                                                                                                            'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                           {'name': 'HeartRate > 9.657420881768438',
#                                                                                                                                            'children': [{'name': 'BodyTemp <= 71.42757148873099',
#                                                                                                                                              'children': [{'name': 'HeartRate <= 10.789670226527495',
#                                                                                                                                                'children': [{'name': 'HeartRate <= 10.323449908097295',
#                                                                                                                                                  'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                                 {'name': 'HeartRate > 10.323449908097295',
#                                                                                                                                                  'children': [{'name': 'Age <= 2.117562409985606',
#                                                                                                                                                    'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                                   {'name': 'Age > 2.117562409985606',
#                                                                                                                                                    'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                                                                                                               {'name': 'HeartRate > 10.789670226527495',
#                                                                                                                                                'children': [{'name': 'Predict: 2.0'}]}]},
#                                                                                                                                             {'name': 'BodyTemp > 71.42757148873099',
#                                                                                                                                              'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                                                                                                                         {'name': 'BS > 5.013576182289149',
#                                                                                                                                          'children': [{'name': 'Predict: 2.0'}]}]}]}]},
#                                                                                                                                   {'name': 'BodyTemp > 73.827887027558',
#                                                                                                                                    'children': [{'name': 'BS <= 3.4943106725045583',
#                                                                                                                                      'children': [{'name': 'HeartRate <= 10.190244102831524',
#                                                                                                                                        'children': [{'name': 'Predict: 2.0'}]},
#                                                                                                                                       {'name': 'HeartRate > 10.190244102831524',
#                                                                                                                                        'children': [{'name': 'Age <= 1.3002576201665998',
#                                                                                                                                          'children': [{'name': 'Predict: 1.0'}]},
#                                                                                                                                         {'name': 'Age > 1.3002576201665998',
#                                                                                                                                          'children': [{'name': 'Predict: 2.0'}]}]}]},
#                                                                                                                                     {'name': 'BS > 3.4943106725045583',
#                                                                                                                                      'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]}

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
# measure model performance
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
model = rfc.fit(train_data)
# predict response
predictions = model.transform(test_data)
# BinaryClassificationEva.luator
evaluator = BinaryClassificationEvaluator(labelCol="RiskLevelIndex", rawPredictionCol="prediction", metricName='areaUnderROC')
# Make predicitons
predictionAndTarget = predictions.select("RiskLevelIndex", "prediction")
# measure area under curve
auc = evaluator.evaluate(predictionAndTarget)
# Returns as a list (false positive rate, true positive rate)
preds = predictions.select('RiskLevelIndex','probability').rdd.map(lambda row: (float(row['probability'][1]),
                                                                                float(row['RiskLevelIndex'])))
roc = CurveMetrics(preds).get_curve('roc')

plt.figure()
x_val = [x[0] for x in roc]
y_val = [x[1] for x in roc]
plt.title('ROC, AUC= '+str(auc))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(x_val, y_val)

# %%
predictions.select('RiskLevelIndex').toPandas().value_counts()/predictions.count()
# Out:
# RiskLevelIndex
# 0.0               0.382222
# 1.0               0.346667
# 2.0               0.271111
# dtype: float64

# %%
# Make predicitons
predictionAndTarget = predictions.select("RiskLevelIndex", "prediction").where(predictions.prediction==1)
# measure area under curve
auc = evaluator.evaluate(predictionAndTarget)
# Returns as a list (false positive rate, true positive rate)
prediction1=predictions.select('RiskLevelIndex','probability').where(predictions.prediction==1)
preds = prediction1.rdd.map(lambda row: (float(row['probability'][1]), float(row['RiskLevelIndex'])))
roc = CurveMetrics(preds).get_curve('roc')
x_val = [x[0] for x in roc]
y_val = [x[1] for x in roc]
plt.plot(x_val, y_val, label=f"(mid risk (label:1), auc= {auc})")
    
plt.title('Receiver Operating Characteristic ')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()

# %%
# receiver operating characterics for "high risk"
from pyspark.ml.evaluation import BinaryClassificationEvaluator
# measure model performance
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
model = rfc.fit(train_data)
# predict response
predictions = model.transform(test_data)
# BinaryClassificationEva.luator
evaluator = BinaryClassificationEvaluator(labelCol="RiskLevelIndex", rawPredictionCol="prediction", metricName='areaUnderROC')
# Make predicitons
predictionAndTarget = predictions.select("RiskLevelIndex", "prediction").where(predictions.prediction==0.0)
# measure area under curve
auc = evaluator.evaluate(predictionAndTarget)

plt.figure()
for i in range(0,3):
    # Make predicitons
    predictionAndTarget = predictions.select("RiskLevelIndex", "prediction").where(predictions.prediction==i)
    # measure area under curve
    auc = evaluator.evaluate(predictionAndTarget)
    # Returns as a list (false positive rate, true positive rate)
    prediction1=predictions.select('RiskLevelIndex','probability').where(predictions.prediction==i)
    preds = prediction1.rdd.map(lambda row: (float(row['probability'][1]), float(row['RiskLevelIndex'])))
    roc = CurveMetrics(preds).get_curve('roc')
    x_val = [x[0] for x in roc]
    y_val = [x[1] for x in roc]
    plt.plot(x_val, y_val, label=f"({i}, auc= {auc})")
    
plt.title('Receiver Operating Characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()

# %%
# 8.4

# %%
from pyspark.mllib.evaluation import MulticlassMetrics
from pyspark.ml.evaluation import BinaryClassificationEvaluator
# measure model performance
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
model = rfc.fit(train_data)
# predict response
predictions = model.transform(test_data)
# Metrics
predictionRDD = predictions.select(['RiskLevelIndex', 'prediction']).rdd.map(lambda line: (line[1], line[0]))
metrics = MulticlassMetrics(predictionRDD)
# Confusion Matrix
print('Confusion Matrix \n', metrics.confusionMatrix().toArray())
print('\nAccuracy =', metrics.accuracy)
# Out:
# Confusion Matrix
#  [[71. 14.  1.]
#  [13. 62.  3.]
#  [ 1.  5. 55.]]
#
# Accuracy = 0.8355555555555556

# %%
# correlation in between features 'SystolicBP' and 'DiastolicBP'
data.select('SystolicBP', 'DiastolicBP').toPandas().corr()
# Out:
#              SystolicBP  DiastolicBP
# SystolicBP     1.000000     0.786854
# DiastolicBP    0.786854     1.000000

# %%
# calculate performance accuracy on all the features
data_changed=data.select(data.columns[0:8])
data_changed = data_changed.drop('SystolicBP')
# collect the input features
assembler = VectorAssembler(
        inputCols=['Age','DiastolicBP','BS','BodyTemp','HeartRate'], outputCol="features")
# transform the data
data_changed=assembler.transform(data_changed)
# standardize the feature values
standardScaler=StandardScaler()
standardScaler.setInputCol('features')
model=standardScaler.fit(data_changed)
model.setOutputCol('features_scaled')
data_changed=model.transform(data_changed)

# %%
from pyspark.mllib.evaluation import MulticlassMetrics
from pyspark.ml.evaluation import BinaryClassificationEvaluator
# splitting data into training and test data set
train_data, test_data = data_changed.randomSplit(weights=[0.75,0.25], seed=1)
# measure model performance
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
model = rfc.fit(train_data)
# predict response
predictions = model.transform(test_data)
# Metrics
predictionRDD = predictions.select(['RiskLevelIndex', 'prediction']).rdd.map(lambda line: (line[1], line[0]))
metrics = MulticlassMetrics(predictionRDD)
# Confusion Matrix
print('Confusion Matrix \n', metrics.confusionMatrix().toArray())
print('\nAccuracy =', metrics.accuracy)
# Out:
# Confusion Matrix
#  [[71. 14.  1.]
#  [13. 62.  3.]
#  [ 1.  5. 55.]]
#
# Accuracy = 0.8355555555555556

# %%
from pyspark.ml import Pipeline
# prepare data and model
pipeline = Pipeline(stages=[rfc])
model = pipeline.fit(data_changed)
tree_model_classifier = model.stages[0]
print(tree_model_classifier.toDebugString)
# Out:
# RandomForestClassificationModel: uid=RandomForestClassifier_ee60ae45a8fe, numTrees=20, numClasses=3, numFeatures=5
#   Tree 0 (weight 1.0):
#     If (feature 2 <= 2.5827513666338042)
#      If (feature 1 <= 7.015647606423727)
#       If (feature 3 <= 72.37315033735982)
#        If (feature 1 <= 3.5617903232612766)
#         Predict: 0.0
#        Else (feature 1 > 3.5617903232612766)
#         If (feature 0 <= 1.0773563138523257)
#          If (feature 2 <= 2.081393748404889)
#           Predict: 1.0
#          Else (feature 2 > 2.081393748404889)
#           Predict: 0.0
#         Else (feature 0 > 1.0773563138523257)
#          If (feature 2 <= 2.1284909792082116)
#           If (feature 1 <= 5.936317205435461)
#            If (feature 1 <= 4.785031444381311)
#             If (feature 0 <= 1.3745580556046912)
#              If (feature 1 <= 3.957544803623641)
#               Predict: 1.0
#              Else (feature 1 > 3.957544803623641)
#               Predict: 0.0
#             Else (feature 0 > 1.3745580556046912)
#              Predict: 0.0
#            Else (feature 1 > 4.785031444381311)
#             If (feature 4 <= 10.323449908097295)
#              If (feature 0 <= 1.3745580556046912)
#               Predict: 0.0
#              Else (feature 0 > 1.3745580556046912)
#               Predict: 1.0
#             Else (feature 4 > 10.323449908097295)
#              If (feature 2 <= 2.1117790586005807)
#               Predict: 1.0
#              Else (feature 2 > 2.1117790586005807)
#               Predict: 2.0
#           Else (feature 1 > 5.936317205435461)
#            If (feature 2 <= 2.0510084382091973)
#             Predict: 0.0
#            Else (feature 2 > 2.0510084382091973)
#             If (feature 0 <= 1.671759797357057)
#              If (feature 2 <= 2.081393748404889)
#               Predict: 1.0
#              Else (feature 2 > 2.081393748404889)
#               Predict: 0.0
#             Else (feature 0 > 1.671759797357057)
#              If (feature 0 <= 1.8203606682332398)
#               Predict: 1.0
#              Else (feature 0 > 1.8203606682332398)
#               Predict: 0.0
#          Else (feature 2 > 2.1284909792082116)
#           If (feature 2 <= 2.354861540166115)
#            If (feature 1 <= 5.2167636047766175)
#             If (feature 0 <= 2.191862845423697)
#              If (feature 0 <= 2.117562409985606)
#               Predict: 0.0
#              Else (feature 0 > 2.117562409985606)
#               Predict: 1.0
#             Else (feature 0 > 2.191862845423697)
#              Predict: 0.0
#            Else (feature 1 > 5.2167636047766175)
#             If (feature 4 <= 9.657420881768438)
#              Predict: 0.0
#             Else (feature 4 > 9.657420881768438)
#              If (feature 0 <= 1.5231589264808743)
#               Predict: 1.0
#              Else (feature 0 > 1.5231589264808743)
#               Predict: 0.0
#           Else (feature 2 > 2.354861540166115)
#            If (feature 4 <= 10.323449908097295)
#             If (feature 0 <= 1.8203606682332398)
#              If (feature 1 <= 5.936317205435461)
#               Predict: 0.0
#              Else (feature 1 > 5.936317205435461)
#               Predict: 1.0
#             Else (feature 0 > 1.8203606682332398)
#              Predict: 0.0
#            Else (feature 4 > 10.323449908097295)
#             Predict: 1.0
#       Else (feature 3 > 72.37315033735982)
#        If (feature 4 <= 8.99139185543958)
#         If (feature 2 <= 1.8838892321328924)
#          If (feature 3 <= 74.55525537265709)
#           Predict: 0.0
#          Else (feature 3 > 74.55525537265709)
#           Predict: 2.0
#         Else (feature 2 > 1.8838892321328924)
#          If (feature 2 <= 2.2940909197747317)
#           If (feature 0 <= 1.0773563138523257)
#            Predict: 0.0
#           Else (feature 0 > 1.0773563138523257)
#            Predict: 2.0
#          Else (feature 2 > 2.2940909197747317)
#           Predict: 2.0
#        Else (feature 4 > 8.99139185543958)
#         If (feature 0 <= 1.3002576201665998)
#          If (feature 4 <= 10.789670226527495)
#           If (feature 2 <= 2.1117790586005807)
#            Predict: 1.0
#           Else (feature 2 > 2.1117790586005807)
#            If (feature 2 <= 2.2940909197747317)
#             If (feature 0 <= 1.0773563138523257)
#              If (feature 2 <= 2.1284909792082116)
#               Predict: 2.0
#              Else (feature 2 > 2.1284909792082116)
#               Predict: 0.0
#             Else (feature 0 > 1.0773563138523257)
#              Predict: 0.0
#            Else (feature 2 > 2.2940909197747317)
#             If (feature 0 <= 1.0773563138523257)
#              Predict: 1.0
#             Else (feature 0 > 1.0773563138523257)
#              If (feature 1 <= 4.425254644051889)
#               Predict: 0.0
#              Else (feature 1 > 4.425254644051889)
#               Predict: 2.0
#          Else (feature 4 > 10.789670226527495)
#           If (feature 2 <= 2.0510084382091973)
#            Predict: 2.0
#           Else (feature 2 > 2.0510084382091973)
#            If (feature 3 <= 73.827887027558)
#             Predict: 2.0
#            Else (feature 3 > 73.827887027558)
#             Predict: 0.0
#         Else (feature 0 > 1.3002576201665998)
#          If (feature 2 <= 2.1436836343060572)
#           If (feature 0 <= 1.3745580556046912)
#            If (feature 2 <= 2.081393748404889)
#             Predict: 0.0
#            Else (feature 2 > 2.081393748404889)
#             Predict: 1.0
#           Else (feature 0 > 1.3745580556046912)
#            If (feature 3 <= 74.55525537265709)
#             If (feature 3 <= 73.827887027558)
#              Predict: 1.0
#             Else (feature 3 > 73.827887027558)
#              If (feature 0 <= 2.117562409985606)
#               Predict: 1.0
#              Else (feature 0 > 2.117562409985606)
#               Predict: 0.0
#            Else (feature 3 > 74.55525537265709)
#             Predict: 0.0
#          Else (feature 2 > 2.1436836343060572)
#           If (feature 0 <= 2.117562409985606)
#            If (feature 0 <= 1.3745580556046912)
#             Predict: 1.0
#            Else (feature 0 > 1.3745580556046912)
#             If (feature 1 <= 4.425254644051889)
#              If (feature 2 <= 2.385246850361807)
#               Predict: 1.0
#              Else (feature 2 > 2.385246850361807)
#               Predict: 2.0
#             Else (feature 1 > 4.425254644051889)
#              Predict: 0.0
#           Else (feature 0 > 2.117562409985606)
#            If (feature 2 <= 2.2940909197747317)
#             If (feature 2 <= 2.2333202993833483)
#              Predict: 2.0
#             Else (feature 2 > 2.2333202993833483)
#              Predict: 1.0
#            Else (feature 2 > 2.2940909197747317)
#             Predict: 2.0
#      Else (feature 1 > 7.015647606423727)
#       If (feature 4 <= 8.325362829110722)
#        Predict: 1.0
#       Else (feature 4 > 8.325362829110722)
#        Predict: 2.0
#     Else (feature 2 > 2.5827513666338042)
#      If (feature 1 <= 6.260116325731941)
#       If (feature 3 <= 73.827887027558)
#        If (feature 1 <= 5.936317205435461)
#         If (feature 4 <= 8.99139185543958)
#          Predict: 1.0
#         Else (feature 4 > 8.99139185543958)
#          If (feature 1 <= 4.425254644051889)
#           If (feature 3 <= 71.42757148873099)
#            Predict: 2.0
#           Else (feature 3 > 71.42757148873099)
#            If (feature 0 <= 1.3002576201665998)
#             Predict: 2.0
#            Else (feature 0 > 1.3002576201665998)
#             Predict: 1.0
#          Else (feature 1 > 4.425254644051889)
#           If (feature 2 <= 5.013576182289149)
#            Predict: 2.0
#           Else (feature 2 > 5.013576182289149)
#            Predict: 1.0
#        Else (feature 1 > 5.936317205435461)
#         If (feature 0 <= 1.5231589264808743)
#          Predict: 1.0
#         Else (feature 0 > 1.5231589264808743)
#          If (feature 0 <= 3.306369376995068)
#           Predict: 2.0
#          Else (feature 0 > 3.306369376995068)
#           Predict: 1.0
#       Else (feature 3 > 73.827887027558)
#        If (feature 0 <= 2.9348671998046107)
#         If (feature 0 <= 1.3002576201665998)
#          If (feature 0 <= 1.0773563138523257)
#           Predict: 2.0
#          Else (feature 0 > 1.0773563138523257)
#           Predict: 1.0
#         Else (feature 0 > 1.3002576201665998)
#          Predict: 2.0
#        Else (feature 0 > 2.9348671998046107)
#         Predict: 1.0
#      Else (feature 1 > 6.260116325731941)
#       If (feature 4 <= 10.057038297565752)
#        If (feature 4 <= 9.657420881768438)
#         If (feature 1 <= 6.655870806094304)
#          If (feature 0 <= 3.306369376995068)
#           Predict: 2.0
#          Else (feature 0 > 3.306369376995068)
#           If (feature 2 <= 4.2539434273968535)
#            Predict: 1.0
#           Else (feature 2 > 4.2539434273968535)
#            Predict: 2.0
#         Else (feature 1 > 6.655870806094304)
#          Predict: 2.0
#        Else (feature 4 > 9.657420881768438)
#         Predict: 2.0
#       Else (feature 4 > 10.057038297565752)
#        If (feature 4 <= 10.789670226527495)
#         If (feature 2 <= 3.4943106725045583)
#          Predict: 2.0
#         Else (feature 2 > 3.4943106725045583)
#          If (feature 4 <= 10.323449908097295)
#           Predict: 2.0
#          Else (feature 4 > 10.323449908097295)
#           If (feature 2 <= 4.2539434273968535)
#            Predict: 2.0
#           Else (feature 2 > 4.2539434273968535)
#            If (feature 0 <= 2.117562409985606)
#             Predict: 2.0
#            Else (feature 0 > 2.117562409985606)
#             Predict: 1.0
#        Else (feature 4 > 10.789670226527495)
#         Predict: 2.0
#   Tree 1 (weight 1.0):
#     If (feature 1 <= 6.655870806094304)
#      If (feature 2 <= 2.5827513666338042)
#       If (feature 2 <= 2.1436836343060572)
#        If (feature 1 <= 3.5617903232612766)
#         Predict: 0.0
#        Else (feature 1 > 3.5617903232612766)
#         If (feature 1 <= 5.936317205435461)
#          If (feature 3 <= 71.64578199226071)
#           If (feature 4 <= 10.523258615995953)
#            If (feature 1 <= 4.92894216451308)
#             If (feature 4 <= 8.325362829110722)
#              Predict: 0.0
#             Else (feature 4 > 8.325362829110722)
#              If (feature 0 <= 1.3745580556046912)
#               Predict: 1.0
#              Else (feature 0 > 1.3745580556046912)
#               Predict: 0.0
#            Else (feature 1 > 4.92894216451308)
#             If (feature 0 <= 1.3745580556046912)
#              Predict: 0.0
#             Else (feature 0 > 1.3745580556046912)
#              If (feature 2 <= 1.8838892321328924)
#               Predict: 0.0
#              Else (feature 2 > 1.8838892321328924)
#               Predict: 1.0
#           Else (feature 4 > 10.523258615995953)
#            If (feature 0 <= 1.151656749290417)
#             Predict: 0.0
#            Else (feature 0 > 1.151656749290417)
#             If (feature 1 <= 4.425254644051889)
#              If (feature 4 <= 11.18928764232481)
#               Predict: 0.0
#              Else (feature 4 > 11.18928764232481)
#               Predict: 1.0
#             Else (feature 1 > 4.425254644051889)
#              If (feature 2 <= 2.0510084382091973)
#               Predict: 1.0
#              Else (feature 2 > 2.0510084382091973)
#               Predict: 0.0
#          Else (feature 3 > 71.64578199226071)
#           If (feature 0 <= 2.563365022614154)
#            If (feature 3 <= 73.827887027558)
#             If (feature 1 <= 4.785031444381311)
#              Predict: 1.0
#             Else (feature 1 > 4.785031444381311)
#              If (feature 2 <= 2.081393748404889)
#               Predict: 0.0
#              Else (feature 2 > 2.081393748404889)
#               Predict: 1.0
#            Else (feature 3 > 73.827887027558)
#             If (feature 1 <= 4.785031444381311)
#              If (feature 0 <= 1.0773563138523257)
#               Predict: 0.0
#              Else (feature 0 > 1.0773563138523257)
#               Predict: 2.0
#             Else (feature 1 > 4.785031444381311)
#              If (feature 2 <= 2.1117790586005807)
#               Predict: 1.0
#              Else (feature 2 > 2.1117790586005807)
#               Predict: 2.0
#           Else (feature 0 > 2.563365022614154)
#            If (feature 3 <= 73.827887027558)
#             Predict: 1.0
#            Else (feature 3 > 73.827887027558)
#             Predict: 0.0
#         Else (feature 1 > 5.936317205435461)
#          If (feature 3 <= 71.42757148873099)
#           If (feature 2 <= 2.0510084382091973)
#            Predict: 0.0
#           Else (feature 2 > 2.0510084382091973)
#            If (feature 1 <= 6.440004725896651)
#             Predict: 0.0
#            Else (feature 1 > 6.440004725896651)
#             If (feature 4 <= 8.858186050173808)
#              Predict: 1.0
#             Else (feature 4 > 8.858186050173808)
#              If (feature 2 <= 2.081393748404889)
#               Predict: 0.0
#              Else (feature 2 > 2.081393748404889)
#               Predict: 1.0
#          Else (feature 3 > 71.42757148873099)
#           Predict: 1.0
#       Else (feature 2 > 2.1436836343060572)
#        If (feature 3 <= 71.42757148873099)
#         If (feature 4 <= 10.323449908097295)
#          If (feature 1 <= 4.425254644051889)
#           Predict: 0.0
#          Else (feature 1 > 4.425254644051889)
#           If (feature 4 <= 9.657420881768438)
#            If (feature 2 <= 2.354861540166115)
#             Predict: 0.0
#            Else (feature 2 > 2.354861540166115)
#             If (feature 4 <= 8.858186050173808)
#              If (feature 1 <= 5.2167636047766175)
#               Predict: 0.0
#              Else (feature 1 > 5.2167636047766175)
#               Predict: 1.0
#             Else (feature 4 > 8.858186050173808)
#              Predict: 0.0
#           Else (feature 4 > 9.657420881768438)
#            Predict: 0.0
#         Else (feature 4 > 10.323449908097295)
#          If (feature 0 <= 2.117562409985606)
#           If (feature 4 <= 10.789670226527495)
#            Predict: 0.0
#           Else (feature 4 > 10.789670226527495)
#            If (feature 4 <= 11.18928764232481)
#             If (feature 2 <= 2.2940909197747317)
#              Predict: 0.0
#             Else (feature 2 > 2.2940909197747317)
#              Predict: 1.0
#            Else (feature 4 > 11.18928764232481)
#             Predict: 0.0
#          Else (feature 0 > 2.117562409985606)
#           If (feature 0 <= 2.191862845423697)
#            Predict: 1.0
#           Else (feature 0 > 2.191862845423697)
#            If (feature 1 <= 5.2167636047766175)
#             Predict: 1.0
#            Else (feature 1 > 5.2167636047766175)
#             Predict: 0.0
#        Else (feature 3 > 71.42757148873099)
#         If (feature 2 <= 2.2940909197747317)
#          If (feature 2 <= 2.2333202993833483)
#           Predict: 2.0
#          Else (feature 2 > 2.2333202993833483)
#           If (feature 0 <= 1.3002576201665998)
#            Predict: 0.0
#           Else (feature 0 > 1.3002576201665998)
#            If (feature 3 <= 73.827887027558)
#             If (feature 1 <= 5.936317205435461)
#              If (feature 4 <= 9.657420881768438)
#               Predict: 0.0
#              Else (feature 4 > 9.657420881768438)
#               Predict: 1.0
#             Else (feature 1 > 5.936317205435461)
#              Predict: 0.0
#            Else (feature 3 > 73.827887027558)
#             Predict: 2.0
#         Else (feature 2 > 2.2940909197747317)
#          If (feature 4 <= 9.657420881768438)
#           Predict: 2.0
#          Else (feature 4 > 9.657420881768438)
#           If (feature 4 <= 10.789670226527495)
#            If (feature 1 <= 4.785031444381311)
#             Predict: 1.0
#            Else (feature 1 > 4.785031444381311)
#             If (feature 3 <= 73.1005186824589)
#              Predict: 2.0
#             Else (feature 3 > 73.1005186824589)
#              Predict: 1.0
#           Else (feature 4 > 10.789670226527495)
#            If (feature 0 <= 1.3002576201665998)
#             Predict: 0.0
#            Else (feature 0 > 1.3002576201665998)
#             If (feature 0 <= 2.117562409985606)
#              Predict: 1.0
#             Else (feature 0 > 2.117562409985606)
#              Predict: 2.0
#      Else (feature 2 > 2.5827513666338042)
#       If (feature 4 <= 9.657420881768438)
#        If (feature 4 <= 8.858186050173808)
#         If (feature 0 <= 1.5231589264808743)
#          Predict: 1.0
#         Else (feature 0 > 1.5231589264808743)
#          If (feature 4 <= 8.325362829110722)
#           If (feature 2 <= 5.013576182289149)
#            If (feature 0 <= 3.306369376995068)
#             Predict: 2.0
#            Else (feature 0 > 3.306369376995068)
#             Predict: 1.0
#           Else (feature 2 > 5.013576182289149)
#            Predict: 2.0
#          Else (feature 4 > 8.325362829110722)
#           Predict: 2.0
#        Else (feature 4 > 8.858186050173808)
#         If (feature 4 <= 8.99139185543958)
#          Predict: 1.0
#         Else (feature 4 > 8.99139185543958)
#          If (feature 0 <= 2.9348671998046107)
#           Predict: 2.0
#          Else (feature 0 > 2.9348671998046107)
#           If (feature 1 <= 5.936317205435461)
#            Predict: 2.0
#           Else (feature 1 > 5.936317205435461)
#            If (feature 2 <= 4.2539434273968535)
#             Predict: 1.0
#            Else (feature 2 > 4.2539434273968535)
#             Predict: 2.0
#       Else (feature 4 > 9.657420881768438)
#        If (feature 2 <= 3.4943106725045583)
#         If (feature 0 <= 2.117562409985606)
#          If (feature 4 <= 10.789670226527495)
#           Predict: 2.0
#          Else (feature 4 > 10.789670226527495)
#           Predict: 1.0
#         Else (feature 0 > 2.117562409985606)
#          If (feature 4 <= 10.190244102831524)
#           Predict: 1.0
#          Else (feature 4 > 10.190244102831524)
#           Predict: 2.0
#        Else (feature 2 > 3.4943106725045583)
#         If (feature 4 <= 10.789670226527495)
#          If (feature 2 <= 4.2539434273968535)
#           Predict: 2.0
#          Else (feature 2 > 4.2539434273968535)
#           If (feature 0 <= 2.9348671998046107)
#            Predict: 2.0
#           Else (feature 0 > 2.9348671998046107)
#            If (feature 0 <= 3.306369376995068)
#             If (feature 4 <= 10.190244102831524)
#              Predict: 2.0
#             Else (feature 4 > 10.190244102831524)
#              Predict: 1.0
#            Else (feature 0 > 3.306369376995068)
#             Predict: 2.0
#         Else (feature 4 > 10.789670226527495)
#          Predict: 2.0
#     Else (feature 1 > 6.655870806094304)
#      If (feature 2 <= 1.8838892321328924)
#       Predict: 0.0
#      Else (feature 2 > 1.8838892321328924)
#       If (feature 0 <= 1.0773563138523257)
#        Predict: 0.0
#       Else (feature 0 > 1.0773563138523257)
#        If (feature 4 <= 10.057038297565752)
#         If (feature 4 <= 9.657420881768438)
#          If (feature 1 <= 7.015647606423727)
#           If (feature 0 <= 3.6778715541855256)
#            If (feature 4 <= 8.858186050173808)
#             Predict: 0.0
#            Else (feature 4 > 8.858186050173808)
#             Predict: 2.0
#           Else (feature 0 > 3.6778715541855256)
#            Predict: 2.0
#          Else (feature 1 > 7.015647606423727)
#           If (feature 4 <= 8.325362829110722)
#            Predict: 1.0
#           Else (feature 4 > 8.325362829110722)
#            Predict: 2.0
#         Else (feature 4 > 9.657420881768438)
#          Predict: 1.0
#        Else (feature 4 > 10.057038297565752)
#         Predict: 2.0
#   Tree 2 (weight 1.0):
#     If (feature 2 <= 2.5827513666338042)
#      If (feature 2 <= 2.1436836343060572)
#       If (feature 1 <= 7.015647606423727)
#        If (feature 3 <= 72.37315033735982)
#         If (feature 1 <= 4.425254644051889)
#          If (feature 4 <= 10.190244102831524)
#           If (feature 0 <= 1.151656749290417)
#            Predict: 1.0
#           Else (feature 0 > 1.151656749290417)
#            If (feature 4 <= 9.657420881768438)
#             Predict: 0.0
#            Else (feature 4 > 9.657420881768438)
#             If (feature 0 <= 1.671759797357057)
#              Predict: 1.0
#             Else (feature 0 > 1.671759797357057)
#              Predict: 0.0
#          Else (feature 4 > 10.190244102831524)
#           If (feature 4 <= 11.18928764232481)
#            If (feature 0 <= 1.151656749290417)
#             Predict: 0.0
#            Else (feature 0 > 1.151656749290417)
#             If (feature 4 <= 10.323449908097295)
#              Predict: 1.0
#             Else (feature 4 > 10.323449908097295)
#              Predict: 0.0
#           Else (feature 4 > 11.18928764232481)
#            Predict: 1.0
#         Else (feature 1 > 4.425254644051889)
#          If (feature 2 <= 1.8838892321328924)
#           If (feature 4 <= 10.057038297565752)
#            Predict: 0.0
#           Else (feature 4 > 10.057038297565752)
#            If (feature 0 <= 2.117562409985606)
#             Predict: 0.0
#            Else (feature 0 > 2.117562409985606)
#             Predict: 1.0
#          Else (feature 2 > 1.8838892321328924)
#           If (feature 1 <= 5.936317205435461)
#            If (feature 3 <= 71.42757148873099)
#             If (feature 0 <= 1.151656749290417)
#              Predict: 0.0
#             Else (feature 0 > 1.151656749290417)
#              Predict: 1.0
#            Else (feature 3 > 71.42757148873099)
#             Predict: 0.0
#           Else (feature 1 > 5.936317205435461)
#            If (feature 1 <= 6.260116325731941)
#             If (feature 0 <= 1.5974593619189656)
#              Predict: 0.0
#             Else (feature 0 > 1.5974593619189656)
#              If (feature 2 <= 2.1117790586005807)
#               Predict: 0.0
#              Else (feature 2 > 2.1117790586005807)
#               Predict: 2.0
#            Else (feature 1 > 6.260116325731941)
#             If (feature 4 <= 8.858186050173808)
#              If (feature 2 <= 2.081393748404889)
#               Predict: 1.0
#              Else (feature 2 > 2.081393748404889)
#               Predict: 0.0
#             Else (feature 4 > 8.858186050173808)
#              If (feature 2 <= 2.081393748404889)
#               Predict: 0.0
#              Else (feature 2 > 2.081393748404889)
#               Predict: 1.0
#        Else (feature 3 > 72.37315033735982)
#         If (feature 4 <= 8.99139185543958)
#          If (feature 3 <= 74.55525537265709)
#           Predict: 0.0
#          Else (feature 3 > 74.55525537265709)
#           Predict: 2.0
#         Else (feature 4 > 8.99139185543958)
#          If (feature 3 <= 73.827887027558)
#           If (feature 1 <= 5.432629684974271)
#            If (feature 2 <= 2.1117790586005807)
#             Predict: 1.0
#            Else (feature 2 > 2.1117790586005807)
#             If (feature 1 <= 4.425254644051889)
#              Predict: 1.0
#             Else (feature 1 > 4.425254644051889)
#              If (feature 0 <= 1.0773563138523257)
#               Predict: 2.0
#              Else (feature 0 > 1.0773563138523257)
#               Predict: 1.0
#           Else (feature 1 > 5.432629684974271)
#            If (feature 0 <= 2.117562409985606)
#             Predict: 1.0
#            Else (feature 0 > 2.117562409985606)
#             If (feature 2 <= 2.081393748404889)
#              If (feature 3 <= 73.1005186824589)
#               Predict: 1.0
#              Else (feature 3 > 73.1005186824589)
#               Predict: 0.0
#             Else (feature 2 > 2.081393748404889)
#              Predict: 1.0
#          Else (feature 3 > 73.827887027558)
#           If (feature 4 <= 10.789670226527495)
#            If (feature 0 <= 2.117562409985606)
#             If (feature 2 <= 2.1117790586005807)
#              Predict: 1.0
#             Else (feature 2 > 2.1117790586005807)
#              Predict: 2.0
#            Else (feature 0 > 2.117562409985606)
#             Predict: 0.0
#           Else (feature 4 > 10.789670226527495)
#            Predict: 2.0
#       Else (feature 1 > 7.015647606423727)
#        Predict: 2.0
#      Else (feature 2 > 2.1436836343060572)
#       If (feature 2 <= 2.354861540166115)
#        If (feature 4 <= 10.323449908097295)
#         If (feature 3 <= 71.42757148873099)
#          If (feature 1 <= 7.015647606423727)
#           If (feature 0 <= 1.8203606682332398)
#            If (feature 1 <= 5.612518085138982)
#             If (feature 0 <= 1.5974593619189656)
#              Predict: 0.0
#             Else (feature 0 > 1.5974593619189656)
#              If (feature 0 <= 1.671759797357057)
#               Predict: 1.0
#              Else (feature 0 > 1.671759797357057)
#               Predict: 0.0
#            Else (feature 1 > 5.612518085138982)
#             If (feature 0 <= 1.151656749290417)
#              If (feature 2 <= 2.2940909197747317)
#               Predict: 1.0
#              Else (feature 2 > 2.2940909197747317)
#               Predict: 0.0
#             Else (feature 0 > 1.151656749290417)
#              Predict: 0.0
#           Else (feature 0 > 1.8203606682332398)
#            Predict: 0.0
#          Else (feature 1 > 7.015647606423727)
#           Predict: 2.0
#         Else (feature 3 > 71.42757148873099)
#          If (feature 0 <= 1.5231589264808743)
#           If (feature 2 <= 2.2940909197747317)
#            Predict: 0.0
#           Else (feature 2 > 2.2940909197747317)
#            Predict: 2.0
#          Else (feature 0 > 1.5231589264808743)
#           If (feature 0 <= 2.191862845423697)
#            Predict: 2.0
#           Else (feature 0 > 2.191862845423697)
#            Predict: 1.0
#        Else (feature 4 > 10.323449908097295)
#         If (feature 1 <= 5.2167636047766175)
#          If (feature 0 <= 1.5231589264808743)
#           If (feature 1 <= 4.425254644051889)
#            If (feature 0 <= 1.3002576201665998)
#             If (feature 3 <= 73.827887027558)
#              If (feature 3 <= 71.42757148873099)
#               Predict: 0.0
#              Else (feature 3 > 71.42757148873099)
#               Predict: 2.0
#             Else (feature 3 > 73.827887027558)
#              Predict: 0.0
#            Else (feature 0 > 1.3002576201665998)
#             Predict: 1.0
#           Else (feature 1 > 4.425254644051889)
#            Predict: 0.0
#          Else (feature 0 > 1.5231589264808743)
#           Predict: 1.0
#         Else (feature 1 > 5.2167636047766175)
#          Predict: 0.0
#       Else (feature 2 > 2.354861540166115)
#        If (feature 3 <= 71.42757148873099)
#         If (feature 4 <= 10.323449908097295)
#          If (feature 1 <= 7.015647606423727)
#           If (feature 1 <= 5.2167636047766175)
#            If (feature 0 <= 1.8203606682332398)
#             Predict: 0.0
#            Else (feature 0 > 1.8203606682332398)
#             If (feature 1 <= 4.785031444381311)
#              If (feature 0 <= 2.3404637162998796)
#               Predict: 1.0
#              Else (feature 0 > 2.3404637162998796)
#               Predict: 0.0
#             Else (feature 1 > 4.785031444381311)
#              Predict: 0.0
#           Else (feature 1 > 5.2167636047766175)
#            If (feature 2 <= 2.385246850361807)
#             If (feature 0 <= 2.563365022614154)
#              If (feature 4 <= 8.325362829110722)
#               Predict: 1.0
#              Else (feature 4 > 8.325362829110722)
#               Predict: 0.0
#             Else (feature 0 > 2.563365022614154)
#              Predict: 1.0
#            Else (feature 2 > 2.385246850361807)
#             If (feature 1 <= 6.260116325731941)
#              Predict: 0.0
#             Else (feature 1 > 6.260116325731941)
#              If (feature 0 <= 1.8203606682332398)
#               Predict: 1.0
#              Else (feature 0 > 1.8203606682332398)
#               Predict: 0.0
#          Else (feature 1 > 7.015647606423727)
#           Predict: 2.0
#         Else (feature 4 > 10.323449908097295)
#          If (feature 1 <= 6.655870806094304)
#           If (feature 1 <= 4.785031444381311)
#            Predict: 0.0
#           Else (feature 1 > 4.785031444381311)
#            If (feature 4 <= 11.18928764232481)
#             Predict: 1.0
#            Else (feature 4 > 11.18928764232481)
#             Predict: 0.0
#          Else (feature 1 > 6.655870806094304)
#           Predict: 2.0
#        Else (feature 3 > 71.42757148873099)
#         If (feature 4 <= 9.657420881768438)
#          Predict: 2.0
#         Else (feature 4 > 9.657420881768438)
#          If (feature 0 <= 2.117562409985606)
#           If (feature 1 <= 4.425254644051889)
#            If (feature 2 <= 2.385246850361807)
#             Predict: 1.0
#            Else (feature 2 > 2.385246850361807)
#             If (feature 0 <= 1.3002576201665998)
#              Predict: 0.0
#             Else (feature 0 > 1.3002576201665998)
#              Predict: 2.0
#           Else (feature 1 > 4.425254644051889)
#            If (feature 4 <= 10.789670226527495)
#             Predict: 1.0
#            Else (feature 4 > 10.789670226527495)
#             Predict: 2.0
#          Else (feature 0 > 2.117562409985606)
#           Predict: 2.0
#     Else (feature 2 > 2.5827513666338042)
#      If (feature 2 <= 3.4943106725045583)
#       If (feature 4 <= 10.789670226527495)
#        If (feature 1 <= 5.432629684974271)
#         Predict: 2.0
#        Else (feature 1 > 5.432629684974271)
#         If (feature 1 <= 6.655870806094304)
#          If (feature 0 <= 2.117562409985606)
#           Predict: 2.0
#          Else (feature 0 > 2.117562409985606)
#           Predict: 1.0
#         Else (feature 1 > 6.655870806094304)
#          Predict: 2.0
#       Else (feature 4 > 10.789670226527495)
#        If (feature 0 <= 2.117562409985606)
#         Predict: 1.0
#        Else (feature 0 > 2.117562409985606)
#         Predict: 2.0
#      Else (feature 2 > 3.4943106725045583)
#       If (feature 0 <= 2.9348671998046107)
#        Predict: 2.0
#       Else (feature 0 > 2.9348671998046107)
#        If (feature 4 <= 10.057038297565752)
#         If (feature 4 <= 8.858186050173808)
#          Predict: 2.0
#         Else (feature 4 > 8.858186050173808)
#          If (feature 2 <= 4.2539434273968535)
#           Predict: 1.0
#          Else (feature 2 > 4.2539434273968535)
#           If (feature 4 <= 9.657420881768438)
#            If (feature 0 <= 3.306369376995068)
#             If (feature 1 <= 5.936317205435461)
#              Predict: 1.0
#             Else (feature 1 > 5.936317205435461)
#              Predict: 2.0
#            Else (feature 0 > 3.306369376995068)
#             Predict: 2.0
#           Else (feature 4 > 9.657420881768438)
#            Predict: 1.0
#        Else (feature 4 > 10.057038297565752)
#         If (feature 0 <= 3.306369376995068)
#          If (feature 1 <= 6.655870806094304)
#           If (feature 2 <= 4.2539434273968535)
#            Predict: 2.0
#           Else (feature 2 > 4.2539434273968535)
#            If (feature 1 <= 5.936317205435461)
#             Predict: 2.0
#            Else (feature 1 > 5.936317205435461)
#             Predict: 1.0
#          Else (feature 1 > 6.655870806094304)
#           Predict: 2.0
#         Else (feature 0 > 3.306369376995068)
#          Predict: 2.0
#   Tree 3 (weight 1.0):
#     If (feature 2 <= 2.5827513666338042)
#      If (feature 3 <= 72.37315033735982)
#       If (feature 1 <= 7.015647606423727)
#        If (feature 2 <= 2.1436836343060572)
#         If (feature 1 <= 4.92894216451308)
#          If (feature 0 <= 2.117562409985606)
#           If (feature 0 <= 1.0773563138523257)
#            If (feature 1 <= 3.957544803623641)
#             Predict: 1.0
#            Else (feature 1 > 3.957544803623641)
#             Predict: 0.0
#           Else (feature 0 > 1.0773563138523257)
#            If (feature 2 <= 2.081393748404889)
#             If (feature 4 <= 9.657420881768438)
#              If (feature 0 <= 1.151656749290417)
#               Predict: 1.0
#              Else (feature 0 > 1.151656749290417)
#               Predict: 0.0
#             Else (feature 4 > 9.657420881768438)
#              Predict: 0.0
#            Else (feature 2 > 2.081393748404889)
#             If (feature 4 <= 9.657420881768438)
#              Predict: 0.0
#             Else (feature 4 > 9.657420881768438)
#              If (feature 0 <= 1.151656749290417)
#               Predict: 0.0
#              Else (feature 0 > 1.151656749290417)
#               Predict: 1.0
#          Else (feature 0 > 2.117562409985606)
#           If (feature 0 <= 2.9348671998046107)
#            Predict: 1.0
#           Else (feature 0 > 2.9348671998046107)
#            If (feature 4 <= 9.657420881768438)
#             Predict: 0.0
#            Else (feature 4 > 9.657420881768438)
#             If (feature 2 <= 2.081393748404889)
#              Predict: 1.0
#             Else (feature 2 > 2.081393748404889)
#              Predict: 0.0
#         Else (feature 1 > 4.92894216451308)
#          If (feature 1 <= 5.936317205435461)
#           If (feature 0 <= 1.151656749290417)
#            Predict: 0.0
#           Else (feature 0 > 1.151656749290417)
#            If (feature 2 <= 1.8838892321328924)
#             If (feature 0 <= 2.191862845423697)
#              Predict: 1.0
#             Else (feature 0 > 2.191862845423697)
#              Predict: 0.0
#            Else (feature 2 > 1.8838892321328924)
#             If (feature 0 <= 3.306369376995068)
#              If (feature 0 <= 1.8203606682332398)
#               Predict: 1.0
#              Else (feature 0 > 1.8203606682332398)
#               Predict: 0.0
#             Else (feature 0 > 3.306369376995068)
#              Predict: 1.0
#          Else (feature 1 > 5.936317205435461)
#           If (feature 0 <= 1.0773563138523257)
#            If (feature 2 <= 2.081393748404889)
#             Predict: 1.0
#            Else (feature 2 > 2.081393748404889)
#             Predict: 0.0
#           Else (feature 0 > 1.0773563138523257)
#            If (feature 0 <= 1.8203606682332398)
#             If (feature 4 <= 8.858186050173808)
#              If (feature 2 <= 1.8838892321328924)
#               Predict: 0.0
#              Else (feature 2 > 1.8838892321328924)
#               Predict: 1.0
#             Else (feature 4 > 8.858186050173808)
#              Predict: 0.0
#            Else (feature 0 > 1.8203606682332398)
#             If (feature 1 <= 6.260116325731941)
#              Predict: 2.0
#             Else (feature 1 > 6.260116325731941)
#              If (feature 4 <= 10.523258615995953)
#               Predict: 0.0
#              Else (feature 4 > 10.523258615995953)
#               Predict: 2.0
#        Else (feature 2 > 2.1436836343060572)
#         If (feature 2 <= 2.354861540166115)
#          If (feature 4 <= 10.323449908097295)
#           If (feature 2 <= 2.324476229970424)
#            Predict: 0.0
#           Else (feature 2 > 2.324476229970424)
#            If (feature 0 <= 2.3404637162998796)
#             Predict: 0.0
#            Else (feature 0 > 2.3404637162998796)
#             If (feature 1 <= 5.432629684974271)
#              If (feature 0 <= 3.306369376995068)
#               Predict: 2.0
#              Else (feature 0 > 3.306369376995068)
#               Predict: 0.0
#             Else (feature 1 > 5.432629684974271)
#              Predict: 0.0
#          Else (feature 4 > 10.323449908097295)
#           If (feature 4 <= 10.523258615995953)
#            Predict: 1.0
#           Else (feature 4 > 10.523258615995953)
#            If (feature 4 <= 10.789670226527495)
#             Predict: 0.0
#            Else (feature 4 > 10.789670226527495)
#             If (feature 1 <= 6.260116325731941)
#              Predict: 0.0
#             Else (feature 1 > 6.260116325731941)
#              If (feature 0 <= 1.5231589264808743)
#               Predict: 1.0
#              Else (feature 0 > 1.5231589264808743)
#               Predict: 0.0
#         Else (feature 2 > 2.354861540166115)
#          If (feature 4 <= 10.323449908097295)
#           If (feature 1 <= 5.936317205435461)
#            If (feature 0 <= 4.123674166814074)
#             If (feature 4 <= 10.190244102831524)
#              Predict: 0.0
#             Else (feature 4 > 10.190244102831524)
#              If (feature 0 <= 1.151656749290417)
#               Predict: 0.0
#              Else (feature 0 > 1.151656749290417)
#               Predict: 1.0
#            Else (feature 0 > 4.123674166814074)
#             If (feature 4 <= 10.057038297565752)
#              Predict: 2.0
#             Else (feature 4 > 10.057038297565752)
#              Predict: 0.0
#           Else (feature 1 > 5.936317205435461)
#            If (feature 4 <= 8.325362829110722)
#             If (feature 2 <= 2.385246850361807)
#              If (feature 0 <= 1.0773563138523257)
#               Predict: 0.0
#              Else (feature 0 > 1.0773563138523257)
#               Predict: 1.0
#             Else (feature 2 > 2.385246850361807)
#              Predict: 0.0
#            Else (feature 4 > 8.325362829110722)
#             If (feature 0 <= 1.8203606682332398)
#              If (feature 1 <= 6.260116325731941)
#               Predict: 0.0
#              Else (feature 1 > 6.260116325731941)
#               Predict: 1.0
#             Else (feature 0 > 1.8203606682332398)
#              Predict: 0.0
#          Else (feature 4 > 10.323449908097295)
#           If (feature 1 <= 4.785031444381311)
#            Predict: 0.0
#           Else (feature 1 > 4.785031444381311)
#            Predict: 1.0
#       Else (feature 1 > 7.015647606423727)
#        If (feature 2 <= 2.081393748404889)
#         If (feature 4 <= 8.325362829110722)
#          Predict: 1.0
#         Else (feature 4 > 8.325362829110722)
#          Predict: 2.0
#        Else (feature 2 > 2.081393748404889)
#         Predict: 2.0
#      Else (feature 3 > 72.37315033735982)
#       If (feature 2 <= 2.1436836343060572)
#        If (feature 3 <= 73.827887027558)
#         If (feature 0 <= 1.0773563138523257)
#          Predict: 2.0
#         Else (feature 0 > 1.0773563138523257)
#          If (feature 0 <= 2.117562409985606)
#           If (feature 4 <= 9.657420881768438)
#            Predict: 1.0
#           Else (feature 4 > 9.657420881768438)
#            If (feature 1 <= 4.425254644051889)
#             Predict: 1.0
#            Else (feature 1 > 4.425254644051889)
#             If (feature 4 <= 10.190244102831524)
#              Predict: 2.0
#             Else (feature 4 > 10.190244102831524)
#              Predict: 1.0
#          Else (feature 0 > 2.117562409985606)
#           If (feature 0 <= 2.3404637162998796)
#            If (feature 2 <= 2.081393748404889)
#             If (feature 4 <= 9.657420881768438)
#              Predict: 1.0
#             Else (feature 4 > 9.657420881768438)
#              Predict: 0.0
#            Else (feature 2 > 2.081393748404889)
#             Predict: 1.0
#           Else (feature 0 > 2.3404637162998796)
#            Predict: 1.0
#        Else (feature 3 > 73.827887027558)
#         If (feature 4 <= 9.657420881768438)
#          Predict: 0.0
#         Else (feature 4 > 9.657420881768438)
#          If (feature 1 <= 6.655870806094304)
#           If (feature 2 <= 2.1117790586005807)
#            If (feature 4 <= 10.190244102831524)
#             If (feature 0 <= 1.3745580556046912)
#              Predict: 1.0
#             Else (feature 0 > 1.3745580556046912)
#              Predict: 0.0
#            Else (feature 4 > 10.190244102831524)
#             Predict: 2.0
#           Else (feature 2 > 2.1117790586005807)
#            Predict: 2.0
#          Else (feature 1 > 6.655870806094304)
#           Predict: 2.0
#       Else (feature 2 > 2.1436836343060572)
#        If (feature 0 <= 1.5231589264808743)
#         If (feature 1 <= 4.6051430442166)
#          If (feature 0 <= 1.0773563138523257)
#           If (feature 4 <= 8.325362829110722)
#            Predict: 0.0
#           Else (feature 4 > 8.325362829110722)
#            If (feature 2 <= 2.2940909197747317)
#             Predict: 1.0
#            Else (feature 2 > 2.2940909197747317)
#             Predict: 2.0
#          Else (feature 0 > 1.0773563138523257)
#           If (feature 3 <= 73.827887027558)
#            If (feature 1 <= 4.425254644051889)
#             If (feature 4 <= 10.190244102831524)
#              Predict: 0.0
#             Else (feature 4 > 10.190244102831524)
#              If (feature 0 <= 1.3002576201665998)
#               Predict: 2.0
#              Else (feature 0 > 1.3002576201665998)
#               Predict: 1.0
#            Else (feature 1 > 4.425254644051889)
#             Predict: 0.0
#           Else (feature 3 > 73.827887027558)
#            Predict: 0.0
#         Else (feature 1 > 4.6051430442166)
#          If (feature 0 <= 1.3745580556046912)
#           If (feature 2 <= 2.385246850361807)
#            If (feature 2 <= 2.2940909197747317)
#             If (feature 1 <= 4.785031444381311)
#              If (feature 0 <= 1.0773563138523257)
#               Predict: 0.0
#              Else (feature 0 > 1.0773563138523257)
#               Predict: 1.0
#             Else (feature 1 > 4.785031444381311)
#              Predict: 0.0
#            Else (feature 2 > 2.2940909197747317)
#             If (feature 3 <= 73.827887027558)
#              Predict: 1.0
#             Else (feature 3 > 73.827887027558)
#              Predict: 2.0
#           Else (feature 2 > 2.385246850361807)
#            Predict: 1.0
#          Else (feature 0 > 1.3745580556046912)
#           Predict: 0.0
#        Else (feature 0 > 1.5231589264808743)
#         If (feature 1 <= 5.936317205435461)
#          If (feature 2 <= 2.385246850361807)
#           If (feature 4 <= 9.657420881768438)
#            Predict: 2.0
#           Else (feature 4 > 9.657420881768438)
#            If (feature 0 <= 2.3404637162998796)
#             Predict: 1.0
#            Else (feature 0 > 2.3404637162998796)
#             Predict: 2.0
#          Else (feature 2 > 2.385246850361807)
#           Predict: 2.0
#         Else (feature 1 > 5.936317205435461)
#          Predict: 0.0
#     Else (feature 2 > 2.5827513666338042)
#      If (feature 3 <= 73.1005186824589)
#       If (feature 0 <= 3.306369376995068)
#        If (feature 0 <= 2.9348671998046107)
#         Predict: 2.0
#        Else (feature 0 > 2.9348671998046107)
#         If (feature 2 <= 5.013576182289149)
#          If (feature 1 <= 6.655870806094304)
#           If (feature 1 <= 6.260116325731941)
#            Predict: 2.0
#           Else (feature 1 > 6.260116325731941)
#            Predict: 1.0
#          Else (feature 1 > 6.655870806094304)
#           Predict: 2.0
#         Else (feature 2 > 5.013576182289149)
#          Predict: 2.0
#       Else (feature 0 > 3.306369376995068)
#        If (feature 2 <= 5.013576182289149)
#         If (feature 4 <= 10.057038297565752)
#          If (feature 1 <= 5.936317205435461)
#           Predict: 2.0
#          Else (feature 1 > 5.936317205435461)
#           If (feature 1 <= 6.655870806094304)
#            Predict: 1.0
#           Else (feature 1 > 6.655870806094304)
#            Predict: 2.0
#         Else (feature 4 > 10.057038297565752)
#          Predict: 2.0
#        Else (feature 2 > 5.013576182289149)
#         Predict: 2.0
#      Else (feature 3 > 73.1005186824589)
#       If (feature 1 <= 4.425254644051889)
#        If (feature 0 <= 2.117562409985606)
#         Predict: 1.0
#        Else (feature 0 > 2.117562409985606)
#         Predict: 2.0
#       Else (feature 1 > 4.425254644051889)
#        If (feature 2 <= 4.2539434273968535)
#         If (feature 2 <= 3.4943106725045583)
#          If (feature 4 <= 9.657420881768438)
#           Predict: 2.0
#          Else (feature 4 > 9.657420881768438)
#           If (feature 0 <= 2.117562409985606)
#            Predict: 2.0
#           Else (feature 0 > 2.117562409985606)
#            Predict: 1.0
#         Else (feature 2 > 3.4943106725045583)
#          Predict: 2.0
#        Else (feature 2 > 4.2539434273968535)
#         Predict: 1.0
#   Tree 4 (weight 1.0):
#     If (feature 2 <= 2.5827513666338042)
#      If (feature 2 <= 2.1436836343060572)
#       If (feature 0 <= 1.151656749290417)
#        If (feature 3 <= 72.37315033735982)
#         If (feature 0 <= 1.0773563138523257)
#          If (feature 2 <= 2.081393748404889)
#           If (feature 2 <= 1.8838892321328924)
#            Predict: 1.0
#           Else (feature 2 > 1.8838892321328924)
#            If (feature 1 <= 4.425254644051889)
#             Predict: 0.0
#            Else (feature 1 > 4.425254644051889)
#             Predict: 1.0
#          Else (feature 2 > 2.081393748404889)
#           Predict: 0.0
#         Else (feature 0 > 1.0773563138523257)
#          If (feature 1 <= 3.957544803623641)
#           If (feature 4 <= 9.657420881768438)
#            Predict: 1.0
#           Else (feature 4 > 9.657420881768438)
#            Predict: 0.0
#          Else (feature 1 > 3.957544803623641)
#           Predict: 0.0
#        Else (feature 3 > 72.37315033735982)
#         If (feature 4 <= 8.325362829110722)
#          Predict: 0.0
#         Else (feature 4 > 8.325362829110722)
#          Predict: 2.0
#       Else (feature 0 > 1.151656749290417)
#        If (feature 0 <= 1.5231589264808743)
#         If (feature 3 <= 74.55525537265709)
#          If (feature 3 <= 71.64578199226071)
#           If (feature 4 <= 10.789670226527495)
#            If (feature 3 <= 71.42757148873099)
#             Predict: 1.0
#            Else (feature 3 > 71.42757148873099)
#             Predict: 0.0
#           Else (feature 4 > 10.789670226527495)
#            Predict: 0.0
#          Else (feature 3 > 71.64578199226071)
#           If (feature 3 <= 73.827887027558)
#            Predict: 1.0
#           Else (feature 3 > 73.827887027558)
#            If (feature 2 <= 2.1117790586005807)
#             If (feature 4 <= 10.190244102831524)
#              Predict: 1.0
#             Else (feature 4 > 10.190244102831524)
#              Predict: 2.0
#            Else (feature 2 > 2.1117790586005807)
#             Predict: 2.0
#         Else (feature 3 > 74.55525537265709)
#          Predict: 2.0
#        Else (feature 0 > 1.5231589264808743)
#         If (feature 0 <= 1.8203606682332398)
#          If (feature 1 <= 6.260116325731941)
#           If (feature 2 <= 2.0510084382091973)
#            Predict: 0.0
#           Else (feature 2 > 2.0510084382091973)
#            If (feature 4 <= 8.325362829110722)
#             Predict: 0.0
#            Else (feature 4 > 8.325362829110722)
#             If (feature 1 <= 5.2167636047766175)
#              Predict: 1.0
#             Else (feature 1 > 5.2167636047766175)
#              If (feature 4 <= 8.858186050173808)
#               Predict: 1.0
#              Else (feature 4 > 8.858186050173808)
#               Predict: 0.0
#          Else (feature 1 > 6.260116325731941)
#           If (feature 2 <= 2.0510084382091973)
#            Predict: 0.0
#           Else (feature 2 > 2.0510084382091973)
#            If (feature 0 <= 1.671759797357057)
#             Predict: 0.0
#            Else (feature 0 > 1.671759797357057)
#             Predict: 2.0
#         Else (feature 0 > 1.8203606682332398)
#          If (feature 1 <= 6.655870806094304)
#           If (feature 3 <= 71.42757148873099)
#            If (feature 2 <= 2.081393748404889)
#             If (feature 0 <= 2.3404637162998796)
#              Predict: 1.0
#             Else (feature 0 > 2.3404637162998796)
#              If (feature 2 <= 2.0510084382091973)
#               Predict: 0.0
#              Else (feature 2 > 2.0510084382091973)
#               Predict: 1.0
#            Else (feature 2 > 2.081393748404889)
#             If (feature 2 <= 2.1117790586005807)
#              Predict: 0.0
#             Else (feature 2 > 2.1117790586005807)
#              If (feature 0 <= 2.3404637162998796)
#               Predict: 2.0
#              Else (feature 0 > 2.3404637162998796)
#               Predict: 1.0
#           Else (feature 3 > 71.42757148873099)
#            If (feature 2 <= 2.081393748404889)
#             If (feature 0 <= 2.117562409985606)
#              Predict: 1.0
#             Else (feature 0 > 2.117562409985606)
#              If (feature 0 <= 2.3404637162998796)
#               Predict: 0.0
#              Else (feature 0 > 2.3404637162998796)
#               Predict: 1.0
#            Else (feature 2 > 2.081393748404889)
#             If (feature 3 <= 73.827887027558)
#              Predict: 1.0
#             Else (feature 3 > 73.827887027558)
#              Predict: 0.0
#          Else (feature 1 > 6.655870806094304)
#           Predict: 2.0
#      Else (feature 2 > 2.1436836343060572)
#       If (feature 1 <= 7.015647606423727)
#        If (feature 4 <= 10.323449908097295)
#         If (feature 3 <= 71.42757148873099)
#          If (feature 1 <= 5.612518085138982)
#           If (feature 1 <= 4.425254644051889)
#            Predict: 0.0
#           Else (feature 1 > 4.425254644051889)
#            If (feature 4 <= 10.190244102831524)
#             Predict: 0.0
#            Else (feature 4 > 10.190244102831524)
#             If (feature 2 <= 2.2940909197747317)
#              Predict: 0.0
#             Else (feature 2 > 2.2940909197747317)
#              Predict: 1.0
#          Else (feature 1 > 5.612518085138982)
#           If (feature 0 <= 2.117562409985606)
#            If (feature 0 <= 1.0773563138523257)
#             Predict: 0.0
#            Else (feature 0 > 1.0773563138523257)
#             If (feature 4 <= 8.858186050173808)
#              If (feature 4 <= 8.325362829110722)
#               Predict: 0.0
#              Else (feature 4 > 8.325362829110722)
#               Predict: 1.0
#             Else (feature 4 > 8.858186050173808)
# ...
#            If (feature 0 <= 2.3404637162998796)
#             Predict: 1.0
#            Else (feature 0 > 2.3404637162998796)
#             Predict: 2.0
#         Else (feature 2 > 2.354861540166115)
#          If (feature 1 <= 4.6051430442166)
#           If (feature 0 <= 1.0773563138523257)
#            Predict: 2.0
#           Else (feature 0 > 1.0773563138523257)
#            If (feature 1 <= 4.425254644051889)
#             Predict: 0.0
#            Else (feature 1 > 4.425254644051889)
#             Predict: 2.0
#          Else (feature 1 > 4.6051430442166)
#           If (feature 3 <= 71.42757148873099)
#            If (feature 0 <= 1.5974593619189656)
#             Predict: 0.0
#            Else (feature 0 > 1.5974593619189656)
#             If (feature 0 <= 2.117562409985606)
#              Predict: 1.0
#             Else (feature 0 > 2.117562409985606)
#              If (feature 0 <= 3.6778715541855256)
#               Predict: 0.0
#              Else (feature 0 > 3.6778715541855256)
#               Predict: 1.0
#           Else (feature 3 > 71.42757148873099)
#            Predict: 2.0
#        Else (feature 1 > 7.015647606423727)
#         Predict: 2.0
#       Else (feature 4 > 10.323449908097295)
#        If (feature 1 <= 6.655870806094304)
#         If (feature 2 <= 2.354861540166115)
#          If (feature 0 <= 1.671759797357057)
#           If (feature 2 <= 2.2333202993833483)
#            Predict: 0.0
#           Else (feature 2 > 2.2333202993833483)
#            If (feature 0 <= 1.3002576201665998)
#             Predict: 0.0
#            Else (feature 0 > 1.3002576201665998)
#             If (feature 3 <= 71.42757148873099)
#              Predict: 0.0
#             Else (feature 3 > 71.42757148873099)
#              Predict: 1.0
#          Else (feature 0 > 1.671759797357057)
#           If (feature 1 <= 5.2167636047766175)
#            If (feature 4 <= 11.18928764232481)
#             Predict: 1.0
#            Else (feature 4 > 11.18928764232481)
#             Predict: 2.0
#           Else (feature 1 > 5.2167636047766175)
#            Predict: 0.0
#         Else (feature 2 > 2.354861540166115)
#          If (feature 2 <= 2.385246850361807)
#           If (feature 3 <= 71.42757148873099)
#            If (feature 4 <= 10.789670226527495)
#             If (feature 4 <= 10.523258615995953)
#              Predict: 1.0
#             Else (feature 4 > 10.523258615995953)
#              Predict: 0.0
#            Else (feature 4 > 10.789670226527495)
#             Predict: 1.0
#           Else (feature 3 > 71.42757148873099)
#            Predict: 1.0
#          Else (feature 2 > 2.385246850361807)
#           If (feature 1 <= 4.425254644051889)
#            Predict: 2.0
#           Else (feature 1 > 4.425254644051889)
#            If (feature 1 <= 4.785031444381311)
#             Predict: 1.0
#            Else (feature 1 > 4.785031444381311)
#             If (feature 3 <= 71.42757148873099)
#              Predict: 1.0
#             Else (feature 3 > 71.42757148873099)
#              Predict: 2.0
#        Else (feature 1 > 6.655870806094304)
#         Predict: 2.0
#     Else (feature 2 > 2.5827513666338042)
#      If (feature 2 <= 5.013576182289149)
#       If (feature 3 <= 73.1005186824589)
#        If (feature 4 <= 8.325362829110722)
#         If (feature 0 <= 1.5231589264808743)
#          Predict: 1.0
#         Else (feature 0 > 1.5231589264808743)
#          If (feature 1 <= 5.2167636047766175)
#           Predict: 2.0
#          Else (feature 1 > 5.2167636047766175)
#           If (feature 0 <= 3.306369376995068)
#            Predict: 2.0
#           Else (feature 0 > 3.306369376995068)
#            Predict: 1.0
#        Else (feature 4 > 8.325362829110722)
#         If (feature 0 <= 2.9348671998046107)
#          Predict: 2.0
#         Else (feature 0 > 2.9348671998046107)
#          If (feature 0 <= 3.306369376995068)
#           If (feature 2 <= 4.2539434273968535)
#            Predict: 2.0
#           Else (feature 2 > 4.2539434273968535)
#            Predict: 1.0
#          Else (feature 0 > 3.306369376995068)
#           If (feature 4 <= 8.858186050173808)
#            Predict: 2.0
#           Else (feature 4 > 8.858186050173808)
#            If (feature 4 <= 10.057038297565752)
#             Predict: 1.0
#            Else (feature 4 > 10.057038297565752)
#             Predict: 2.0
#       Else (feature 3 > 73.1005186824589)
#        If (feature 0 <= 3.306369376995068)
#         If (feature 4 <= 10.789670226527495)
#          If (feature 1 <= 5.432629684974271)
#           Predict: 2.0
#          Else (feature 1 > 5.432629684974271)
#           If (feature 0 <= 2.117562409985606)
#            Predict: 2.0
#           Else (feature 0 > 2.117562409985606)
#            If (feature 0 <= 2.3404637162998796)
#             Predict: 1.0
#            Else (feature 0 > 2.3404637162998796)
#             Predict: 2.0
#         Else (feature 4 > 10.789670226527495)
#          If (feature 0 <= 2.117562409985606)
#           Predict: 1.0
#          Else (feature 0 > 2.117562409985606)
#           Predict: 2.0
#        Else (feature 0 > 3.306369376995068)
#         Predict: 1.0
#      Else (feature 2 > 5.013576182289149)
#       Predict: 2.0
#   Tree 19 (weight 1.0):
#     If (feature 2 <= 2.5827513666338042)
#      If (feature 1 <= 7.015647606423727)
#       If (feature 2 <= 2.1436836343060572)
#        If (feature 3 <= 72.37315033735982)
#         If (feature 1 <= 5.936317205435461)
#          If (feature 1 <= 4.92894216451308)
#           If (feature 4 <= 10.190244102831524)
#            If (feature 4 <= 8.325362829110722)
#             Predict: 0.0
#            Else (feature 4 > 8.325362829110722)
#             If (feature 0 <= 2.563365022614154)
#              Predict: 1.0
#             Else (feature 0 > 2.563365022614154)
#              Predict: 0.0
#           Else (feature 4 > 10.190244102831524)
#            If (feature 2 <= 2.1117790586005807)
#             If (feature 0 <= 1.671759797357057)
#              Predict: 0.0
#             Else (feature 0 > 1.671759797357057)
#              Predict: 1.0
#            Else (feature 2 > 2.1117790586005807)
#             Predict: 0.0
#          Else (feature 1 > 4.92894216451308)
#           If (feature 0 <= 1.3745580556046912)
#            Predict: 0.0
#           Else (feature 0 > 1.3745580556046912)
#            If (feature 2 <= 2.1284909792082116)
#             If (feature 0 <= 1.8203606682332398)
#              Predict: 1.0
#             Else (feature 0 > 1.8203606682332398)
#              If (feature 0 <= 2.117562409985606)
#               Predict: 0.0
#              Else (feature 0 > 2.117562409985606)
#               Predict: 1.0
#            Else (feature 2 > 2.1284909792082116)
#             If (feature 1 <= 5.2167636047766175)
#              Predict: 1.0
#             Else (feature 1 > 5.2167636047766175)
#              Predict: 2.0
#         Else (feature 1 > 5.936317205435461)
#          If (feature 0 <= 1.5231589264808743)
#           If (feature 2 <= 2.081393748404889)
#            Predict: 1.0
#           Else (feature 2 > 2.081393748404889)
#            Predict: 0.0
#          Else (feature 0 > 1.5231589264808743)
#           If (feature 4 <= 8.858186050173808)
#            If (feature 2 <= 1.8838892321328924)
#             Predict: 0.0
#            Else (feature 2 > 1.8838892321328924)
#             If (feature 1 <= 6.260116325731941)
#              If (feature 2 <= 2.1117790586005807)
#               Predict: 1.0
#              Else (feature 2 > 2.1117790586005807)
#               Predict: 0.0
#             Else (feature 1 > 6.260116325731941)
#              Predict: 1.0
#           Else (feature 4 > 8.858186050173808)
#            If (feature 2 <= 2.0510084382091973)
#             Predict: 0.0
#            Else (feature 2 > 2.0510084382091973)
#             If (feature 4 <= 9.657420881768438)
#              If (feature 0 <= 2.563365022614154)
#               Predict: 0.0
#              Else (feature 0 > 2.563365022614154)
#               Predict: 2.0
#             Else (feature 4 > 9.657420881768438)
#              Predict: 0.0
#        Else (feature 3 > 72.37315033735982)
#         If (feature 3 <= 73.827887027558)
#          If (feature 1 <= 5.2167636047766175)
#           Predict: 1.0
#          Else (feature 1 > 5.2167636047766175)
#           If (feature 0 <= 1.3002576201665998)
#            Predict: 2.0
#           Else (feature 0 > 1.3002576201665998)
#            If (feature 2 <= 2.081393748404889)
#             If (feature 3 <= 73.1005186824589)
#              Predict: 1.0
#             Else (feature 3 > 73.1005186824589)
#              If (feature 0 <= 2.117562409985606)
#               Predict: 1.0
#              Else (feature 0 > 2.117562409985606)
#               Predict: 0.0
#            Else (feature 2 > 2.081393748404889)
#             Predict: 1.0
#         Else (feature 3 > 73.827887027558)
#          If (feature 0 <= 1.3002576201665998)
#           If (feature 4 <= 8.325362829110722)
#            Predict: 0.0
#           Else (feature 4 > 8.325362829110722)
#            If (feature 1 <= 4.785031444381311)
#             Predict: 2.0
#            Else (feature 1 > 4.785031444381311)
#             Predict: 1.0
#          Else (feature 0 > 1.3002576201665998)
#           Predict: 0.0
#       Else (feature 2 > 2.1436836343060572)
#        If (feature 3 <= 71.42757148873099)
#         If (feature 4 <= 10.323449908097295)
#          If (feature 1 <= 5.2167636047766175)
#           If (feature 1 <= 4.425254644051889)
#            Predict: 0.0
#           Else (feature 1 > 4.425254644051889)
#            If (feature 4 <= 10.190244102831524)
#             Predict: 0.0
#            Else (feature 4 > 10.190244102831524)
#             If (feature 0 <= 2.3404637162998796)
#              Predict: 1.0
#             Else (feature 0 > 2.3404637162998796)
#              Predict: 0.0
#          Else (feature 1 > 5.2167636047766175)
#           If (feature 4 <= 8.858186050173808)
#            If (feature 2 <= 2.354861540166115)
#             If (feature 1 <= 5.936317205435461)
#              Predict: 0.0
#             Else (feature 1 > 5.936317205435461)
#              If (feature 4 <= 8.325362829110722)
#               Predict: 0.0
#              Else (feature 4 > 8.325362829110722)
#               Predict: 1.0
#            Else (feature 2 > 2.354861540166115)
#             If (feature 0 <= 1.0773563138523257)
#              Predict: 0.0
#             Else (feature 0 > 1.0773563138523257)
#              If (feature 1 <= 6.655870806094304)
#               Predict: 1.0
#              Else (feature 1 > 6.655870806094304)
#               Predict: 0.0
#           Else (feature 4 > 8.858186050173808)
#            If (feature 1 <= 5.936317205435461)
#             If (feature 0 <= 1.151656749290417)
#              Predict: 1.0
#             Else (feature 0 > 1.151656749290417)
#              Predict: 0.0
#            Else (feature 1 > 5.936317205435461)
#             Predict: 0.0
#         Else (feature 4 > 10.323449908097295)
#          If (feature 4 <= 10.523258615995953)
#           Predict: 1.0
#          Else (feature 4 > 10.523258615995953)
#           If (feature 4 <= 10.789670226527495)
#            Predict: 0.0
#           Else (feature 4 > 10.789670226527495)
#            If (feature 4 <= 11.18928764232481)
#             If (feature 2 <= 2.2940909197747317)
#              If (feature 0 <= 1.671759797357057)
#               Predict: 0.0
#              Else (feature 0 > 1.671759797357057)
#               Predict: 1.0
#             Else (feature 2 > 2.2940909197747317)
#              Predict: 1.0
#            Else (feature 4 > 11.18928764232481)
#             Predict: 0.0
#        Else (feature 3 > 71.42757148873099)
#         If (feature 0 <= 2.117562409985606)
#          If (feature 2 <= 2.2940909197747317)
#           If (feature 3 <= 74.55525537265709)
#            If (feature 1 <= 4.425254644051889)
#             If (feature 4 <= 8.325362829110722)
#              Predict: 0.0
#             Else (feature 4 > 8.325362829110722)
#              If (feature 0 <= 1.3002576201665998)
#               Predict: 0.0
#              Else (feature 0 > 1.3002576201665998)
#               Predict: 1.0
#            Else (feature 1 > 4.425254644051889)
#             Predict: 0.0
#           Else (feature 3 > 74.55525537265709)
#            Predict: 1.0
#          Else (feature 2 > 2.2940909197747317)
#           If (feature 1 <= 4.425254644051889)
#            If (feature 0 <= 1.0773563138523257)
#             Predict: 2.0
#            Else (feature 0 > 1.0773563138523257)
#             If (feature 3 <= 73.827887027558)
#              If (feature 0 <= 1.3002576201665998)
#               Predict: 0.0
#              Else (feature 0 > 1.3002576201665998)
#               Predict: 1.0
#             Else (feature 3 > 73.827887027558)
#              Predict: 0.0
#           Else (feature 1 > 4.425254644051889)
#            If (feature 3 <= 74.55525537265709)
#             If (feature 0 <= 1.0773563138523257)
#              Predict: 1.0
#             Else (feature 0 > 1.0773563138523257)
#              If (feature 0 <= 1.3002576201665998)
#               Predict: 2.0
#              Else (feature 0 > 1.3002576201665998)
#               Predict: 1.0
#            Else (feature 3 > 74.55525537265709)
#             Predict: 2.0
#         Else (feature 0 > 2.117562409985606)
#          If (feature 0 <= 2.3404637162998796)
#           If (feature 0 <= 2.191862845423697)
#            Predict: 2.0
#           Else (feature 0 > 2.191862845423697)
#            If (feature 2 <= 2.2940909197747317)
#             Predict: 1.0
#            Else (feature 2 > 2.2940909197747317)
#             Predict: 2.0
#          Else (feature 0 > 2.3404637162998796)
#           Predict: 2.0
#      Else (feature 1 > 7.015647606423727)
#       If (feature 4 <= 8.325362829110722)
#        Predict: 1.0
#       Else (feature 4 > 8.325362829110722)
#        Predict: 2.0
#     Else (feature 2 > 2.5827513666338042)
#      If (feature 3 <= 73.827887027558)
#       If (feature 2 <= 3.4943106725045583)
#        If (feature 4 <= 9.657420881768438)
#         Predict: 2.0
#        Else (feature 4 > 9.657420881768438)
#         If (feature 4 <= 10.190244102831524)
#          Predict: 1.0
#         Else (feature 4 > 10.190244102831524)
#          If (feature 3 <= 71.42757148873099)
#           Predict: 2.0
#          Else (feature 3 > 71.42757148873099)
#           If (feature 0 <= 1.3002576201665998)
#            Predict: 2.0
#           Else (feature 0 > 1.3002576201665998)
#            Predict: 1.0
#       Else (feature 2 > 3.4943106725045583)
#        If (feature 1 <= 6.260116325731941)
#         If (feature 4 <= 9.657420881768438)
#          If (feature 0 <= 3.306369376995068)
#           If (feature 2 <= 5.013576182289149)
#            Predict: 2.0
#           Else (feature 2 > 5.013576182289149)
#            Predict: 1.0
#          Else (feature 0 > 3.306369376995068)
#           If (feature 4 <= 8.99139185543958)
#            If (feature 0 <= 4.123674166814074)
#             Predict: 1.0
#            Else (feature 0 > 4.123674166814074)
#             If (feature 1 <= 5.936317205435461)
#              Predict: 2.0
#             Else (feature 1 > 5.936317205435461)
#              Predict: 1.0
#           Else (feature 4 > 8.99139185543958)
#            Predict: 2.0
#         Else (feature 4 > 9.657420881768438)
#          Predict: 2.0
#        Else (feature 1 > 6.260116325731941)
#         If (feature 2 <= 5.013576182289149)
#          If (feature 4 <= 9.657420881768438)
#           Predict: 2.0
#          Else (feature 4 > 9.657420881768438)
#           If (feature 3 <= 71.42757148873099)
#            If (feature 4 <= 10.789670226527495)
#             If (feature 4 <= 10.323449908097295)
#              Predict: 2.0
#             Else (feature 4 > 10.323449908097295)
#              If (feature 0 <= 2.117562409985606)
#               Predict: 2.0
#              Else (feature 0 > 2.117562409985606)
#               Predict: 1.0
#            Else (feature 4 > 10.789670226527495)
#             Predict: 2.0
#           Else (feature 3 > 71.42757148873099)
#            Predict: 2.0
#         Else (feature 2 > 5.013576182289149)
#          Predict: 2.0
#      Else (feature 3 > 73.827887027558)
#       If (feature 2 <= 3.4943106725045583)
#        If (feature 4 <= 10.190244102831524)
#         Predict: 2.0
#        Else (feature 4 > 10.190244102831524)
#         If (feature 0 <= 1.3002576201665998)
#          Predict: 1.0
#         Else (feature 0 > 1.3002576201665998)
#          Predict: 2.0
#       Else (feature 2 > 3.4943106725045583)
#        Predict: 1.0

# %%
# splitting data into training and test data set
train_data, test_data = data_changed.randomSplit(weights=[0.75,0.25], seed=1)
# measure model performance
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
model = rfc.fit(train_data)

# %%
# predict 'RiskLevelIndex' from raw data
from pyspark.ml.linalg import Vectors
model.predict(Vectors.dense([35, 80, 8, 70, 60]))
# Out:
# 2.0

# %%
# 8.5

# %%
# calculate performance accuracy on all the features
data_changed=data.select(data.columns[0:8])
data_changed = data_changed.drop('SystolicBP')
# collect the input features
assembler = VectorAssembler(
        inputCols=['Age','DiastolicBP','BS','BodyTemp','HeartRate'], outputCol="features")
# transform the data
data_changed=assembler.transform(data_changed)
# standardize the feature values
standardScaler=StandardScaler()
standardScaler.setInputCol('features')
model=standardScaler.fit(data_changed)
model.setOutputCol('features_scaled')
data_changed=model.transform(data_changed)

# %%
from pyspark.mllib.evaluation import MulticlassMetrics
from pyspark.ml.evaluation import BinaryClassificationEvaluator
# splitting data into training and test data set
train_data, test_data = data_changed.randomSplit(weights=[0.75,0.25], seed=1)
# measure model performance
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
model = rfc.fit(train_data)
# predict response
predictions = model.transform(test_data)
# Metrics
predictionRDD = predictions.select(['RiskLevelIndex', 'prediction']).rdd.map(lambda line: (line[1], line[0]))
metrics = MulticlassMetrics(predictionRDD)
# Confusion Matrix
print('Confusion Matrix \n', metrics.confusionMatrix().toArray())
print('\nAccuracy =', metrics.accuracy)
# Out:
# Confusion Matrix
#  [[71. 14.  1.]
#  [13. 62.  3.]
#  [ 1.  5. 55.]]
#
# Accuracy = 0.8355555555555556

# %%
# splitting data into training and test data set
train_data, test_data = data_changed.randomSplit(weights=[0.8,0.2], seed=1)
# measure model performance
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
model = rfc.fit(train_data)
# predict response
predictions = model.transform(test_data)
# Metrics
predictionRDD = predictions.select(['RiskLevelIndex', 'prediction']).rdd.map(lambda line: (line[1], line[0]))
metrics = MulticlassMetrics(predictionRDD)
# Confusion Matrix
print('Confusion Matrix \n', metrics.confusionMatrix().toArray())
print('\nAccuracy =', metrics.accuracy)
# Out:
# Confusion Matrix
#  [[57.  7.  2.]
#  [13. 49.  3.]
#  [ 2.  3. 46.]]
#
# Accuracy = 0.8351648351648352

# %%
# splitting data into training and test data set
train_data, test_data = data_changed.randomSplit(weights=[0.9,0.1], seed=1)
# measure model performance
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
model = rfc.fit(train_data)
# predict response
predictions = model.transform(test_data)
# Metrics
predictionRDD = predictions.select(['RiskLevelIndex', 'prediction']).rdd.map(lambda line: (line[1], line[0]))
metrics = MulticlassMetrics(predictionRDD)
# Confusion Matrix
print('Confusion Matrix \n', metrics.confusionMatrix().toArray())
print('\nAccuracy =', metrics.accuracy)
# Out:
# Confusion Matrix
#  [[26.  5.  0.]
#  [ 6. 24.  1.]
#  [ 3.  1. 19.]]
#
# Accuracy = 0.8117647058823529

# %%
# model
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                                 numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)
ratio=[]
acc=[]
for i in np.arange(0.1,1,0.05):
    i=np.around(i,2)
    j=np.around((1-i), 2)
    # splitting data into training and test data set
    train_data, test_data = data_changed.randomSplit(weights=[i,j], seed=1)
    # measure model performance
    model = rfc.fit(train_data)
    # predict response
    predictions = model.transform(test_data)
    # Metrics
    predictionRDD = predictions.select(['RiskLevelIndex', 'prediction']).rdd.map(lambda line: (line[1], line[0]))
    metrics = MulticlassMetrics(predictionRDD)
    ratio.append([i,j])
    acc.append(np.around(metrics.accuracy, 4))

# %%
rfc_acc = pd.DataFrame({'train/test partition ratio':ratio, 'accuracy': acc})
rfc_acc
# Out:
#    train/test partition ratio  accuracy
# 0                  [0.1, 0.9]    0.6295
# 1                [0.15, 0.85]    0.6957
# 2                  [0.2, 0.8]    0.7112
# 3                [0.25, 0.75]    0.7065
# 4                  [0.3, 0.7]    0.7438
# 5                [0.35, 0.65]    0.7480
# 6                  [0.4, 0.6]    0.7612
# 7                [0.45, 0.55]    0.7514
# 8                  [0.5, 0.5]    0.7495
# 9                [0.55, 0.45]    0.7494
# 10                 [0.6, 0.4]    0.7881
# 11               [0.65, 0.35]    0.7901
# 12                 [0.7, 0.3]    0.8094
# 13               [0.75, 0.25]    0.8356
# 14                 [0.8, 0.2]    0.8352
# 15               [0.85, 0.15]    0.8268
# 16                 [0.9, 0.1]    0.8118
# 17               [0.95, 0.05]    0.8780

# %%
# rfc model
rfc = RandomForestClassifier(labelCol='RiskLevelIndex',featuresCol='features_scaled', seed=4,
                            numTrees=20, maxDepth=10, maxBins=17, subsamplingRate=0.97)

# Evaluate model
evaluator = MulticlassClassificationEvaluator(
            labelCol="RiskLevelIndex", predictionCol="prediction", metricName="accuracy")

params_grid = ParamGridBuilder().build()

# create 10-fold cross validator with 10 repeats
accuracy=[]
for i in range(0,20):
    # shuffle data
    shuffledDF = data_changed.orderBy(rand())
    # split data into train and test data set
    train_data, test_data = shuffledDF.randomSplit(weights=[0.75,0.25], seed=1)
    # 10-fold CrossValidator
    rfcv = CrossValidator(estimator=rfc, estimatorParamMaps=params_grid, evaluator=evaluator, numFolds=10, seed=1)
    # run cross validations
    cvmodel = rfcv.fit(train_data)
    # model predictions
    predictions = cvmodel.transform(test_data)
    accuracy.append(evaluator.evaluate(predictions))
np.average(accuracy)
# Out:
# 0.8355555555555554

# %%
pip install xgboost==1.2.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xgboost==1.2.0
#   Downloading xgboost-1.2.0-py3-none-manylinux2010_x86_64.whl (148.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.9/148.9 MB 946.8 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in ./.local/lib/python3.10/site-packages (from xgboost==1.2.0) (1.22.4)
# Requirement already satisfied: scipy in ./.local/lib/python3.10/site-packages (from xgboost==1.2.0) (1.8.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

# splitting data into training and test data set
train_data, test_data = data_changed.randomSplit(weights=[0.75,0.25], seed=1)
# Your code ...
x=train_data.select('Age','DiastolicBP','BS','BodyTemp','HeartRate').toPandas()
y=train_data.select('RiskLevelIndex').toPandas()
x_test = test_data.select('Age','DiastolicBP','BS','BodyTemp','HeartRate').toPandas()
# fit model and predict
xgb = XGBClassifier(random_state=4).fit(x, y)
pred = xgb.predict(x_test)
y_test=np.array(test_data.select('RiskLevelIndex').toPandas().RiskLevelIndex)
print('confusion_matrix \n', confusion_matrix(y_test, pred))
print('\nAccuracy_score =', accuracy_score(y_test, pred))
# Out:
# confusion_matrix
#  [[72 10  4]
#  [12 62  4]
#  [ 1  4 56]]
#
# Accuracy_score = 0.8444444444444444

# %%
ratio=[]
acc=[]
for i in np.arange(0.1,1,0.05):
    i=np.around(i,2)
    j=np.around((1-i), 2)
    # splitting data into training and test data set
    train_data, test_data = data_changed.randomSplit(weights=[i,j], seed=1)
    # Your code ...
    x=train_data.select('Age','DiastolicBP','BS','BodyTemp','HeartRate').toPandas()
    y=train_data.select('RiskLevelIndex').toPandas()
    x_test = test_data.select('Age','DiastolicBP','BS','BodyTemp','HeartRate').toPandas()
    # fit model and predict
    xgb = XGBClassifier(random_state=4).fit(x, y)
    pred = xgb.predict(x_test)
    y_test=np.array(test_data.select('RiskLevelIndex').toPandas().RiskLevelIndex)
    ratio.append([i,j])
    acc.append(accuracy_score(y_test, pred))
xgb_acc = pd.DataFrame({'train/test partition ratio':ratio, 'accuracy': acc})
xgb_acc
# Out:
#    train/test partition ratio  accuracy
# 0                  [0.1, 0.9]  0.630650
# 1                [0.15, 0.85]  0.710024
# 2                  [0.2, 0.8]  0.737913
# 3                [0.25, 0.75]  0.739130
# 4                  [0.3, 0.7]  0.756914
# 5                [0.35, 0.65]  0.772071
# 6                  [0.4, 0.6]  0.785223
# 7                [0.45, 0.55]  0.779661
# 8                  [0.5, 0.5]  0.788501
# 9                [0.55, 0.45]  0.826698
# 10                 [0.6, 0.4]  0.832041
# 11               [0.65, 0.35]  0.814815
# 12                 [0.7, 0.3]  0.834532
# 13               [0.75, 0.25]  0.844444
# 14                 [0.8, 0.2]  0.862637
# 15               [0.85, 0.15]  0.889764
# 16                 [0.9, 0.1]  0.894118
# 17               [0.95, 0.05]  0.878049

# %%
# plot test accuracies of both the models on one grid
plt.figure()

x_val = [x[0] for x in rfc_acc['train/test partition ratio']]
y_val = [x for x in rfc_acc['accuracy']]
plt.plot(x_val, y_val, label="Random Forest Classifier")

x_val = [x[0] for x in xgb_acc['train/test partition ratio']]
y_val = [x for x in xgb_acc['accuracy']]
plt.plot(x_val, y_val, label="XGBClassifier")

plt.title('test accuracy versus train set ratio')
plt.xlabel('train ratio')
plt.ylabel('test accuracy')
plt.legend()
